# %%
# -*- coding: utf-8 -*-

# %%
import os
import pandas as pd 
from glob import glob

# %%
import sys
import time, re, pickle, itertools
import urllib3, json
sys.path.append('~/Documents/GitHub/Private_Project/personal_project/')
import re

# %%
import nltk
from __future__ import print_function, unicode_literals
from gensim.models.word2vec import Word2Vec
from sklearn.preprocessing import normalize as sknorm
import numpy as np
from operator import itemgetter
import html

# %%
from ckonlpy.tag import Twitter as ctwitter
from collections import Counter
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer, TfidfTransformer
from sklearn.linear_model import LogisticRegression
import numpy as np
import matplotlib.pyplot as plt
from konlpy.tag import Twitter, Mecab,Kkma
from konlpy.utils import pprint

# %%
import chat_bot as cb
import Database_Handler as dh

# %%
ct = ctwitter()
ot = Twitter()
mecab = Mecab()
xxxx = ct._dictionary._pos2words
print (list(map(lambda x: len(xxxx[x]), xxxx)))

score_weights = {
    'num_nouns': -0.1,
    'num_words': -0.2,
    'no_noun': -1
}

def my_score(candidate):
    num_nouns = len([w for w,t in candidate if t == 'Noun'])
    num_words = len(candidate)
    no_noun = 1 if num_nouns == 0 else 0
    
    score = (num_nouns * score_weights['num_nouns'] 
             + num_words * score_weights['num_words']
             + no_noun * score_weights['no_noun'])
    return score

ct.set_selector(score_weights, my_score)
# Out:
# [512, 1464079, 5532]
# [('이', 'Noun'), ('것', 'Noun'), ('은', 'Josa'), ('테', 'Noun'), ('스트', 'Noun')]
# [('이것', 'Noun'), ('은', 'Josa'), ('테', 'Noun'), ('스트', 'Noun')]
# [('이것', 'Noun'), ('은', 'Josa'), ('테스트', 'Noun')]
# best: [('이것', 'Noun'), ('은', 'Josa'), ('테스트', 'Noun')]

# %% [markdown]
# ## 언론사 리스트

# %% [markdown]
# > stopwords를 위해서

# %%
pressList = pd.read_excel('./data/presslist.xlsx')

with(open('./data/newspress.txt','w',encoding='utf-8')) as f:
    f.write('\n'.join(set(pressList['언론사'].tolist())))
def Stopwords(file):
    stopwords = open(file,'r',  encoding='utf-8').readlines()
    stopwords = list(map(lambda x:x.strip(), stopwords))
    return stopwords
stopwordList = Stopwords('./data/newspress.txt')

# %% [markdown]
# # 자연어 처리

# %% [markdown]
# ## TextRank

# %%
swords =['이제','너무','중인' ,'만큼', '마찬가지', '꼬집었', '기자','습니다','어요','이렇게', "아", "휴", 
         "아이구", "아이쿠", "아이고",'라고','지난','당시','오전','오후',"어", "나", "우리", "저희", "따라", "의해",'데일리',
         '이날','갑자기','같다','는데','다른','에서','하는','하게','이후','통해','이날','정말','다시','스스로','같은','지난주',
         '이번주','다음주','그런','이런','첫째','둘째','셋째','넷째','다섯째','여섯째','일곱째','여덟째','아홉째','열째','기성',
             '이었','라는','저번','이번','면서','이렇게','저렇게','그렇게','정근','판청','아르테',
            '앵커','아나운서','좌윤','주고', 'B씨','A씨','경우','서로','대로','지사','인근','스완','위해','대한',
            '통한','기성','영제','간다','대해','수준','젊은','스탠','이씨','헤아','하라','패스트','좌안','이토','2TV',
            '성은','산다','나요','선우','누나','억원','태수','그냥','사이','어마','위엄','남자','로서','우리','누리','관련',
            '윤종','다친','승헌','골망','있는','까지','반종빈','녹이','현재','세이','카스티','스티','물론','라덴','상대로',
            '여러','아미','아사다','이닝','유기','신서','티브이데일리','공동','윤이','치원','타고','박씨','루수','유력','타고',
            '하고','처음','김씨','연재','사람','다이어','이다','인근','니다','아직','이씨','탈린','윤계','이날',
            '이것','저것','그것','신잡','장영','고씨','박씨','사실','경정','손새','장의','미도','말했',
            '빈살','실제','분들','건너','최근','조씨','장씨','올해','내년','작년','지난해','여서','A군','B군',
            '고든','램지','진혁','심지어','D씨','최근','니다','협회','그리즈','미오','그것','메이','이재','윈터',
            '임오','레이먼','사는','잡고','이야','치치','있다','1호','2호','3호','4호','5호','6호','7호','8호','9호',
            '다양한','부분','심씨','트루시','트루','심씨','부분','전체','주씨','펀치','원투','A사','1차','2차','3차','4차',
            '5차','6차','7차','8차','9차','10차','계속','MK','매경닷컴','MK스포츠','티노','처음','모현','들이','있는',
            '더욱','차장','부장','시점','000','달라','모든','구름','맑음','방향','같아','믹스','나인','윤균','모두',
            '라며','헤아','제트','라카','소속','1분','신잡','울스','일단','번째','어서','이지','원장','교수','선수',
            '안젤리나','브래드','드려','조원','둥지','빅리그','어떻','대답했','루프','트리플','빅토르','지금','때문','해성',
             '빠졌','그리팅','5일','점프','그룹','시즌','크게','없는']
swords2 = ['중인' ,'만큼', '마찬가지', '꼬집었', "기자","아", "휴", "아이구",
                      "아이쿠", "아이고", "어", "나", "우리", "저희", "따라", "의해", "을", "를", "에", "가"] + pressList['언론사'].tolist() + ["저", "것",
    "동시에", "몇", "고려하면", "관련이", "놀라다", "무엇", "어느쪽", "오", "정도의", "더구나", "아무도", "줄은모른다", "참", "아니",
         "휘익", "향하다", "응당", "알겠는가", "인젠", "그래서", "자신", "해서는", "둘", "이었다", "임에", "하도록시키다", "누구", "이때",
         "삼", "제외하고", "쿵", "하면", "좀", "그렇지않으면", "아니었다면", "이라면", "팍", "일", "통하여", "무엇때문에", 
         "보아", "하게하다", "하는", "이르다", "타다", "까지도", "오직", "도달하다", "잠깐", "외에", "심지어", "하려고하다", "게다가",
         "후", "알", "비하면", "헉헉", "근거로", "월", "따라서", "않는다면", "일지라도", "함께", "이유는", "흥", "혼자", "관하여", 
         "붕붕", "하다", "진짜로", "의해", "바와같이", "대하면", "퍽", "보다더", "그렇게", "끼익", "댕그", "시초에", "당장", 
         "하는것만", "누가", "만이", "만일", "이지만", "하마터면", "꽈당", "만은", "우선", "없다", "휴", "하도록하다", "그런데",
         "비로소", "하게될것이다", "만큼 어찌됏든", "오히려", "을", "더라도", "안", "왜냐하면", "습니다", "줄은", "그리하여", "하",
         "어떻게", "대로", "기대여", "끙끙", "예를", "와르르", "이리하여", "이", "조차", "하고", "이젠", "뒤이어", "할줄알다", "반대로",
         "시각", "펄렁", "잇따라", "공동으로", "비록", "가까스로", "여덟", "비슷하다", "이상", "차라리", "이어서", "모두", "툭", "조차도",
         "헉", "부터", "혹시", "않고", "우리", "삐걱", "여보시오", "허", "해요", "견지에서", "하기는한데", "토하다", "않으면", "이봐", "관계가", 
         "한다면", "시작하여", "연이서", "이외에도", "그", "운운", "에게", "그럼에도", "예", "만약에", "했어요", "결과에", "제", "오자마자",
         "것들", "약간", "것과", "일때", "셋", "각종", "아이구", "같은", "향해서", "일것이다", "해야한다", "아이야", "로", "편이", "등등", 
         "해도좋다", "하기에", "김에", "몰랏다", "같이", "하도다", "즉시", "갖고말하자면", "우에", "어느", "허허", "하자마자", "에서", "그래도",
         "하여야", "된이상", "까악", "한켠으로는", "많은", "그중에서", "사", "낼", "뿐만", "저쪽", "어쩔수", "어떤것들", "물론", "결론을", "이만큼",
         "이렇게되면", "소인", "바꾸어말하면", "들", "이렇구나", "하물며", "얼마간", "얼마든지", "한항목", "하는것도", "졸졸", "한마디", "말할것도", 
         "만약", "남들", "총적으로", "허걱", "그리고", "따지지", "구체적으로", "못하다    하기보다는", "언제", "따르는", "구토하다", "앞에서",
         "대해서", "아", "앞의것", "비걱거리다", "헐떡헐떡", "어찌하든지", "입장에서", "의", "마저", "바로", "하기만", "않기", "또한", "쓰여",
         "위해서", "의거하여", "인", "아니면", "를", "사람들", "할수있다", "일곱", "근거하여", "한적이있다", "함으로써", "낫다", "어떤것",
         "방면으로", "중의하나", "어", "무릎쓰고", "저것만큼", "서술한바와같이", "그런즉", "들자면", "하지", "아이고", "불문하고", "만", 
         "마저도", "얼마만큼", "예컨대", "이렇게말하자면", "연관되다", "않다면", "들면", "이쪽", "의지하여", "여섯", "그저", "아니다", 
         "그렇지만", "기준으로", "되어", "가", "무렵", "즉", "말하면", "어찌", "그럼", "그위에", "그런", "조금", "매번", "혹은",
         "이천구", "중에서", "따름이다", "하기", "가령", "잠시", "아무거나", "하기보다는", "주저하지", "당신", "봐라", "그렇지",
         "자기집", "할지라도", "요만한걸", "우르르", "못하다", "왜", "이렇게", "퉤", "관계없이", "그래", "대해", "쪽으로", 
         "저것", "자기", "아홉", "지만", "구", "하지마", "따위", "하지만", "나", "해도", "전자", "그만이다", "안된다", "까닭으로", 
         "되다", "오르다", "딱", "다음에", "너희들", "점에서", "아이쿠", "쾅쾅", "종합한것과같이", "할수있어", "그치지", "비교적",
         "륙", "되는", "개의치않고", "엉엉", "하든지", "때가", "영차", "바꿔", "더불어", "주룩주룩", "따라", "이용하여", "우리들",
         "여기", "더욱이는", "하더라도", "입각하여", "여러분", "마치", "하느니", "너", "어디", "제각기", "밖에", "봐", "위하여", 
         "팔", "요만큼", "가서", "아니라면", "지든지", "참나", "할만하다", "타인", "든간에", "하겠는가", "거바", "겨우", "다음", 
         "이러한", "이럴정도로", "각자", "어때", "지말고", "형식으로", "그러한즉", "아니나다를가", "할", "불구하고", "지경이다",
    "어떠한", "기점으로", "할때", "등", "다시", "시키다", "답다", "소생", "라", "로써", "각", "부류의", "알았어", "훨씬", "위에서",
    "뿐이다", "시간", "그러나", "하곤하였다", "일단", "막론하고", "좋아", "솨", "이곳", "뿐만아니라", "아울러", "옆사람", "다수", 
    "예하면", "령", "어떤", "어떻해", "할수록", "말하자면", "전후", "메쓰겁다", "에", "으로써", "이번", "하면된다", "이것", "딩동",
"양자", "달려", "본대로", "탕탕", "마음대로", "쉿", "미치다", "다시말하면", "동안", "그러니까", "과연", "뚝뚝", "거의", "이천팔",
"이로", "않도록", "또", "한하다", "아래윗", "수", "다소", "어느것", "까지", "남짓", "저기", "관한", "무슨", "그에", "년도", 
"삐걱거리다", "이러이러하다", "와", "넷", "쳇", "논하지", "습니까", "이천육", "기타", "오로지", "어느곳", "설령", "할지언정", "칠",
"다만", "반드시", "한데", "곧", "의해서", "얼마나", "아니라", "상대적으로", "너희", "있다", "인하여", "다섯", "생각이다", "몰라도", 
"정도에", "버금", "까닭에", "얼마큼", "전부", "로부터", "힘입어", "틈타", "해도된다", "나머지는", "흐흐", "그때", "하여금", "모", 
"이런", "바꾸어서", "비추어", "각각", "설사", "이래", "비길수", "하지마라", "응", "다른", "듯하다", "보는데서", "어쨋든", "대하여", 
"좍좍", "으로", "여차", "틀림없다", "과", "고로", "요컨대", "일반적으로", "줄", "하는바", "그들", "요만한", "윙윙", "콸콸", "어기여차",
"언젠가", "이와", "할망정", "이천칠", "네", "없고", "둥둥", "겸사겸사", "그러므로", "안다", "거니와", "년", "여부", "때문에", "된바에야",
"향하여", "때", "하하", "및", "오호", "하면서", "더군다나", "한", "이유만으로", "어이", "하나", "저희", "더욱더", "두번째로", "바꾸어말하자면",
"이와같다면", "이르기까지", "단지", "그러면", "야", "결국", "영","뒤따라", "즈음하여", "도착하다", "와아", "다음으로", "같다", "자",
"아하", "생각한대로", "외에도", "의해되다", "설마", "으로서", "보면", "할뿐", "첫번째로", "아야", "어째서", "하는것이", "하구나", "않다",
"힘이", "육", "그러니", "여전히", "어찌됏어", "어찌하여", "어느해", "앗", "게우다","보드득", "관해서는", "자마자", "매", "하고있었다", 
"어느때", "여", "실로", "해봐요", "얼마", "아이"]

# %%
class SentenceTokenizer(object):
    def __init__(self):
        self.twitter = ot
        self.ctwitter = ct
        self.mecab = mecab
        
        #self.stopwords = []
        self.stopwords = swords +swords2 + stopwordList
    def text2sentences(self, text):
        sentences = re.sub('\. ','.\n', text).split('\n')
        for idx in range(0, len(sentences)):
            if len(sentences[idx]) <= 10:
                sentences[idx-1] += (' ' + sentences[idx])
                sentences[idx] = ''
        return sentences
    def get_nouns(self, sentences):
        nouns = []
        for sentence in sentences:
            if sentence is not '':
                #nouns.append(' '.join([noun for noun in self.ctwitter.phrases(str(sentence))
                #                                    if noun not in self.stopwords and len(noun) > 1]))
                #nouns.append(' '.join([noun for noun in self.ctwitter.nouns(str(sentence))
                #                                  if noun not in self.stopwords and len(noun) > 1]))
                #nouns.append(' '.join([noun for noun in self.ctwitter.morphs(str(sentence))
                #                                   if noun not in self.stopwords and len(noun) > 1]))
                nouns.append(' '.join([noun for noun in self.mecab.nouns(str(sentence))
                                                  if noun not in self.stopwords and len(noun) > 1]))
                nouns.append(' '.join([noun for noun in self.mecab.morphs(str(sentence))
                                                   if noun not in self.stopwords and len(noun) > 1]))
        nouns = list(set(nouns))
        return nouns
    
class GraphMatrix(object):
    def __init__(self):
        self.tfidf = TfidfVectorizer(ngram_range=(1,4),sublinear_tf=True, lowercase=False, min_df=0.0001)
        self.cnt_vec = CountVectorizer(ngram_range=(1,4), lowercase=False,min_df=0.0001,)
        self.graph_sentence = []
    def build_sent_graph(self, sentence):
        tfidf_mat = self.tfidf.fit_transform(sentence).toarray()
        #tfidf_mat = self.tfidf.fit_transform(sentence).toarray()
        self.graph_sentence = np.dot(tfidf_mat, tfidf_mat.T)
        return self.graph_sentence
    def build_words_graph(self, sentence):
        cnt_vec_mat = sknorm(self.cnt_vec.fit_transform(sentence).toarray().astype(float), axis=0)
        vocab = self.cnt_vec.vocabulary_
        return np.dot(cnt_vec_mat.T, cnt_vec_mat), {vocab[word] : word for word in vocab}

class Rank(object):
    def get_ranks(self, graph, d=0.85): # d = damping factor
        A = graph
        matrix_size = A.shape[0]
        for id in range(matrix_size):
            A[id, id] = 0 # diagonal 부분을 0으로
            link_sum = np.sum(A[:,id]) # A[:, id] = A[:][id]
            if link_sum != 0:
                A[:, id] /= link_sum
            A[:, id] *= -d
            A[id, id] = 1
        B = (1-d) * np.ones((matrix_size, 1))
        ranks = np.linalg.solve(A, B) # 연립방정식 Ax = b
        return {idx: r[0] for idx, r in enumerate(ranks)}

class TextRankX(object):
    def __init__(self, text):
        self.sent_tokenize = SentenceTokenizer()
        self.sentences = self.sent_tokenize.text2sentences(text)
        self.nouns = self.sent_tokenize.get_nouns(self.sentences)
        self.graph_matrix = GraphMatrix()
        self.sent_graph = self.graph_matrix.build_sent_graph(self.nouns)
        self.words_graph, self.idx2word = self.graph_matrix.build_words_graph(self.nouns)
        self.rank = Rank()
        self.sent_rank_idx = self.rank.get_ranks(self.sent_graph)
        self.sorted_sent_rank_idx = sorted(self.sent_rank_idx, key=lambda k: self.sent_rank_idx[k], reverse=True)
        self.word_rank_idx = self.rank.get_ranks(self.words_graph)
        self.sorted_word_rank_idx = sorted(self.word_rank_idx, key=lambda k: self.word_rank_idx[k], reverse=True)
    def summarize(self, sent_num=3):
        summary = []
        index=[]
        for idx in self.sorted_sent_rank_idx[:sent_num]:
            index.append(idx)
        index.sort()
        for idx in index:
            summary.append(self.sentences[idx])
        return summary
    def keywords(self, word_num=10):
        rank = Rank()
        rank_idx = rank.get_ranks(self.words_graph)
        sorted_rank_idx = sorted(rank_idx, key=lambda k: rank_idx[k], reverse=True)
        keywords = []
        index=[]
        for idx in sorted_rank_idx[:word_num]:
            index.append(idx)
        #index.sort()
        for idx in index:
            keywords.append(self.idx2word[idx])
        return keywords

# %% [markdown]
# # 분석

# %% [markdown]
# * 중복되서 나오는 것 제거
# * 혼자 나왔는데 태그가 이상한거 제거

# %%
extract_keywords_dict = dict()
site = 'Naver'
#site = 'daum'
if site == 'daum':
    binList = []
    collection = 'newsDaum'
    etri_outcome = '/Users/hyunyoun/Documents/GitHub/Private_Project/personal_project/data/ETRI_OUTCOME/daum2/'
elif site.lower() == 'naver':
    binList = []
    collection = 'newsNaver'
    etri_outcome = '/Users/hyunyoun/Documents/GitHub/Private_Project/personal_project/data/ETRI_OUTCOME/naver2/'

mongodb = dh.ToMongoDB(*dh.AWS_MongoDB_Information())
dbname = 'hy_db'
useDb = dh.Use_Database(mongodb, dbname)
slack = cb.Slacker(cb.slacktoken())
useCollection = dh.Use_Collection(useDb, collection)
keywordList = list()
for data in useCollection.find({'site':site}):
    #if len(data['mainText'].strip()) == 0:
        #print (data['link'])
        #break
    idIs = data['_id']._ObjectId__id
    tis2 = html.unescape(data['title'])+'. '+html.unescape(data['mainText'])
    #tis2 = '.\n'.join(tis.split('. '))
    #tis2 = data['mainText']
    if data['keywords'] !='NaN':
        keywordList += list(map(lambda x: ''.join(x.split(' · ')[-1].split(' ')), data['keywords']))
    else:
        pass
    print (data['link'])
    print (data['title'])
    print (data['keywords'])
    try:
        workrank = TextRankX(tis2)
    except:
        try:
            workrank = TextRankX(tis2)
        except:
            workrank = TextRankX(tis2)
            break
    extract_keywords_dict[idIs.hex()]= workrank.keywords()
    print (workrank.keywords())
    #print (lr)
    print ()
    
    '''
    if not os.path.isfile(etri_outcome+idIs.hex()+'.picked.txt'):
        try:
            etri = USE_ETRI_ANALYSIS('srl', tis2)
        except:
            print (etri[1])
            break
        else:
            pickle.dump(etri[0], open(etri_outcome+idIs.hex()+'.picked.txt','wb'))
            '''
# Out:
# http://sports.news.naver.com/sports/index.nhn?ctg=ranking_news&mod=read&ranking_type=popular_day&date=20171212&office_id=410&article_id=0000425760
# [윈터미팅 1일차] 모리스의 눈물, 스탠튼의 뒤끝
# ['마이애미 말린스', '지안카를로 스탠튼']
# ['말린스', '스탠튼', '계약', '윈터미팅', '명예 전당', '전당', '명예', '이적', '양키스', '생각']
#
# http://sports.news.naver.com/sports/index.nhn?ctg=ranking_news&mod=read&ranking_type=popular_day&date=20171212&office_id=477&article_id=0000102428
# [SPO 이슈] '2% 확률' 니퍼트 재취업 가능성은?
# NaN
# ['외국인', '니퍼트', '영입', '두산', '선발', '롯데', '삼성', '계약', '선발투수', '외국인 선발투수']
#
# http://sports.news.naver.com/sports/index.nhn?ctg=ranking_news&mod=read&ranking_type=popular_day&date=20171212&office_id=452&article_id=0000000730
# [서호정의 킥오프] 믿을 건 황금세대뿐, 한국 여자 축구의 현실
# NaN
# ['한국', '북한', '여자', '축구', '월드컵', '여자 축구', '일본', '감독', '대표', '한국 여자']
#
# http://sports.news.naver.com/sports/index.nhn?ctg=ranking_news&mod=read&ranking_type=popular_day&date=20171212&office_id=139&article_id=0002084547
# "우리가 바카요코를 좀 도와주자" 캉테 호소
# ['은골로 캉테']
# ['바카요코', '첼시', '캉테', '훈련', '한다', '열심히', '열심히 훈련', '필요', '감독', '무에']
#
# http://sports.news.naver.com/sports/index.nhn?ctg=ranking_news&mod=read&ranking_type=popular_day&date=20171212&office_id=382&article_id=0000612811
# 두산, ‘니느님’ 아닌 ‘린동원’ 택한 진짜이유
# ['더스틴 니퍼트', '조쉬 린드블럼']
# ['린드블럼', '두산', '투수', '롯데', '니퍼트', '투구', '계약', '협상', '판단', '코프']
#
# http://sports.news.naver.com/sports/index.nhn?ctg=ranking_news&mod=read&ranking_type=popular_day&date=20171212&office_id=001&article_id=0009746247
# '안데르센 감독 지휘' 1년 반 北축구 국제 경쟁력은 '아직'
# ['요른 안데르센']
# ['북한', '일본', '경기', '한국', '대회', '밀집', '축구', '감독', '북한 축구', '밀집 수비']
#
# http://sports.news.naver.com/sports/index.nhn?ctg=ranking_news&mod=read&ranking_type=popular_day&date=20171212&office_id=410&article_id=0000425716
# [현장 인터뷰] 다저스 사장의 농담 "오승환은 어디로 갈까?"
# ['오승환']
# ['프리드먼', '다저스', '사장', '오승환', '계약', '취재진', '한국', '해서', '농담', '스포츠']
#
# http://sports.news.naver.com/sports/index.nhn?ctg=ranking_news&mod=read&ranking_type=popular_day&date=20171212&office_id=216&article_id=0000092245
# 바르사-첼시, 붙었다 하면 전쟁…드록신 ‘F’ 욕의 추억
# ['첼시 FC']
# ['첼시', '바르사', '경기', '결승', '챔피언스리그', '이니에스타', '16강', '준결승', '후반', '바르사 첼시']
#
# http://sports.news.naver.com/sports/index.nhn?ctg=ranking_news&mod=read&ranking_type=popular_day&date=20171212&office_id=468&article_id=0000330339
# 삼성 "니퍼트·해커 영입 가능성? 영입 기준과 맞지 않아"
# ['더스틴 니퍼트']
# ['영입', '삼성', '투수', '진행', '아델만', '작업', '외국인', '외국인 투수', '단장', '활약']
#
# http://sports.news.naver.com/sports/index.nhn?ctg=ranking_news&mod=read&ranking_type=popular_day&date=20171212&office_id=109&article_id=0003679204
# KIA 투트랙 연봉협상 훈풍…최대 포커스는 김선빈
# ['김선빈']
# ['협상', '인상', '연봉', '안치홍', '가운데', '요인', '인상 요인', '진행', '최고', '생애']
#
# http://entertain.naver.com/ranking/read?oid=112&aid=0002983780
# '신과함께' 이정재 "다음 생에 정우성으로 태어나고 싶다"
# ['이정재', '죄와벌', '김용화', '신과함께']
# ['리얼', '이정재', '신과함께', '작품', '감독', '김용화', '정우성', '배우', '영화', '정우성 태어나']
#
# http://entertain.naver.com/ranking/read?oid=112&aid=0002983622
# "폭풍공감"…'막영애16' 김현숙, 막돼먹은 세상 향해 메시지 던졌다
# NaN
# ['영애', '이사', '방송', '임신', '공감', '이사 영애', '여성', '막돼먹', '막영애', '16']
#
# http://entertain.naver.com/ranking/read?oid=076&aid=0003191450
# "절대낭만 퇴마극"..'화유기' 이승기X차승원 포스터 최초 공개
# ['이승기', '화유기', '명품', '서유기', '모티브']
# ['화유기', '포스터', '드라마', '절대', '절대 낭만', '낭만 퇴마', '절대 낭만 퇴마', '낭만', '퇴마', '배우']
#
# http://entertain.naver.com/ranking/read?oid=109&aid=0003679395
# "영화로 봐주길" ‘신과함께’ 웹툰과 다른 재미..관객 사로잡을까 [종합]
# ['신과함께', '웹툰', '차태현', '하정우', '죄와벌']
# ['영화', '신과함께', '원작', '영화 신과함께', '생각', '이야기', '웹툰', '다고', '다고 생각', '원본']
#
# http://entertain.naver.com/ranking/read?oid=076&aid=0003191370
# [SC줌인] 짐승돌→먹소→트라우마남…'그사이' 준호, 또 재발견
# ['그냥사랑하는사이', '트라우마', '원진아', '기대와관심', '먹방']
# ['준호', '이강두', '연기', '사랑', '사고', '상처', '발견', '하문', '거부', '방송']
#
# http://entertain.naver.com/ranking/read?oid=213&aid=0001005713
# [룩@차이나] "세월은 못 속여?" 중년 미모甲 공리, 충격 근황
# ['미모', '눈길', '여배우', '블로거']
# ['공리', '사진', '창춘', '궈마오', '창춘 궈마오', '근황', '중국', '여배우', '차이', '이미지 원본']
#
# http://entertain.naver.com/ranking/read?oid=112&aid=0002983623
# '투깝스' 조정석 "나 사기꾼인 거 잊었어?"…소름 돋는 배신
# NaN
# ['동탁', '지안', '수사', '여고생', '방송', '투깝스', '형사', '사기', '오늘', '박실장']
#
# http://entertain.naver.com/ranking/read?oid=109&aid=0003679238
# [★SHOT!] "몸은 참 정직해"..한혜진, 톱모델의 명품복근
# ['운동', '모델', '인스타그램']
# ['한혜진', '운동', '사진', '모습', '영상', '게재', '복근', '원본', '이미지', '이미지 원본']
#
# http://entertain.naver.com/ranking/read?oid=076&aid=0003190204
# "리듬체조→발레"..'백조클럽' 은퇴 손연재 '제2막' 도전[종합]
# ['손연재', '리듬체조', '오윤아', '발레리나', '박주미']
# ['발레', '손연재', '리듬체조', '공연', '멤버', '의지', '백조', '클럽', '백조 클럽', '이유']
#
# http://entertain.naver.com/ranking/read?oid=213&aid=0001005679
# [TV줌인] '동상이몽2' 추자현♥우효광, 결혼→'바다' 부모 '최고의 1년'
# ['추자현', '우효광', '결혼', '너는내운명', '라면']
# ['우효광', '추자현', '추자현 우효광', '동상이몽', '바다', '부부', '운명', '최고', '손효정', '결혼']
#
# http://entertain.naver.com/ranking/read?oid=076&aid=0003191360
# '최파타' 현아가 엿보인 의외성 #집순이 #남친 #콤플렉스[종합]
# ['현아', '최화정의파워타임', '콤플렉스', '최화정', '10주년']
# ['현아', '한다', '의외', '주년', '요리', '섹시', '최화정', '성격', '음식', '매력']
#
# http://entertain.naver.com/ranking/read?oid=213&aid=0001005747
# '강철비' 정우성 "예능 출연 독 될 때도, '아수라'가 그랬다" [인터뷰②]
# ['강철비', '아수라', '곽도원', '무한도전', '쿠데타']
# ['영화', '정우성', '강철비', '출연', '아수라', '감독', '홍보', '예능 출연', '예능', '반응']
#
# http://entertain.naver.com/ranking/read?oid=112&aid=0002983611
# [어게인TV]'무도' 이어 '섬총사'까지…조세호, 강호동도 감탄한 '프로입담러'
# NaN
# ['조세호', '강호동', '입담', '정상훈', '방송', '유재석', '상황극', '시작', '웃음', '면모']
#
# http://entertain.naver.com/ranking/read?oid=109&aid=0003679062
# [TV톡톡] “독설·고춧가루”..‘냉부해’ 고든 램지, 마성의 악마셰프
# ['고든램지', '이연복', '대결', '팬서비스', '김성주']
# ['셰프', '냉장고', '출연', '방송', '요리', '부탁', '냉장고 부탁', '독설', '대결', '한국']
#
# http://entertain.naver.com/ranking/read?oid=213&aid=0001005694
# 침대업체, 윤계상에 공식사과 "A씨는 블랙컨슈머, 심려끼쳐 죄송" [전문]
# ['민사소송', '언론매체', '악성루머', '공식입장']
# ['당사', '상대', '제기', '소송', '지속', '악의', '터무니', '행위', '윤계상', '요구']
#
# http://entertain.naver.com/ranking/read?oid=109&aid=0003679111
# [단독] "아이유희열, 기대해…SBS '가요대전' 특급 콜라보 성사
# ['아이유', '유희열', '콜라보', '콜라보레이션', '슈가맨']
# ['유희열', '아이유', '콜라보레이션', '무대', '가요대전', '콜라보레이션 무대', '유희열 아이유', '앨범', '토이', '음악']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=277&aid=0004138303&date=20171212&type=1&rankingSectionId=105&rankingSeq=30
# VR 롤러코스터는 게임물일까 놀이기구일까
# ['vr', '롤러코스터', '놀이기구']
# ['규제', 'VR', '롤러코스터', '시설', '적용', '게임', '콘텐츠', '설치', 'VR 롤러코스터', '허가']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=119&aid=0002227694&date=20171212&type=1&rankingSectionId=105&rankingSeq=28
# 아이폰8, 10월 스마트폰 판매 1위...삼성, 전체 점유율 선두
# ['아이폰8', '스마트폰', '삼성']
# ['점유', '애플', '삼성', '프리미엄', '시장', '리서치', '카운터포인트', '카운터포인트 리서치', '판매', '아이폰8']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=421&aid=0003096079&date=20171212&type=1&rankingSectionId=105&rankingSeq=27
# 직원PC만 해킹됐다고? 빗썸, 웹사이트 관리소홀 드러나
# ['이슈 · 가상화폐 광풍', '빗썸', '방송통신위원회', '과징금']
# ['빗썸', '해킹', '가상화폐', '웹사이트', '거래소', '탐지', '방통위', '유출', '정보', '공격']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=021&aid=0002336484&date=20171212&type=1&rankingSectionId=105&rankingSeq=25
# < ICT & Science >닻올렸다! ‘無人 화물船’ 시대
# ['ict', '자율주행차', '배터리']
# ['USV', '개발', '알파', '오션', '오션 알파', '배터리', '인건비', '자율주행차', '기업', '무인']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=015&aid=0003864072&date=20171212&type=1&rankingSectionId=105&rankingSeq=22
# [이슈+] 삼성 신기술 머금은 '갤럭시S9', 어떻게 나오나
# ['갤럭시s9', '삼성전자', '스마트폰']
# ['갤럭시', '삼성전자', '갤럭시S8', '탑재', '스마트폰', 'GB', '시리즈', '갤럭시S', '갤럭시S 9플러스', '9플러스']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=001&aid=0009744524&date=20171212&type=1&rankingSectionId=105&rankingSeq=21
# 10월 세계에서 가장 많이 팔린 스마트폰은 '아이폰8'
# ['이슈 · 아이폰X・아이폰8', '아이폰8', '스마트폰', '애플']
# ['점유', '시장', '카운터포인트 리서치', '카운터포인트', '리서치', '아이폰8', '시장 점유', '스마트폰', '삼성', '애플']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=001&aid=0009742969&date=20171212&type=1&rankingSectionId=105&rankingSeq=17
# 한국 LTE 속도 세계에서 가장 빠르다…"뉴욕의 4배"
# ['lte', '뉴욕', '다운로드']
# ['조사', '결과', '품질', '속도', '도시', 'Mbps', '서비스', '주요', '품질 조사', '한국']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=022&aid=0003233172&date=20171212&type=1&rankingSectionId=105&rankingSeq=15
# 낮아진 이모티콘 시장 장벽…막 그린듯 재치있는 'B급'유행
# ['카카오', '카카오톡', '직장인']
# ['이모티콘', '제작', '이모티콘 제작', '유행', '출시', '작품', '감정', '캐릭터', '설명', '보다']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=053&aid=0000024143&date=20171212&type=1&rankingSectionId=105&rankingSeq=12
# [IT] 카풀앱 풀러스 우버가 못 뚫은 규제 넘어설까
# NaN
# ['카풀', '서비스', '카풀 서비스', '풀러스', '규제', '퇴근', '서울시', '택시', '차량', '금지']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=015&aid=0003863698&date=20171212&type=1&rankingSectionId=105&rankingSeq=10
# [사이언스] "1770년 동북아 밤하늘을 9일이나 붉게 물들인 건 오로라였다"
# ['동북아', '동아시아', '비']
# ['기록', '자기폭풍', '오로라', '규모', '관측', '캐링턴', '발견', '문헌', '현상', '천문학자']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=025&aid=0002780468&date=20171212&type=1&rankingSectionId=105&rankingSeq=8
# 무한진화 AI 생태계 “한국은 바닥서 쫓겨다니는 토끼”
# ['인공지능', 'ai', '생태계']
# ['인공지능', '기술', '한국', '인공지능 기술', '세계', '투자', '집중', '엑소브레인', '산업', '소프트웨어']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=028&aid=0002390543&date=20171212&type=1&rankingSectionId=105&rankingSeq=2
#  인터넷 통신사 바꿀 때 해지신청 안 하면…요금은?
# ['번호이동', '이동통신', '인터넷']
# ['사업자', '요금', '자동', '신청', '대부분', '고객', '초고속인터넷', '해지', '인터넷텔레비전', '이동']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=016&aid=0001327170&date=20171212&type=0&rankingSectionId=105&rankingSeq=1
# “01X 번호 쓰게 해주세요” 다시 불거지는 2G종료 갈등
# ['2g', '3g', 'sk텔레콤']
# ['SK텔레콤', '종료', '이용', '가입자', '변경', '요금제', '단말기', '이용자', 'LTE', '청원']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=052&aid=0001093373&date=20171212&type=2&rankingSectionId=104&rankingSeq=26
# 日, 학교로 돌진한 멧돼지에 학생들 '혼비백산'
# ['멧돼지', '보수공사', '일본도']
# ['멧돼지', '일본', '교토', '학생', '녀석', '경찰', '합니다', '나라', '학교', '입니다']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=421&aid=0003094172&date=20171212&type=1&rankingSectionId=104&rankingSeq=24
# 탈영 후 월북했던 전 주한미군 젠킨스 사망
# ['주한미군', '고문', '비무장지대']
# ['북한', '일본', '납북 피해자', '피해자', '납북', '생활', '북한 생활', '젠킨스', '고문 감시', '감시']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=001&aid=0009743977&date=20171212&type=1&rankingSectionId=104&rankingSeq=23
# 트럼프, '뉴욕테러'에 이민법 촉구…"너무 많은 위험인물 입국"
# ['도널드 트럼프', '입국', '테러']
# ['미국', '트럼프', '대통령', '이민', '발생', '맨해튼', '트럼프 대통령', '용의자', '입국', '테러']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=001&aid=0009745038&date=20171212&type=1&rankingSectionId=104&rankingSeq=21
# 청혼앞둔 中 고층빌딩 클라이머, 62층 빌딩서 추락사
# ['추락사', '인터넷', '사우스차이나모닝포스트']
# ['빌딩', '융닝', '인터넷', '중국', '오르', '결혼', '추락', '62', '62 빌딩', '다가']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=001&aid=0009743693&date=20171212&type=1&rankingSectionId=104&rankingSeq=16
# 사우디, 여성운전 이어 영화관도 허용…내년 3월부터
# ['사우디', '영화관', '이슬람']
# ['사우디', '영화관', '허용', '이슬람', '남녀', '여성', '영화', '정부', '영화관 허용', '영화제']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=001&aid=0009744284&date=20171212&type=1&rankingSectionId=104&rankingSeq=14
# 필리핀에 첫 위안부 동상 건립…"일제 강점기 희생자 기억하자"(종합)
# ['필리핀', '위안부', '일제강점기']
# ['필리핀', '여성', '위안부', '일본', '동상', '정부', '마닐라', '위안부 여성', '필리핀 정부', '일본군 위안부']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=003&aid=0008337096&date=20171212&type=1&rankingSectionId=104&rankingSeq=13
# 이스라엘군,  탱크로 가자지구 하마스거점 또 보복공격
# ['이슈 · 미, 예루살렘 수도 선언', '이스라엘군', '가자지구', '이스라엘']
# ['이스라엘', '공격', '팔레스타인', '가자지구', '예루살렘', '로켓포', '차미례', '현지', '발표', '다고']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=001&aid=0009744527&date=20171212&type=1&rankingSectionId=104&rankingSeq=12
# 팔레스타인 로켓공격에 이스라엘 공습…'예루살렘 갈등' 최고조
# ['팔레스타인', '예루살렘', '가자지구']
# ['이스라엘', '팔레스타인', '가자지구', '공습', '공격', '이스라엘 팔레스타인', '하마스', '전투기', '양측', '사진']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=025&aid=0002780639&date=20171212&type=1&rankingSectionId=104&rankingSeq=10
# 한·중 사드 갈등 닮아가는 일·러 ‘지상형 이지스’ 배치 갈등
# ['이지스', '사드', '러시아군']
# ['러시아', '일본', '배치', '도입', '이지스', '러시아군', '이지스 어쇼어', '어쇼어', '미사일', '지대']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=081&aid=0002876553&date=20171212&type=1&rankingSectionId=104&rankingSeq=9
# [글로벌 인사이트] 시진핑 뒤에 ‘왕’ 있다
# ['시진핑', '왕후닝', '중국공산당']
# ['왕후닝', '중국', '주석', '정치', '시진핑', '상무위원', '권력', '미국', '학자', '장쩌민']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=421&aid=0003094284&date=20171212&type=1&rankingSectionId=104&rankingSeq=7
# 이-팔 예루살렘 둘러싸고 닷새째 교전…공중폭격까지
# ['이슈 · 미, 예루살렘 수도 선언', '예루살렘', '하마스', '이스라엘']
# ['이스라엘', '공격', '예루살렘', '팔레스타인', '무장', '로켓포', '하마스', '시위대', '정파', '헤즈볼라']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=001&aid=0009743797&date=20171212&type=1&rankingSectionId=104&rankingSeq=6
# "트럼프가 성추행" 의회조사 요청 …트럼프도 '미투' 휩쓸리나(종합)
# ['도널드 트럼프', '미투', '백악관']
# ['트럼프', '대통령', '트럼프 대통령', '성추행', '여성', '회견', '주장', '의혹', '미투', '주장 여성']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=055&aid=0000593860&date=20171212&type=1&rankingSectionId=104&rankingSeq=2
# [뉴스pick] 거북이 등껍질에 생긴 커다란 구멍…'3D 프린팅' 기술로 말끔히 복원
# ['합병증', '2013년', '원']
# ['구멍', '등껍질', '거북', '거북이', '아쿠아리움', '구조', '기술', '프린팅', '모팻', '복원']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=052&aid=0001093169&date=20171212&type=2&rankingSectionId=103&rankingSeq=29
# [날씨] 최강 한파 엄습...낮에도 체감 -10℃ 추위
# NaN
# ['한파', '추위', '서울', '고요', '바람', '체감', 'cm', '내일', '내려진', '온도']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=028&aid=0002390533&date=20171212&type=1&rankingSectionId=103&rankingSeq=25
#  [단독] 고조선 후예가 찾았다, 흉노제국 금속 마차
# ['몽골', '유라시아', '안개']
# ['마차', '흉노', '무덤', '조사단', '발굴', '조사', '바퀴', '몽골', '귀족', '목곽']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=277&aid=0004138291&date=20171212&type=1&rankingSectionId=103&rankingSeq=23
# [한파의 진실]②혹한을 뜻하는 '동장군'이란 말이 영어에서 비롯됐다고요?
# ['동장군', '한파', '이란']
# ['나폴레옹', '동장군', '러시아', '프랑스군', '단어', '러시아 원정', '원정', '나라', '한파', '시작']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=422&aid=0000292334&date=20171212&type=2&rankingSectionId=103&rankingSeq=22
# [날씨] 퇴근길 체감 영하 10도…한파 모레까지
# ['한파', '퇴근길', '경기북부']
# ['영하', '내일', '내리', '서울', '모레', '날씨', '오늘', '금요일', '10', '영하 10']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=003&aid=0008337901&date=20171212&type=1&rankingSectionId=103&rankingSeq=20
# 지하철역 사고대응 구멍 '숭숭'…직원 1명이 7개업무 수행
# ['지하철', '행안부', '화재']
# ['지하철', '현장', '사고', '행안부', '발생', '지침', '안전', '대응', '조치', '역사']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=056&aid=0010528212&date=20171212&type=2&rankingSectionId=103&rankingSeq=18
# 모스크바보다 추운 ‘때이른 한파’…“북극 찬공기 유입”
# ['한파', '한반도', '지구온난화']
# ['북극', '한반도', '한파', '공기', '모스크바', '발생', '한파 발생', '상공', '러시아', '송영석']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=052&aid=0001093090&date=20171212&type=2&rankingSectionId=103&rankingSeq=16
# [날씨] 한파와 칼바람에 전국이  꽁꽁...서울 -12.3℃
# NaN
# ['기온', '영하', '서울', '올겨울', '전국', '추위', '고요', '대구', '호남', '아침']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=052&aid=0001092927&date=20171212&type=2&rankingSectionId=103&rankingSeq=14
# [날씨] 중부에 첫 한파경보..."북극 한기 몰려왔다"
# ['한파경보', '한파', '한반도']
# ['한기', '한파', '영하', '북극', '입니다', '기온', '안팎', '예보', '15도', '전망']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=001&aid=0009744371&date=20171212&type=1&rankingSectionId=103&rankingSeq=13
# 최강 한파에 '저체온증·동상' 주의보…"음주는 금물"
# ['저체온증', '한파', '음주']
# ['동상', '저체온증', '한다', '환자', '해야', '부위', '발생', '행동', '한파', '영하']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=001&aid=0009744544&date=20171212&type=1&rankingSectionId=103&rankingSeq=9
# 서울 지하철 2호선 유리창에 금 간 채 1시간 운행…시민 불안
# ['유리창', '서울교통공사', '한파']
# ['열차', '균열', '운행', '원인', '균열 발생', '한파', '충돌', '발생', '해당', '해당 열차']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=032&aid=0002837806&date=20171212&type=1&rankingSectionId=103&rankingSeq=3
# 인천공항 제2터미널 가보니...분산 효과 기대, 초기 혼란 걱정도
# ['대한항공', '제2여객터미널', '패스트트랙']
# ['제2터미널', '터미널', '대한항공', '이용', '제1 터미널', '제1', '항공사', '승객', '제2여객터미널', '항공']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=277&aid=0004138290&date=20171212&type=1&rankingSectionId=103&rankingSeq=1
# [한파의 진실]①서울은 왜 위도가 훨씬 높은 모스크바보다 추울까?
# ['한파', '지구온난화', '기상청']
# ['서울', '보다', '기온', '북극', '기상청', '북극진동', '지구온난화', '지역', '기단', '한반도']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=003&aid=0008338480&date=20171212&type=1&rankingSectionId=102&rankingSeq=30
# 일자리 통계도 '맞춤형'…베이비부머·사회적경제 新통계 개발
# ['일자리', '일자리위원회', '세종시']
# ['통계', '일자리', '대상', '한다', '분석', '작성', '경제', '사회', '변동', '자료']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=005&aid=0001055043&date=20171212&type=1&rankingSectionId=102&rankingSeq=29
# [집과 삶, 그리고 주거권] “집 있어 다행?… 라면 하나 사먹기도 힘들어”
# ['라면', '단독주택', '고정비']
# ['할아버지', '서울', '단독주택', '기초', '연금', '노인', '이사', '월소득', '기준', '고정비']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=001&aid=0009744377&date=20171212&type=1&rankingSectionId=102&rankingSeq=28
# 경찰, '비트코인 사기극' 논란 고교생 신변보호
# ['비트코인', '가상화폐', '스마트워치']
# ['경찰', '신변보호', '요청', '스마트워치', '비트코인', '강남경찰서', '신변보호 요청', '경찰서', '주장', '계정']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=057&aid=0001204811&date=20171212&type=2&rankingSectionId=102&rankingSeq=25
# 가짜 자선냄비 조심하세요…진짜 구세군 자선냄비 구별법
# ['구세군', '이현재', '자원봉사자']
# ['구세군', '자선냄비', '봉사자', '자원 봉사자', '자원', '구세군 자선냄비', '단체', '모금', '확인', '윗면']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=014&aid=0003922818&date=20171212&type=1&rankingSectionId=102&rankingSeq=22
# 박은정 "선물 상한액 조정, 청탁금지법 취지 후퇴 아니다"
# ['박은정', '청탁금지법', '조정']
# ['부정청탁금지법', '상한액', '선물', '시행', '조사', '감소', '공무원', '권익위', '위원장', '10']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=025&aid=0002780463&date=20171212&type=1&rankingSectionId=102&rankingSeq=19
# 경조사비 부담 5만원 줄어들자 관가 환영 … 꽃·과일농가, 10만원 선물 가능해져 숨통
# ['청탁금지법', '구속영장', '사드']
# ['선물', '10', '경조사비', '김영란법', '농가', '5만원', '시행령', '수산물', '시행령 개정안', '개정안']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=001&aid=0009745577&date=20171212&type=1&rankingSectionId=102&rankingSeq=18
# "박근혜 정부 세월호 특조위 조사 방해의혹 사실로…수사의뢰"(종합2보)
# ['이슈 · 세월호 침몰 사고', '특조위', '세월호특조위', '해수부']
# ['특조위', '세월호', '활동', '해수부', '문건', '특조위 활동', '조사', '의혹', '세월호 특조위', '확인']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=001&aid=0009744879&date=20171212&type=1&rankingSectionId=102&rankingSeq=17
# 초등생 91%가 게임 즐겨…고2 여학생 86% '수면 부족'
# ['초등생', '비만율', '스트레스']
# ['비율', '청소년', '여학생', '게임', '상승', '초등학생', '비만율', '고2', '보다', '수면']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=079&aid=0003043393&date=20171212&type=1&rankingSectionId=102&rankingSeq=15
# 고교 급식에 '1인 1랍스터' 화제…"학생들 힘내라"
# ['급식', '예산', '피자']
# ['랍스터', '급식', '메뉴', '학생', '제공', '학교', '특식', '준비', '세인고', '울산']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=018&aid=0003990487&date=20171212&type=1&rankingSectionId=102&rankingSeq=10
# 공무원 노사협상, 11년 만에 타결…대화 물꼬 텄다(상보)
# ['공무원', '인사혁신처', '단체협약']
# ['교섭', '노사', '위원장', '공무원', '노조', '타결', '정부', '마련', '회의', '행정부']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=055&aid=0000593688&date=20171212&type=2&rankingSectionId=102&rankingSeq=7
# 오죽했으면…참다 참다 내걸린 현수막 '반말 그만'
# ['현수막', '공무원노조', '갑질']
# ['반말', '김해시', '모욕', '복잡', '송원재', '잖아', '현수막', '입니다', '체육관', '갑질']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=421&aid=0003094915&date=20171212&type=1&rankingSectionId=102&rankingSeq=6
# "외할머니는 힘들다"…맞벌이 19% 청소·육아 처가에 의존
# ['맞벌이', '육아', '통계청']
# ['시가', '비율', '처가', '부모', '지원', '도구 지원', '도구', '도움', '증가', '육아']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=003&aid=0008338156&date=20171212&type=1&rankingSectionId=102&rankingSeq=4
# 이영학 "망치로 개 6마리 죽여"…딸 상습폭행은 부인
# ["이슈 · '어금니 아빠' 살인사건", '이영학', '망치', '집으로']
# ['혐의', '재판', '이영학', '이양', '기소', '폭행', '상습 폭행', '상습', '유인', '서울']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=003&aid=0008337507&date=20171212&type=1&rankingSectionId=102&rankingSeq=3
# 서울역 도심공항터미널서 탄창 6개 적발…경찰 긴급출동
# ['서울역', '여객기', '아시아나항공']
# ['탄창', '공항철도', '경찰', '병사', '발견', '적발', '일본', '수하물', '도심공항터미널', '서울역']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=001&aid=0009743859&date=20171212&type=1&rankingSectionId=104&rankingSeq=22
# 美 맨해튼 테러, '원시적 파이프 폭탄'…"부분 폭발에 그쳐"
# ['테러', '맨해튼', '폭발물']
# ['용의자', '테러', '울라', '폭발물', '폭발', '쿠오모', '가능', '미국', '영감', '세력']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=005&aid=0001055058&date=20171212&type=1&rankingSectionId=102&rankingSeq=2
# [집과 삶, 그리고 주거권] “돈 모으는 건 포기했어요” 옥탑방 청년의 집 이야기
# ["이슈 · '주거복지로드맵' 발표", '주거비', '월세', '주거복지']
# ['정책', '주거', '준현', '옥탑방', '주거비', '청년', '월세', '생활', '투자자', '소리']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=001&aid=0009745327&date=20171212&type=1&rankingSectionId=101&rankingSeq=26
# 비트코인 선물 데뷔전 "기대 이상"…가격불안·거래지연은 여전
# ['이슈 · 가상화폐 광풍', '비트코인', '가상화폐', '선물거래']
# ['비트코인', '가상화폐', '가격', '선물거래', '다고', '미국', '거래', 'CBOE', '비트코인 가격', '보도']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=020&aid=0003114349&date=20171212&type=1&rankingSectionId=101&rankingSeq=24
# 이틀새 반토막 출렁, 가슴 철렁… 등락 이유 모른채 “가즈아∼”
# ['이슈 · 가상화폐 광풍', '가상화폐', '비트코인', '이더리움']
# ['가격', '비트코인', '가상화폐', '투자', '시작', '코인', '전화', '휴대', '휴대 전화', '비트코인 가격']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=001&aid=0009745130&date=20171212&type=1&rankingSectionId=101&rankingSeq=16
# 돌고도는 보이스피싱 수법…"네 아이 납치했다" 또 늘어
# ['보이스피싱', '금융감독원', '방송통신위원회']
# ['납치', '금감원', '자녀', '보이스피싱', '금융', '부모', '납치 빙자', '빙자', '상황', '소리']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=437&aid=0000169789&date=20171212&type=2&rankingSectionId=101&rankingSeq=12
# 위장이혼한 부인 집에 금괴…소파 뜯자 수표뭉치 '우수수'
# ['체납자', '국세청', '배우자']
# ['이혼', '수표', '세금', '체납자', '금고', '배우자', '금괴', '위장 이혼', '위장', '국세청']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=421&aid=0003094746&date=20171212&type=1&rankingSectionId=101&rankingSeq=9
# 왜 비트코인 선물가격이 현물보다 13%나 높을까?
# ['이슈 · 가상화폐 광풍', '비트코인', '선물시장', 'etf']
# ['비트코인', '선물', '비트코인 선물', '선물 시장', '보다', '현물', '시장', '전문가', '가격', '상승']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=008&aid=0003977306&date=20171212&type=1&rankingSectionId=101&rankingSeq=6
# [단독]정부, 비트코인 거래 원칙적 금지… 조건부 허용 추진
# ['이슈 · 가상화폐 광풍', '비트코인', '실명확인', '보좌관회의']
# ['정부', '거래', '행위', '금지', '가상통화', '유사수신행위', '조건', '가상통화 거래', '통화', '마련']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=025&aid=0002780405&date=20171212&type=1&rankingSectionId=101&rankingSeq=5
# 은행 가계대출 ‘파이프라인’ 더 잠근다
# ['가계대출', '기업대출', '주택담보대출']
# ['은행', '가계대출', '정부', '자본', 'LTV', '기업대출', '자본규제', '규제', '대출', '비율']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=001&aid=0009745201&date=20171212&type=1&rankingSectionId=101&rankingSeq=4
# "나도 한 번 해볼까" '묻지마 투자'에 가상화폐 시장 '아수라장'
# ['이슈 · 가상화폐 광풍', '가상화폐', '비트코인', '환치기']
# ['가상화폐', '비트코인', '학생', '투자', '뉴스', '규제', '범죄', '가상화폐 시장', '시장', '거래']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=023&aid=0003336968&date=20171212&type=1&rankingSectionId=101&rankingSeq=2
# 200만명 뛰어든 '거대한 투기판'
# ['제주', '울산시', '대구']
# ['가상', '화폐', '가상 화폐', '비트코인', '거래', '거품', '시장', '네티즌', '제도', '선물']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=003&aid=0008336872&date=20171212&type=1&rankingSectionId=100&rankingSeq=29
# [종합]장시호, 실형 후 첫 법정서 눈물…'최순실 혐의' 증언
# ['영재센터', '최순실', 'ebs']
# ['영재센터', '후원', '증언', '영재센터 후원', '특검', '최순실', '영재센터 자금', '자금', '국정농단', '공판']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=001&aid=0009744821&date=20171212&type=1&rankingSectionId=100&rankingSeq=25
# 통합파는 부산, 반대파는 광주…제 갈길 가는 국민의당
# ['부산시', '통합파', '통합']
# ['통합', '대표', '평화개혁연대', '모임', '안철수', '연대', '반대파', '의원', '국민의당', '행사']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=001&aid=0009746291&date=20171212&type=1&rankingSectionId=100&rankingSeq=23
# 한국당 '친홍체제' 강화…새 원내사령탑 김성태 앞에 과제 산적
# ['김성태', '한국당', '친홍']
# ['의원', '원내대표', '한국당', '선거', '원내', '정부', '대표', '홍준표', '당내', '수사']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=437&aid=0000169876&date=20171212&type=2&rankingSectionId=100&rankingSeq=22
# 한국당 새 원내대표에 '친홍' 김성태…당 개혁 속도 전망
# ['김성태', '한국당', '친홍']
# ['의원', '홍준표', '대표', '원내대표', '친박계', '홍준표 대표', '목소리', '김성태', '친홍', '속도']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=001&aid=0009744743&date=20171212&type=1&rankingSectionId=100&rankingSeq=18
# 한중 정상회담 후 '공동언론발표' 아닌 '언론발표'
# ['한중정상회담', '사드', '정상회담']
# ['양국', '청와대', '발표', '형식', '언론발표', '내용', '별도', '양국 별도', '진행', '한국']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=437&aid=0000169779&date=20171212&type=2&rankingSectionId=100&rankingSeq=17
# [단독] '박근혜 특활비 상납' 시작에 최경환 관여 정황
# ['최경환', '박근혜', '국가정보원']
# ['의원', '상납', '특활비', '특활비 상납', '대통령', '국정원', '정황', '으로부터', '박근혜', '의원 국정원']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=001&aid=0009745481&date=20171212&type=1&rankingSectionId=100&rankingSeq=12
# 외교부 "네팔서 한국민의 대리모 출산사례 있어…동향 주시"
# ['외교부', '출산', '대변인']
# ['출산', '대리모 출산', '대변인', '대리모', '국민', '해당', '외교부', '파악', '노규덕', '불법']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=001&aid=0009744844&date=20171212&type=1&rankingSectionId=102&rankingSeq=27
# '어금니 아빠' 이영학 범행 도운 딸, 정신감정 받는다
# ['이영학', '어금니아빠', '이성호']
# ['이영학', '지시', '혐의', '재판', '범행', '확인', '저항', '는지', '재판부', '도피']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=001&aid=0009746201&date=20171212&type=1&rankingSectionId=100&rankingSeq=11
# 한국당 새 원내대표에 '친홍' 김성태…"문재인 정권과 싸우겠다"
# ['문재인', '김성태', '친홍']
# ['원내대표', '의원', '대표', '선출', '신임', '김성태', '야당', '홍준표 대표', '홍준표', '55표']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=079&aid=0003043748&date=20171212&type=1&rankingSectionId=100&rankingSeq=6
# 방중 앞둔 文 무거운 발걸음…사드·북핵·평창 쉬운 게 없다
# ['이슈 · 문 대통령 중국 국빈 방문', '사드', '북핵', '방중']
# ['대통령', '중국', '북한', '회담', '정상', '정상 회담', '사드', '정부', '중단', '북핵']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=008&aid=0003977308&date=20171212&type=1&rankingSectionId=100&rankingSeq=1
# 조원진, 문재인 대통령에 '문재인씨' 호칭 논란
# ['문재인', '조원진', '한미동맹']
# ['대통령', '문재인', '대표', '정부', '지칭', '호칭', '한미동맹', '개월', '안보', '대통령 문재인']
#
# http://sports.news.naver.com/sports/index.nhn?ctg=ranking_news&mod=read&ranking_type=popular_day&date=20171211&office_id=382&article_id=0000612771
# ‘홈런왕’ 스탠튼, 뉴욕 양키스 공식 입단… 신체검사 통과
# ['지안카를로 스탠튼']
# ['스탠튼', '뉴욕', '스탠튼 뉴욕', '양키스', '스탠튼 뉴욕 양키스', '뉴욕 양키스', '동아닷컴', '확정', '신체 검사 통과', '신체']
#
# http://sports.news.naver.com/sports/index.nhn?ctg=ranking_news&mod=read&ranking_type=popular_day&date=20171211&office_id=459&article_id=0000000282
# [홍기자의 아웃사이더] 입단 1년차 KIA 박정우 현역 입대,' 강해져 돌아오겠다'
# NaN
# ['야구', '웃음', '군대', '더라', '다고', '정도', '박정우', '선배', '많이', '프로']
#
# http://sports.news.naver.com/sports/index.nhn?ctg=ranking_news&mod=read&ranking_type=popular_day&date=20171211&office_id=109&article_id=0003678341
# 애타는 허들 감독, “강정호와 연락해 보겠다”
# ['강정호', '클린트 허들']
# ['강정호', '허들', '감독', '피츠버그', '허들 감독', '비자', '감독 강정호', '오프시즌', 'MLB', '프랭크 쿠넬리 사장']
#
# http://sports.news.naver.com/sports/index.nhn?ctg=ranking_news&mod=read&ranking_type=popular_day&date=20171211&office_id=477&article_id=0000102341
# 니퍼트 대신 린드블럼? 직구 회전수는 답 알고 있다
# ['더스틴 니퍼트', '조쉬 린드블럼']
# ['니퍼트', '린드블럼', '회전수', '두산', '자책점', '평균', '평균 자책점', 'rpm', '기록', '점차']
#
# http://sports.news.naver.com/sports/index.nhn?ctg=ranking_news&mod=read&ranking_type=popular_day&date=20171211&office_id=468&article_id=0000329800
# [동아시안컵]신태용의 반론 "중국전 내용 완벽, 북한전은 결과도 얻겠다"
# NaN
# ['완벽', '결과', '북한', '생각', '중국', '한다', '도쿄', '대처', '일본 도쿄', '일본']
#
# http://sports.news.naver.com/sports/index.nhn?ctg=ranking_news&mod=read&ranking_type=popular_day&date=20171211&office_id=108&article_id=0002666337
# [KBO 윈터미팅] TEX 관계자 "추신수 연봉, 내년 예산에 반영"
# NaN
# ['추신수', '텍사스', '참석', '구단', '연봉', '추신수 연봉', '윈터미팅', '투수', '양재 박수진', '양재']
#
# http://sports.news.naver.com/sports/index.nhn?ctg=ranking_news&mod=read&ranking_type=popular_day&date=20171211&office_id=001&article_id=0009742388
# 린드블럼 "롯데 구단 언론플레이, 정도 지나쳤다"
# ['조쉬 린드블럼']
# ['린드블럼', '롯데', '구단', '롯데 구단', '건강', '주장', '협상', '언론', '계약', '평균자책점']
#
# http://sports.news.naver.com/sports/index.nhn?ctg=ranking_news&mod=read&ranking_type=popular_day&date=20171211&office_id=343&article_id=0000077727
#  쿠르투와, 가정사 이유로 첼시와 결별 확정
# ['티보 쿠르투아']
# ['쿠르투와', '첼시', '이유', '계약', '떠나', '보도', '쿠르투와 첼시', '다는', '스페인', '아틀레티코 마드리드']
#
# http://sports.news.naver.com/sports/index.nhn?ctg=ranking_news&mod=read&ranking_type=popular_day&date=20171211&office_id=343&article_id=0000077720
#  [이주의 EPL-16R] 맨시티, 어쩌면 EPL 역사상 최강의 팀
# NaN
# ['경기', '시티', '전반', '맨체스터', '득점', '후반', '기록', '맨체스터 시티', '아스널', '승리']
#
# http://sports.news.naver.com/sports/index.nhn?ctg=ranking_news&mod=read&ranking_type=popular_day&date=20171211&office_id=144&article_id=0000527108
# 양현종, KIA와 큰틀은 합의…잔류 확정 초읽기?
# ['양현종']
# ['양현종', 'KIA', '계약', '협상', '구단', '연봉', '단계', '계약금', '규모', '결정']
#
# http://sports.news.naver.com/sports/index.nhn?ctg=ranking_news&mod=read&ranking_type=popular_day&date=20171211&office_id=413&article_id=0000059189
# [맨더비 리뷰] '최강' 맨시티, 맨유 2-1 꺾고 'EPL 14연승 신기록'
# NaN
# ['맨유', '슈팅', '맨시티', '후반', '시티', '래쉬포드', '로호', '오타멘디', '전반', '실바']
#
# http://sports.news.naver.com/sports/index.nhn?ctg=ranking_news&mod=read&ranking_type=popular_day&date=20171211&office_id=076&article_id=0003190816
# 린드블럼 SNS 폭로, 롯데 "딸 문제로 얘기한 적 없다"
# ['조쉬 린드블럼']
# ['롯데', '린드블럼', '구단', '협상', '언론', '건강', '다는', '문제', 'SNS', '인사']
#
# http://sports.news.naver.com/sports/index.nhn?ctg=ranking_news&mod=read&ranking_type=popular_day&date=20171211&office_id=396&article_id=0000466204
# [SW직격인터뷰] 한화 박종훈 단장 "FA 정근우? 용병타자? 걱정 안한다"
# NaN
# ['단장', '타자', '외국인', '한화', '외국인 타자', '정근우', '박종훈', '차이', 'FA', '박정진']
#
# http://sports.news.naver.com/sports/index.nhn?ctg=ranking_news&mod=read&ranking_type=popular_day&date=20171211&office_id=413&article_id=0000059255
# [UCL 대진] 챔스 16강 대진 확정...토트넘vs유베, PSGvs레알 성사
# NaN
# ['16강', '레알', '16강 대진', '대진', '챔피언스리그', '토트넘', '바르셀로나', '첼시', '챔피언스리그 16강', '바이에른 뮌헨']
#
# http://sports.news.naver.com/sports/index.nhn?ctg=ranking_news&mod=read&ranking_type=popular_day&date=20171211&office_id=108&article_id=0002666349
# [오피셜] 두산, '前롯데' 린드블럼 145만$ 영입 발표..'니퍼트와 결별'
# NaN
# ['린드블럼', '두산', '평균', '평균 자책점', '자책점', '달러 계약', '계약', '총액', '발표', '영입']
#
# http://entertain.naver.com/ranking/read?oid=382&aid=0000612706
# [DAY컷] ‘화유기’ 윤보라, 씨스타 해체→배우 변신 괜찮을까
# ['씨스타', '해체', '차승원', '고대소설', '서유기']
# ['섹시', '스타', '섹시 스타', '윤보라', '앨리스', '화유기', '섹시 스타 앨리스', '스타 앨리스', '촬영', '활동']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=366&aid=0000392282&date=20171212&type=1&rankingSectionId=101&rankingSeq=28
# 정부, 가상화폐 규제 놓고 고민…전면금지對예외허용
# ['가상화폐', '금융위', '법무부']
# ['가상화폐', '거래', '가상화폐 거래', '정부', '규제', '금지', '거래소', '마련', '규제안', '가상화폐 규제']
#
# http://entertain.naver.com/ranking/read?oid=241&aid=0002736446
# [단독] 조용필, 내년 데뷔 50주년 기념 잠실 주경기장서 단독 콘서트
# ['조용필', '음악', '콘서트', '가요시상식', '골든디스크시상식']
# ['조용필', '콘서트', '데뷔', '주년', '음악', '국내', '인기', '가요', '단독', '주경기장']
#
# http://entertain.naver.com/ranking/read?oid=112&aid=0002983249
# [어게인TV]"랩→보컬"…'복면가왕' 전지윤X최유정, 모두가 놀란 실력
# NaN
# ['최유정', '모습', '전지윤', '보컬', '복면가왕', '보여', '실력', '판정단', '많이', '등장']
#
# http://entertain.naver.com/ranking/read?oid=076&aid=0003190840
# [SC초점] '그사이' 이준호의 첫 주연, '김과장' 잇는 '신의한수' 될까
# ['이준호', '김과장', '신의한수', '먹방', '아이돌']
# ['연기', '이준호', '사랑', '배우', '드라마', '주연', '도움', '만들', '많이', '인생']
#
# http://entertain.naver.com/ranking/read?oid=213&aid=0001005574
# ‘막영애16’ 김현숙 인생 2막, 노처녀→워킹맘 고충 나눈다
# ['인생2막', '노처녀', '워킹맘', '임신', '사랑과이별']
# ['영애', '임신', '이야기', '인생', '결혼', '공감', '이미지', '이미지 원본', '원본', '영애 임신']
#
# http://entertain.naver.com/ranking/read?oid=144&aid=0000527111
# [간밤TV] ‘문남’ 라이언 전, 치킨 사업가에서 대박 작곡가 되기까지(종합)
# ['라이언', '치킨', '대박', '옹성우', '눈길']
# ['라이언', '작곡', '작곡가', '아버지', '프로듀스', '즌2', '이어', '전이', '라이언 전이', '밝혔']
#
# http://entertain.naver.com/ranking/read?oid=109&aid=0003678623
# [단독] 워너원 윤지성, 동국대 영상대학원 합격…새내기 된다
# ['워너원', '동국대', '음악시상식', '프로듀스101', '연극영화과']
# ['워너원', '대학원', '윤지', '윤지성', '워너원 윤지성', '대학원 입학', '영상 대학원', '합격', '영상', '새내기']
#
# http://entertain.naver.com/ranking/read?oid=109&aid=0003678380
# [최고의 TV] "공감에 오열"..'세상에서', 안방 울린 원미경 수술포기
# ['원미경', '유동근', '수술실', '시어머니', '며느리']
# ['정철', '수술', '포기', '유동근', '원미경', '수술실', '암세포', '정박사', '수술 포기', '세상']
#
# http://entertain.naver.com/ranking/read?oid=109&aid=0003678698
# 유재석, 6년연속 올해의 개그맨..박나래 女유일 순위권
# ['유재석', '무한도전', '박나래', '개그맨', '해피투게더시즌3']
# ['개그맨', '유재석', '이름', '차지', '출연', '코미디언', '코미디언 개그맨', 'tvN', '활약', '토크쇼']
#
# http://entertain.naver.com/ranking/read?oid=421&aid=0003092825
# "정치색 無 군납비리 실화"…김상경X김옥빈이 폭로한 '1급기밀' [종합]
# ['김옥빈', '실화', '홍기선', '김상경', '최귀화']
# ['영화', '감독', '1급기밀', '생각', '김상경', '김옥빈', '홍기선', '홍기선 감독', '사회', '실화']
#
# http://entertain.naver.com/ranking/read?oid=022&aid=0003232246
# 웬만한 중소기업 수준라는 '아이유' 스태프 규모
# ['스태프', '인스타그램', '매니저', '가수']
# ['아이유', '사진', '공개', '야유회', '아이유 야유회', '이미지', '원본', '이미지 원본', '사진 아이유', '규모']
#
# http://entertain.naver.com/ranking/read?oid=109&aid=0003678375
# [최고의 TV] “올해 최고”..‘황금빛’, 꿈 아닌 현실된 시청률 40%
# ['황금빛내인생', '시청률', '유인영', '신혜선', '박시후']
# ['시청', '황금빛', '방송', '기록', '황금빛 인생', '인생', '돌파', '40', '시청자', '시청 40']
#
# http://entertain.naver.com/ranking/read?oid=241&aid=0002736520
# [이슈IS] '황금빛' CP "40% 돌파 감사…끝까지 재미있게 풀어나갈 것"
# ['감사', '황금빛내인생', '닐슨코리아', '대박', '시청률']
# ['황금빛', '돌파', '40 돌파', '40', '인생', '황금빛 인생', '시청', 'CP', '시청 40', '시청 40 돌파']
#
# http://entertain.naver.com/ranking/read?oid=076&aid=0003190607
# "몸만 오면 돼"…'미우새' 아들의 결혼, 간절한 母벤져스 [종합]
# ['박수홍', '빽가', '박경림', '김건모', '결혼']
# ['박수홍', '결혼', '어머니', '김건모', '박경림', '절친', '모습', '축하', '빽가', '표정']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=008&aid=0003977150&date=20171211&type=0&rankingSectionId=105&rankingSeq=30
# 통신비協, 法보단 시장자율 '가닥'…단말기자급제 입법화 '찬물'
# ['단말기자급제', '통신비', '알뜰폰']
# ['완전자급제', '논의', '단말기', '자급', '국회', '협의', '정책협의회', '결과', '입법화', '소비자']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=014&aid=0003922389&date=20171211&type=1&rankingSectionId=105&rankingSeq=29
# 초고가 스마트폰, 소비자 선택 받을까
# ['스마트폰', '아이폰x', '아이폰']
# ['스마트폰', '출시', '내장메모리', 'GB', '아이폰', '제품', '판매', '최대', '업계', '고가']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=030&aid=0002665593&date=20171211&type=1&rankingSectionId=105&rankingSeq=26
# 삼성전자, 세계 기업 R&D 투자 4위로 밀려...톱 10 중 유이한 마이너스
# ['삼성전자', '회계연도', '유럽연합']
# ['기업', '삼성전자', '투자', '미국', '중국', '순위', '기록', '기업 투자', '유로', '증가']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=029&aid=0002437349&date=20171211&type=1&rankingSectionId=105&rankingSeq=24
# 암세포장벽 분해 나노물질 개발 … KIST, 김인산·양유수 연구팀
# ['암세포', '임상시험', '단백질']
# ['개발', '엑소', '히알루로니다아제', '분해', '양유수', '연구', '효소', '박사', '김인산', '세포외기질 분해']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=138&aid=0002057227&date=20171211&type=1&rankingSectionId=105&rankingSeq=23
# 갤럭시S9에 샌디스크 UFS 적용될 듯…퀄컴이 ‘점찍었다’
# NaN
# ['샌디스크', '낸드플래시', 'UFS', '퀄컴', '공급', '제품', '갤럭시', '국내', '낸드', '삼성전자']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=001&aid=0009742554&date=20171211&type=1&rankingSectionId=105&rankingSeq=22
# LG G7, 홍채인식 탑재할까…LG전자, 관련 특허 출원
# ['lg전자', 'lg', '스마트폰']
# ['홍채인식', '인식', '홍채', '홍채 인식', '스마트폰', '탑재', '사용', 'LG', '렛츠고 디지털', '디지털']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=437&aid=0000169704&date=20171211&type=2&rankingSectionId=105&rankingSeq=21
# 축구장 2개 넓이를 10분 만에…'드론' 띄워 AI 잡는다
# ['드론', 'ai', 'ai바이러스']
# ['드론', '방역', 'AI', '10', '농가', '효과', '소독', '대형', '대형 드론', '닭오리']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=022&aid=0003232613&date=20171211&type=1&rankingSectionId=105&rankingSeq=19
# "비트코인에 눈독 들이는 北…내년 거래소 해킹 가능성"
# ['이슈 · 가상화폐 광풍', '비트코인', '해킹', '가상화폐']
# ['공격', '거래소', '랜섬웨어', '사이버', '가상화폐', '전망', '가상화폐 거래소', '테러', '시스템', '비트코인']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=055&aid=0000593383&date=20171211&type=2&rankingSectionId=105&rankingSeq=14
# [단독] 몰라서 못 쓴 통신사 마일리지, 내년부터 통신비 결제
# ['마일리지', '통신비', '스마트폰']
# ['마일리지', '통신사', '고객', '소멸', '서비스', '적립', '사용', '통신', '결제', '자동']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=014&aid=0003921601&date=20171211&type=1&rankingSectionId=105&rankingSeq=10
# 역대급 512GB 장착한 갤럭시S9 나온다
# ['갤럭시s9', '삼성전자', '퀄컴']
# ['삼성전자', '갤럭시', '512 GB', '512', 'GB', '스냅드래곤', '최대', '탑재', '스마트폰', '업계']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=001&aid=0009741478&date=20171211&type=1&rankingSectionId=105&rankingSeq=9
# 韓 2021년에도 인터넷이용률 아태 1위…스마트폰이용률은 6위
# ['스마트폰', '인터넷', '대만']
# ['인터넷', '한국', '이마케터', '이용자', '이용', '아태지역', '2021년', '전망', '스마트폰', '인터넷 이용자']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=023&aid=0003336548&date=20171211&type=0&rankingSectionId=105&rankingSeq=8
# 한계 다다른 실리콘 반도체… 전자산업의 쌀도 곧 '그래핀 시대'
# ['반도체', '쌀', '바로']
# ['반도체', '실리콘', '그래핀', '입니다', '소재', '흑린', '전기', '성질', '사용', '부도체 성질']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=023&aid=0003336547&date=20171211&type=1&rankingSectionId=105&rankingSeq=7
# 휘어지는 화면·5배 빠른 충전… '꿈의 소재' 그래핀, 일상속으로
# ['배터리', '자동차', '디스플레이']
# ['그래핀', '소재', '입니다', '그래핀 플레이크', '플레이크', '중국', '배터리', '세계', '연구', '상용화']
#
# http://entertain.naver.com/ranking/read?oid=213&aid=0001005760
# '막영애16' CP "영애 결혼 장미빛 NO, 현실 그릴 것" [인터뷰]
# ['결혼', '막돼먹은영애씨', 'tvn', '인터뷰']
# ['영애', '공감', '결혼', '현실', '막영애', '애정', '의도', '장미빛', 'CP', '밝혔']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=293&aid=0000021130&date=20171211&type=1&rankingSectionId=105&rankingSeq=5
# [ICT2017] '아이폰' 10년, 분기점에 서다
# NaN
# ['애플', '아이폰', '인식', '홈버튼', '제품', '카메라', '아이폰8', '11', '스피커', '탑재']
#
# http://entertain.naver.com/ranking/read?oid=109&aid=0003678984
# [최고의 TV] "왜 상무님이 거기서 나와?" '저글러스', 시트콤보다 웃겨
# ['최다니엘', '백진희', '김정현', '눈길', '집으로']
# ['저글러스', '시트콤', '방송', '연필', '비서', '최다니엘', '최다니엘 백진희', '백진희', 'TV', '세입자']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=001&aid=0009741888&date=20171211&type=1&rankingSectionId=105&rankingSeq=4
# "돈줄 막힌 北, 비트코인 거래소 해킹 노린다" 전문가 경고
# ['이슈 · 가상화폐 광풍', '비트코인', '해킹', '가상화폐']
# ['비트코인', '공격', '북한', '해킹', '거래소', '사이버', '해커', '은행', '비트코인 거래소', '사이버 공격']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=001&aid=0009742969&date=20171211&type=1&rankingSectionId=105&rankingSeq=3
# 한국 LTE 속도 세계에서 가장 빠르다…"뉴욕의 4배"
# ['lte', '뉴욕', '다운로드']
# ['조사', '결과', '품질', '속도', '도시', 'Mbps', '서비스', '주요', '품질 조사', '한국']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=001&aid=0009743002&date=20171211&type=1&rankingSectionId=104&rankingSeq=30
# 카타르, 8조7천억원어치 英전투기 24대 구입하기로
# ['이슈 · 카타르-아랍국 단교', '카타르', '전투기', '수니파']
# ['카타르', '전투기', '영국', '계약', '타이푼', '윌리엄슨', '타이푼 전투기', '로이터통신', '천억', '윌리엄슨 장관']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=448&aid=0000229781&date=20171211&type=1&rankingSectionId=104&rankingSeq=29
# 중조우의교 오늘 전격 폐쇄…北 길들이기 나선 中
# NaN
# ['중국', '북한', '폐쇄', '수리', '현지', '입니다', '무역', '북중', '분석', '오늘']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=277&aid=0004137521&date=20171211&type=1&rankingSectionId=104&rankingSeq=27
# [흔들리는 북중관계]①폐쇄·단교·개통연기…北中 잇는 다리의 세 모습
# ['단교', '단둥', '신의주']
# ['다리', '북한', '중국', '압록강', '대교', '압록강 대교', '폐쇄', '신의주', '단둥', '압록강철교']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=001&aid=0009741425&date=20171211&type=1&rankingSectionId=104&rankingSeq=20
# "자기보존 위한 실시간 전투"…NYT '트럼프 백악관' 조명(종합)
# ["이슈 · 트럼프 '러시아 스캔들'", '트럼프', '백악관', '켈리']
# ['트럼프 대통령', '트럼프', '대통령', '켈리', '켈리 실장', '통제', '실장', '백악관', '트윗', 'NYT']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=055&aid=0000593675&date=20171211&type=2&rankingSectionId=104&rankingSeq=17
# 북중 철교 폐쇄 이유 알고보니…중국 압박 아니었다
# ['단둥', '보수공사', '화물차']
# ['북한', '중국', '철교', '단둥', '폐쇄', '입니다', '중국 당국', '경고', '당국', '오늘']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=025&aid=0002780290&date=20171211&type=1&rankingSectionId=104&rankingSeq=14
# 말로는 ‘예루살렘 항의’…계산기 두드리는 중동 맹주들
# ['예루살렘', '이스라엘', '트럼프']
# ['이스라엘', '예루살렘', '팔레스타인', '트럼프', '국가', '이란', '선언', '하마스', '예루살렘 선언', '사우디']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=023&aid=0003336620&date=20171211&type=1&rankingSectionId=104&rankingSeq=13
# "美 군사옵션보다 압박이 우선… 北 금지선 넘으면 선제타격"
# ['선제타격', '트럼프', '제임스매티스']
# ['트럼프', '미국', '의장', '깅리치', '북한', '금지선', '압박', '선제공격', '트럼프 행정부', '행정부']
#
# http://sports.news.naver.com/sports/index.nhn?ctg=ranking_news&mod=read&ranking_type=popular_day&date=20171211&office_id=216&article_id=0000092228
# 우승 경쟁 끝났냐 질문에 무리뉴 “아마도”
# ['조세 무링요']
# ['맨시티', '감독', '무리뉴', '무리뉴 감독', '프리미어리그', '우승', '11', '우승 경쟁', '경쟁', '생각']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=001&aid=0009741769&date=20171211&type=1&rankingSectionId=104&rankingSeq=11
# 아시아 최고목탑, 쓰촨지진탓 파손 복구후 이번엔 불…전체 소실
# ['화재', '명나라', '불교']
# ['영관', '목탑', '건립', '파손', '구룡사', '중국', '화재', '소실', '명나라', '중건']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=081&aid=0002876343&date=20171211&type=1&rankingSectionId=104&rankingSeq=7
# 뉴턴이 350여년 전 생가에 남긴 그림 발견
# ['바로', '영국', '그림자']
# ['뉴턴', '그림', '소프', '뉴스', '영국', '그림 발견', '발견', 'RTI', '시절', '소프 매너']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=001&aid=0009741939&date=20171211&type=1&rankingSectionId=104&rankingSeq=6
# 노벨평화상 수상자 "자칫 짜증 한번에 핵전쟁" 북미긴장 우려
# ['핵전쟁', '핵무기', 'bbc방송']
# ['사무총장', '미국', '북한', '위원장', '핵무기', '핵전쟁', '연설', '대통령', '트럼프', '노벨평화상']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=001&aid=0009743080&date=20171211&type=1&rankingSectionId=104&rankingSeq=4
# "다르다고 비난하면 안되잖아요"…美서 왕따소년 동영상 '반향'
# ['페이스북', '왕따', '트위터']
# ['소년', '영상', '어머니', '눈물', '괴로움', '트위터', '캡처', '친구', '동영상', '성원']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=421&aid=0003093014&date=20171211&type=1&rankingSectionId=104&rankingSeq=2
# "한국산 무기수출 20% 늘어…증가율 세계 최고수준"
# ['kai', '국방비', '핵무기']
# ['한국', '무기', 'SIPRI', '세계', '통신', '100', '베제', '연구원', '전년', '보고서']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=081&aid=0002876350&date=20171211&type=1&rankingSectionId=104&rankingSeq=1
# 예비 신랑신부, 알고 보니 10년 전 ‘포토밤’ 주인공
# ['런던', '네티즌', '남자친구']
# ['가족', '사진', '부자', '네티즌', '몬테네그로', '여행', '코리', '주인공', '나우', '뉴스']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=001&aid=0009743248&date=20171211&type=1&rankingSectionId=103&rankingSeq=29
# 경기북부 올겨울 첫 한파경보…체감온도 더 낮아 최강추위
# ['한파경보', '경기북부', '체감온도']
# ['영하', '기온', '추위', '11', '최저기온', '동파', '떨어지', '기상청', '연천', '파주']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=001&aid=0009743230&date=20171211&type=1&rankingSectionId=103&rankingSeq=27
# 제주 유네스코 무형유산위 종료…獨 오르간 음악 등 유산 등재
# ['유네스코', '제주', '문화재청']
# ['등재', '회의', '보호', '목록', '긴급', '대표 목록', '긴급 보호 목록', '보호 목록', '긴급 보호', '대표']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=023&aid=0003336552&date=20171211&type=1&rankingSectionId=103&rankingSeq=25
# 흩어져 달리는 선수들 중, 한국 대표만 콕 찍어 경기 볼 수 있다
# ['5g', '평창', 'vr']
# ['영상', '카메라', '중계', '위치', '평창', '경기', '실시간', '제공', '올림픽', '장치']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=052&aid=0001092927&date=20171211&type=2&rankingSectionId=103&rankingSeq=23
# [날씨] 중부에 첫 한파경보..."북극 한기 몰려왔다"
# ['한파경보', '한파', '한반도']
# ['한기', '한파', '영하', '북극', '입니다', '기온', '안팎', '예보', '15도', '전망']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=214&aid=0000791977&date=20171211&type=2&rankingSectionId=103&rankingSeq=19
# [날씨] 다시 강추위 몰려온다…호남엔 '대설특보'
# ['대설특보', '강추위', '서해안']
# ['호남', '영하', '기온', '서울', '오늘', '지역', '고요', '발효', '최고', '가량']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=469&aid=0000260673&date=20171211&type=1&rankingSectionId=103&rankingSeq=18
# ‘저지방의 역설’ 지방 적게 먹으면 대사증후군 위험
# ['대사증후군', '탄수화물', '고지혈증']
# ['대사증후군', '지방', '탄수화물', '섭취', '탄수화물 섭취', '여성', '위험도', '대사증후군 위험도', '지방 섭취', '연구']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=052&aid=0001092718&date=20171211&type=2&rankingSectionId=103&rankingSeq=17
# [날씨] 칼바람에 영하권 추위 계속...서해안 폭설
# ['서해안', '영하권', '폭설']
# ['바람', '서해안', '영하', '기온', '서울', '10도', '영하 10도', '호남', '는데요', '내일']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=296&aid=0000033968&date=20171211&type=1&rankingSectionId=103&rankingSeq=16
# 술 마신 뒤 먹지 말아야 할 5가지
# ['알코올', '카페인', '근육']
# ['음식', '마신', '성분', '사탕', '마시', '토마토소스', '알코올', '위장', '위장 장애', '장애']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=052&aid=0001092654&date=20171211&type=2&rankingSectionId=103&rankingSeq=15
# [날씨] 낮에도 영하권 추위...호남 서해안 폭설
# ['영하권', '서해안', '폭설']
# ['기온', '서울', '고요', '보이', '아침', '오늘', '서해안', '한파', '12도', '는데요']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=022&aid=0003232969&date=20171211&type=1&rankingSectionId=103&rankingSeq=12
# '살을 에는 추위' 예고…12일 체감온도 '-20도'
# ['체감온도', '출근길', '강추위']
# ['영하', '추위', '체감온도', '10도', '영하 10도', '최저기온', '서울', '바람', '떨어지', '11']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=028&aid=0002390375&date=20171211&type=1&rankingSectionId=103&rankingSeq=10
#  “나는 멍청한 번역가일뿐…모든 디자인은 자연에 물어라”
# ['자동차', '돌고래', '제시']
# ['콜라', '작품', '곡률', '디자인', '하디드', '자연', '루이지', '디디피', '작업', '전시']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=346&aid=0000018609&date=20171211&type=1&rankingSectionId=103&rankingSeq=9
# 속 더부룩할 때 무·매실·양배추를 먹어야 하는 이유
# ['위암', '탄수화물', '알코올']
# ['매실', '양배추', '소화', '위장', '효과', '으면', '도움', '풍부', '보호', '된다']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=052&aid=0001092811&date=20171211&type=2&rankingSectionId=103&rankingSeq=8
# [날씨] 올겨울 첫 한파경보...내일 동장군 맹위, 서울 -12℃
# NaN
# ['서울', '영하', '기온', '올겨울', '보이', '한파주의보', '추위', '내일', '한파', '서울 한파주의보']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=056&aid=0010527695&date=20171211&type=2&rankingSectionId=103&rankingSeq=7
# 찬 바람에 기온 뚝…내일, 올겨울 들어 제일 추워
# ['전라도', '서해안', '대설특보']
# ['영하', '서울', '전라도', '오늘', '기온', '내일', '서울 영하', '서해안', '영하 9도', '9도']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=001&aid=0009742321&date=20171211&type=1&rankingSectionId=103&rankingSeq=6
# '정체' 저기압, 찬 공기 불어넣어…맹추위 이번 주 지속
# ['체감온도', '강원', '기상청']
# ['서울', '기상청', '체감온도', '기온', '11', '7도', '저기압', '정체', '고기압', '강원']
#
# ...
# 중국-호주 갈등 악화일로 ..무역 보복으로 확산되나
# ['호주', '턴불', '로비스트']
# ['호주', '중국', '턴불', '총리', '턴불 총리', '중국 호주', '관계', '갈등', '제기', '양국']
#
# http://entertain.naver.com/ranking/read?oid=109&aid=0003677550
# [단독] "동화형제 어게인"..정용화, 강호동 토크쇼 '토크몬' 합류
# ['강호동', '정용화', '올리브', '호흡', '강심장']
# ['강호동', '토크', '토크쇼', '정용화', '출연', '섬총사', '예정', '강심장', '이수근', '동화']
#
# http://entertain.naver.com/ranking/read?oid=109&aid=0003677455
# [Oh!쎈 톡] '모두의 연애' PD "호불호 반응 알아..2회부터 더 새로워질 것"
# ['호불호', '변우석', '이시아', '성시경', '박유나']
# ['연애', '방송', '포맷', '생각', '심우경', '을까', '상담', '호불호', '토크', '신개념']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=277&aid=0004136900&date=20171210&type=1&rankingSectionId=105&rankingSeq=23
# 내년 사이버 공격 핵심 키워드는 '랜섬웨어'와 '가상화폐'
# ['이슈 · 가상화폐 광풍', '가상화폐', '사이버공격', '랜섬웨어']
# ['공격', '가상화폐', '사이버', '노린', '랜섬웨어', '전망', '결합', '악성코드', '사이버 공격', '사이버공격']
#
# http://entertain.naver.com/ranking/read?oid=213&aid=0001005362
# [리폿@스타] '아가씨' 충격 이후 1년..'1987' 김태리 증명할 가치
# ['김태리', '아가씨', '박찬욱', '장준환', '김윤석']
# ['김태리', '영화', '아가씨', '1987', '연희', '관객', '캐릭터', '한다', '감정', '대학생']
#
# http://entertain.naver.com/ranking/read?oid=076&aid=0003190242
# "데뷔 첫 충격 비주얼"…'화유기' 이세영, 좀비가 귀여워도 되나요?
# ['이세영', '좀비', '화유기', '월계수양복점신사들', '서유기']
# ['이세영', '소녀', '화유기', '진부', '기억', '좀비', '매력', '만들', '촬영', '매력 가진']
#
# http://entertain.naver.com/ranking/read?oid=109&aid=0003677524
# [Oh! 뮤직] 다음주 가요계, 음원퀸 전쟁..태연vs소유vs트와이스
# ['태연', '윤하', '태민', 'thischristmas', '퍼포먼스']
# ['앨범', '기대', '공개', '한다', '음원퀸', '발표', '감성', '예정', '음악', '트와이스']
#
# http://sports.news.naver.com/sports/index.nhn?ctg=ranking_news&mod=read&ranking_type=popular_day&date=20171209&office_id=410&article_id=0000424927
# 美 언론 "스탠튼, 다저스행 확률 70%, 잔류 가능성 제로"
# NaN
# ['스탠튼', '세인트루이스', '미쉬', '트레이드', '확률', '다고', '이적', '스탠튼 이적', '잔류', '스포츠']
#
# http://entertain.naver.com/ranking/read?oid=076&aid=0003190204
# "리듬체조→발레"..'백조클럽' 은퇴 손연재 '제2막' 도전[종합]
# ['손연재', '리듬체조', '오윤아', '발레리나', '박주미']
# ['발레', '손연재', '리듬체조', '공연', '멤버', '의지', '백조', '클럽', '백조 클럽', '이유']
#
# http://entertain.naver.com/ranking/read?oid=109&aid=0003677445
# [2017 가요결산③] '프로듀스101 시즌2'가 빚어낸 현상
# ['프로듀스101', '황민현', '음반판매량', '뉴이스트', '워너원']
# ['데뷔', '프듀2', '대중', '가요', '뉴이스트', '연습생', '파생', '프로듀스101', '인기', '시즌2']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=003&aid=0008335694&date=20171211&type=1&rankingSectionId=102&rankingSeq=30
# [일문일답]평가원장 "수능만점자 총 15명…재학생 7명"
# ['대학수학능력시험', '수학', '국어']
# ['수능', '발표', '졸업', '평가', '비율', '만점', '등급', '결과', '만점자', '학생']
#
# http://entertain.naver.com/ranking/read?oid=213&aid=0001005338
# [단독] ‘감빵생활’ 박해수, 연인 임강희와 3년 열애 마침표
# ['감빵생활', '마침표', '결별', '육룡이나르샤', '슬기로운감빵생활']
# ['박해수', '임강희', '만남', '박해수 임강희', '연인', '이별', '주변', '결별', '풀잎', '공연']
#
# http://entertain.naver.com/ranking/read?oid=396&aid=0000466053
# [단독] 스윗소로우 성진환, 음악 활동 스톱… "팀 탈퇴·해체 아니다"…①
# NaN
# ['스윗소로우', '멤버', '진환', '성진환', '마음', '사랑', '음악', '활동', '생각', '다는']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=001&aid=0009741203&date=20171210&type=1&rankingSectionId=102&rankingSeq=8
# 경기·강원 폭설…전동차 운행중단·교통사고 속출, 여객선 멈춰
# ['여객선', '교통사고', '전동차']
# ['10', '사고', '강원', '차량', '운행', 'co kr', 'co', 'yna co', 'yna', 'kr']
#
# http://entertain.naver.com/ranking/read?oid=109&aid=0003677460
# [단독] "YG남매 출격" 아이콘·블랙핑크, 내년 1월 가요계 컴백
# ['ikon', 'yg', '뮤직비디오', '교칙위반수학여행', '음악']
# ['아이콘', '컴백', '블랙핑크', '아이콘 블랙핑크', 'YG', '안무', '가요계', '준비', '비디오', '뮤직']
#
# http://entertain.naver.com/ranking/read?oid=009&aid=0004062377
# 올해 가성비 갑 한국영화 3위는 `범죄도시`…1위는?
# ['범죄도시', '택시운전사', '유해진', '청년경찰', '아이캔스피크']
# ['영화', '제작비', '매출액', '이미지', '원본', '관객수', '이미지 원본', '가성비', '관객', '흥행']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=421&aid=0003092228&date=20171211&type=1&rankingSectionId=101&rankingSeq=4
# 비트코인 선물 출시, 가상화폐 버블 터트릴 ‘기회’
# ['비트코인', '가상화폐', '나스닥']
# ['비트코인', '선물', '출시', '투자자', '비트코인 선물', '선물 출시', '거래소', '거래', '베팅', '하락 베팅']
#
# http://entertain.naver.com/ranking/read?oid=213&aid=0001005335
# [리폿@나혼자] 비 아니면 몰랐을 이시언의 반전 매력
# ['비', '나혼자', '눈길', '뮤직비디오', '나혼자산다']
# ['이시언', '모습', '친구', '반전', '나라', '이미지', '제작진', '시언', '이시언 반전', '드러냈']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=014&aid=0003921252&date=20171209&type=1&rankingSectionId=105&rankingSeq=30
# 커지는 구글-아마존 갈등, 피해는 소비자
# ['아마존', '구글', 'it']
# ['구글', '기업', '아마존', '소비자', '인터넷', '갈등', '합의', '시장 장악', '장악', '시장']
#
# http://entertain.naver.com/ranking/read?oid=213&aid=0001005646
# [리폿@이슈] KBS 연기대상…김영철vs천호진, 父들의 전쟁 될까
# ['천호진', 'kbs연기대상', '김영철', '아버지가이상해', '김윤석']
# ['아버지', '천호진', '인생', '김영철', '모습', '연기', '황금빛 인생', '황금빛', '대상', '역시']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=009&aid=0004063280&date=20171209&type=1&rankingSectionId=105&rankingSeq=29
# 까칠한 소비자가 쓴 다이슨 수퍼소닉 헤어드라이어 사용기
# ['스위치', '포인트', '바로']
# ['헤어드라이어', '소닉', '수퍼', '수퍼 소닉', '다이슨', '다이슨 수퍼', '다이슨 수퍼 소닉', '사용', '제품', '모터']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=008&aid=0003976281&date=20171209&type=1&rankingSectionId=105&rankingSeq=27
# "다양한 자급제폰 출시해야"…완전자급제 대신 자급률 활성화
# ['보편요금제', '단말기자급제', '모델']
# ['단말기', '자급', '논의', '회의', '내용', '다양', '진행', '자급제', '단말기 자급', '한다는']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=030&aid=0002665251&date=20171209&type=1&rankingSectionId=105&rankingSeq=26
# 中 스타트업 "장기판 졸"...알리바바·텐센트 그늘 못벗어나
# ['알리바바', '텐센트', '스타트업']
# ['알리바바', '텐센트', '자전거', '업계', '중국', '공유', '스타트업', '공유 업계', '자전거 공유', '알리바바 텐센트']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=025&aid=0002779783&date=20171209&type=1&rankingSectionId=105&rankingSeq=25
# 매머드의 멸종, 과도한 사냥 탓일까
# ['사냥', 'dna', '기후변화']
# ['매머드', '복제', '사체', '멸종', '발견', '주장', '매머드 사체', '러시아', '다는', '박사']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=001&aid=0009743251&date=20171211&type=1&rankingSectionId=101&rankingSeq=13
# 비트코인 선물 거래 첫날 20% 폭등…두차례 거래 중단
# ['이슈 · 가상화폐 광풍', '비트코인', '폭등', '선물거래']
# ['가격', '선물', '비트코인', '거래', '비트코인 선물', '선물 거래', '선물 가격', '비트코인 선물 가격', 'CBOE', '중단']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=449&aid=0000143378&date=20171209&type=2&rankingSectionId=105&rankingSeq=23
# 사고 부르는 졸음운전…인공지능이 예방한다
# ['졸음운전', '인공지능', '화물차']
# ['사고', '졸음운전', '기술', '차량', '졸음', '시스템', '대형', '예방', '테스트', '인공지능']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=023&aid=0003336289&date=20171209&type=1&rankingSectionId=105&rankingSeq=22
# [Tech & BIZ] 시장 질서 파괴하는 '아마존'… 다음 타깃은 누구?
# ['이슈 · 떠오르는 신기술, 로봇', '아마존', '일자리', '헬스케어']
# ['아마존', '미국', '시장', '오프라인', '업체', '일자리', '사업', '점포', '분야', '진출']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=022&aid=0003232447&date=20171209&type=1&rankingSectionId=105&rankingSeq=20
# [S스페셜 - 우주 이야기] (39) 뭉치면 살고 흩어지면 죽는다? 군집 위성의 세계
# ['위성', '로켓', 'nasa']
# ['위성', '군집', '소형', '소형 위성', '우주', '군집 위성', '발사', '지구', '프로젝트', '출처']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=119&aid=0002227159&date=20171209&type=1&rankingSectionId=105&rankingSeq=18
# 12월 신규 스마트폰 쏟아진다
# ['스마트폰', 'lg전자', '화웨이']
# ['스마트폰', '화웨이', 'LG전자', '전망', '비와이폰', '제공', '프리미엄', '샤오미', '시그니처 에디션', 'LG전자 시그니처 에디션']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=081&aid=0002876052&date=20171209&type=1&rankingSectionId=105&rankingSeq=17
# [핵잼 사이언스] 가오리 로봇 “삐리삐리~ 내 우아한 수영실력 어때”
# ['로봇', '유연성', '길']
# ['로봇', '만타', '드로이드', '만타 드로이드', '박사', '바다', '우아', '가슴지느러미', '수중', '쥐가오리']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=277&aid=0004136578&date=20171209&type=1&rankingSectionId=105&rankingSeq=16
# "애플, 내년 아이폰 3종 출시…배터리 용량 최대 10%↑"
# ['배터리', '아이폰', '애플']
# ['아이폰', '디스플레이', '배터리', '용량', '애플', '출시', '적용', '1인치', '배터리 용량', '지원']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=421&aid=0003089342&date=20171209&type=1&rankingSectionId=105&rankingSeq=15
# [단독]방통위 '갤S8 대란' 이통3사에 위반내용 통보
# ['방송통신위원회', '과징금', '갤럭시s8']
# ['방통위', '과징금', '이통3사', '위반', '갤럭시S8', '의견', '시정조치', '결정', '조사', '의견 수렴']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=277&aid=0004136477&date=20171209&type=1&rankingSectionId=105&rankingSeq=14
# 평창 망 훼손사건…KT, LG유플러스도 고소했다
# ['kt', 'lg유플러스', 'sk텔레콤']
# ['LG유플러스', 'SK텔레콤', '훼손', 'KT', '고소', '관로', '밝혔', '설치', '올림픽', '자사']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=031&aid=0000432453&date=20171209&type=1&rankingSectionId=105&rankingSeq=13
# 퀄컴, 하이파이 오디오 키운다…소니·삼성 '압박'
# ['퀄컴', '소니', '생태계']
# ['퀄컴', '하이파이', '어쿠스틱', '퀄컴 어쿠스틱', '오디오', '스냅드래곤', '스피커', '강화', '지원', '한다']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=001&aid=0009739563&date=20171209&type=1&rankingSectionId=105&rankingSeq=12
# 테슬라 "세계최고 AI칩 개발 중…강력한 자율주행 가능"
# ['테슬라', 'ai', '알파벳']
# ['테슬라', '하드웨어', '개발', '자율 주행', '자율', '주행', '부사장', '켈러', '머스크', 'AI']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=014&aid=0003921394&date=20171209&type=1&rankingSectionId=105&rankingSeq=11
# "샤오미 미노트3 카메라, 아이폰과 동급 수준"
# ['아이폰', '카메라', '샤오미']
# ['노트3', '카메라', '평가', '점수', '아이폰8', '94', '아이폰7 85점', '아이폰8 플러스', '85점', '플러스']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=023&aid=0003336268&date=20171209&type=1&rankingSectionId=105&rankingSeq=9
# [IF] 가리비 눈 속에 '우주망원경' 있었네
# ['이스라엘', '바로', 'dna']
# ['가리비', '반사경', '처럼', '망막', '초점', '망막 초점', '연구진', '종류', '종류 망막', '사이언스']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=081&aid=0002876115&date=20171210&type=1&rankingSectionId=105&rankingSeq=16
# [와우! 과학] 아가미로 숨쉬고 영양분도 흡수… ‘슈퍼 빌런’ 게 발견
# ['산소', '생태계', '캐나다']
# ['아가미', '흡수', '연구', '산소', '능력', '캐나다', '환경', '갑각류', '해안', '변화']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=014&aid=0003921269&date=20171209&type=1&rankingSectionId=105&rankingSeq=8
# 절반도 못 쓴 통신사 포인트, 왜 내년에 이어서 못쓸까?
# ['포인트', '마일리지', '한국소비자원']
# ['포인트', '통신사', '멤버십', '멤버십 포인트', '기간', '소비자', '소멸', '결제', '서비스', '사용']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=023&aid=0003336267&date=20171209&type=1&rankingSectionId=105&rankingSeq=3
# [IF] 2033년, 달 찍고 화성 밟는다
# ['이슈 · 화성 탐사', '화성', '로켓', '우주선']
# ['화성', '탐사', '로켓', '지구', '화성 탐사', '발사', '우주선', '개발', '우주', 'NASA']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=001&aid=0009740098&date=20171209&type=1&rankingSectionId=104&rankingSeq=30
# 이라크, 3년여만에 'IS 완전 격퇴' 승전 선언
# ['이슈 · 세력 잃어가는 IS', '이라크', 'is', '테러']
# ['이라크', 'IS', '이라크 정부', '정부', '복구', '지원', '필요', '다에시', '영토', '통제']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=014&aid=0003921284&date=20171209&type=1&rankingSectionId=104&rankingSeq=29
# 약혼자가 디자인한 반지 잃어버린 여성에게 찾아온 '기적'
# ['다이아몬드', '바로', '22세']
# ['반지', '크리스티', '약혼자', '여성', '그녀', '사연', '모하메드', '개월', '디자인', '커플']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=421&aid=0003090733&date=20171209&type=1&rankingSectionId=104&rankingSeq=28
# 펠트먼 유엔 사무차장, 닷새간 방북 끝내…베이징 도착
# ['유엔', '베이징', '조선중앙통신']
# ['펠트', '사무차장', '유엔', '펠트 사무차장', '한반도', '북한', '회담', '베이징', '조선중앙통신', '발표']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=030&aid=0002665264&date=20171209&type=1&rankingSectionId=104&rankingSeq=27
# 테슬라 "독자적인 AI 칩 개발…세계 최고 기대"
# ['테슬라', 'ai', '알파벳']
# ['테슬라', '하드웨어', '개발', '머스크', '부사장', '켈러', 'AI', 'CEO', '자율주행', '자체']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=011&aid=0003170770&date=20171209&type=1&rankingSectionId=104&rankingSeq=25
# “지옥의 문 열렸는데”··백악관서 '유대교 축제' 즐긴 트럼프
# ['도널드 트럼프', '유대교', '백악관']
# ['대통령', '트럼프', '예루살렘', '이스라엘', '트럼프 대통령', '수도', '백악관', '유대교', '하누카', '미국']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=003&aid=0008333914&date=20171210&type=1&rankingSectionId=104&rankingSeq=2
# 日,13만명분 '건빵' 무료 배포…재난대비 비축기간 곧 만료
# ['유통기한', '비상식량', '이재민']
# ['배포', '건빵', '도쿄도', '무료', '인분', '무료 배포', '비축', '가운데', '유통기한', 'NHK']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=001&aid=0009739976&date=20171209&type=1&rankingSectionId=104&rankingSeq=19
# "5천억원 다빈치 예수 초상화, 아부다비가 샀다"
# ['아부다비', '다빈치', '초상화']
# ['문디', '살바토르', '살바토르 문디', '경매', '아부다비', '크리스티', '다빈치', '공개', '아부다비 문화관광부', '문화관광부']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=008&aid=0003977732&date=20171212&type=1&rankingSectionId=100&rankingSeq=4
# 한국당, 崔 체포동의안 표결 당론 없을 듯…표결 불참도 거론
# ['한국당', '체포동의안', '본회의']
# ['의원', '체포동의안', '한국당', '의원 체포동의안', '국회', '한국당 의원', '차원', '개인', '한다', '장제원']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=001&aid=0009739723&date=20171209&type=1&rankingSectionId=104&rankingSeq=18
# 中, 호주에 "편견 가졌다" 비난…'反中 기조' 성토 이어가
# ['호주', '턴불', '겅솽']
# ['호주', '중국', '언론', '정부', '관계', '다고', '발언', '총리', '턴불', '편견']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=001&aid=0009739677&date=20171209&type=1&rankingSectionId=104&rankingSeq=15
# EU 5개국 "예루살렘은 이·팔 쌍방의 수도" 공동성명
# ['이슈 · 미, 예루살렘 수도 선언', '예루살렘', '이스라엘', '유엔']
# ['이스라엘', '국가', '예루살렘', '해법', '수도', '미국', '팔레스타인', '이스라엘 팔레스타인', '결정', '국가 해법']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=020&aid=0003113930&date=20171209&type=1&rankingSectionId=104&rankingSeq=14
# 팔레스타인 무장단체들 ‘인티파다’ 독려… 美는 해병대 출격까지 시사
# ['이슈 · 미, 예루살렘 수도 선언', '팔레스타인', '예루살렘', '이스라엘']
# ['미국', '이스라엘', '팔레스타인', '트럼프', '대통령', '트럼프 대통령', '예루살렘', '헤즈볼라', '수도', '선언']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=008&aid=0003977671&date=20171212&type=1&rankingSectionId=101&rankingSeq=19
# "금리, 올릴까 말까"…FRB 흔드는 아마존
# ['아마존', '금리인상', '금리']
# ['아마존', '미국', '금리', '가격', '물가', '인상', 'FRB', '지적', '금리 인상', '압력']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=081&aid=0002876053&date=20171209&type=1&rankingSectionId=104&rankingSeq=10
# ‘투명 망토’ 실화? 네티즌 놀라게 한 영상의 진실
# ['조작', '네티즌', '디테일']
# ['영상', '망토', '기술', '투명', '현지', '투명 망토', '웨이보', '투명망토', '중국', '해당']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=023&aid=0003336362&date=20171209&type=1&rankingSectionId=104&rankingSeq=8
# 시속 130㎞ 돌풍에 '럭비공 불길'… 주민들 공황상태
# ['이슈 · 미 캘리포니아 대형산불', '산불', '돌풍', '캘리포니아']
# ['산불', '주민', '미국', '예측', '캘리포니아', '지역', '대피', '샌디에이고', '에이커', '발화']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=081&aid=0002875999&date=20171209&type=1&rankingSectionId=104&rankingSeq=7
# 한·중 정상회담 견제하고 北도 압박… 美의 ‘평창올림픽 게임’
# ['정상회담', '평창올림픽', '평창동계올림픽']
# ['참가', '결정', '선수단', '미국', '백악관', '올림픽', '압박', '상황', '평창동계올림픽', '분석']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=023&aid=0003336318&date=20171209&type=1&rankingSectionId=104&rankingSeq=5
# 체포한 왕자 너무 많아… 호텔 하나로 모자라 옆 호텔도 '교도소'로
# ['호텔', '사우디', '부패']
# ['사우디', '왕자', '호텔', '부패', '리츠칼튼', '조사', '관료', '외국', '메리어트', '정부']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=005&aid=0001054252&date=20171209&type=1&rankingSectionId=104&rankingSeq=2
# 일단 판부터 뒤엎기… 트럼프식 길들이기 외교
# ['이슈 · 미, 예루살렘 수도 선언', '트럼프', '예루살렘', '팔레스타인']
# ['미국', '트럼프', '대통령', '접근법', '트럼프 대통령', '방식', '이스라엘', '인정', '동맹국', '정부']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=003&aid=0008336154&date=20171211&type=1&rankingSectionId=101&rankingSeq=17
# 최종구 "비트코인, 금융 아냐…당연히 선물거래도 안돼"
# ['최종구', '비트코인', '선물거래']
# ['거래', '비트코인', '위원장', '가상통화', '가상통화 거래', '금융', '법무부', '근거', '입장', '거래소']
#
# http://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=025&aid=0002779749&date=20171209&type=1&rankingSectionId=104&rankingSeq=1
# [윤석만의 인간혁명]진나라 vs 로마제국, 누가 이겼을까
# ['문화', '누가', '바로']

# %% [markdown]
# * 형태소 분석 : morp
# * 어휘의미 분석 : wsd (동음이의어)
# * 어휘의미 분석 : wsd_poly (다의어)
# * 개체명 인식 : ner
# * 의존구문 분석 : dependency
# * 의미역 인식 : srl

# %%
pickle.dump(extract_keywords_dict, open('./data/Keyword_outcome/mecab-naver.pickled','wb'))

# %% [markdown]
# # sentiment analysis
