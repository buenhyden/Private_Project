# %% [markdown]
# # News Clustering

# %%
import pickle
import itertools
import warnings
import sys 
import os
import logging
from multiprocessing import cpu_count

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from ckonlpy.tag import Twitter
from konlpy.tag import Mecab

from gensim.models import CoherenceModel, LdaModel, LsiModel, HdpModel, ldaseqmodel, LdaMulticore, lda_dispatcher
from gensim.models.wrappers import LdaMallet, DtmModel
from gensim.corpora import Dictionary, bleicorpus
from gensim.matutils import hellinger
from gensim import corpora, models, similarities
from gensim.models.callbacks import CoherenceMetric, DiffMetric, PerplexityMetric, ConvergenceMetric

import pyLDAvis.gensim

from tqdm import tqdm
tqdm.pandas(desc="progress-bar")

warnings.filterwarnings('ignore')

# %%
def Nav_tokenizer(doc, tagger, stopwords):
    pos = tagger.pos(doc)
    pos = [word[0] for word in pos if (len(word[0])>1) & (not word[0] in stopwords)]
    return pos

# %%
def Nav_tokenizer_noun(doc, tagger, stopwords):
    pos = tagger.nouns(doc)
    pos = [word for word in pos if (len(word)>1) & (not word in stopwords)]
    return pos

# %%
def evaluate_graph(dictionary, corpus, texts, limit, tagger, modelpath):
    """
    Function to display num_topics - LDA graph using c_v coherence
    
    Parameters:
    ----------
    dictionary : Gensim dictionary
    corpus : Gensim corpus
    limit : topic limit
    
    Returns:
    -------
    lm_list : List of LDA topic models
    c_v : Coherence values corresponding to the LDA model with respective number of topics
    """
    c_v = []
    lm_list = []
    import os
    for num_topics in range(1, limit):
        ldaFileName = os.path.join(modelpath, 'ldamodel_{}_topic-{}'.format(tagger, num_topics))
        cohFileName = os.path.join(modelpath, 'coherencemodel_{}_topic-{}'.format(tagger, num_topics))
        if not os.path.isfile(ldaFileName):
            lm = LdaModel(corpus=corpus, num_topics=num_topics, id2word=dictionary)
            lm.save(ldaFileName)
        else:
            lm = LdaModel.load(ldaFileName)
        lm_list.append(lm)
        if not os.path.isfile(cohFileName):
            cm = CoherenceModel(model=lm, texts=texts, dictionary=dictionary, coherence='c_v')
            cm.save(cohFileName)
        else:
            cm = CoherenceModel.load(cohFileName)
        c_v.append(cm.get_coherence())
        
    # Show graph
    x = range(1, limit)
    plt.plot(x, c_v)
    plt.xlabel("num_topics")
    plt.ylabel("Coherence score")
    plt.legend(("c_v"), loc='best')
    plt.show()
    
    return lm_list, c_v

# %% [markdown]
# ### Stopwords

# %%
stopwords = open('./data/stopwordsList.txt',encoding='utf-8').readlines()
stopwords = list(map(lambda x: x.strip(), stopwords))

# %% [markdown]
# ## News

# %% [markdown]
# ### Naver

# %%
dictNaver = pickle.load(open('./data/pre_data/stastics/for_statistics_Naver_from_mongodb.pickled','rb'))
dfNaver = pd.DataFrame.from_dict(dictNaver, orient='index')
print (dfNaver.shape)
# Out:
# (15120, 10)

# %% [markdown]
# ### Daum

# %%
dictDaum = pickle.load(open('./data/pre_data/stastics/for_statistics_daum_from_mongodb.pickled','rb'))
dfDaum = pd.DataFrame.from_dict(dictDaum, orient='index')
print (dfDaum.shape)
# Out:
# (9372, 10)

# %% [markdown]
# ## Daum

# %% [markdown]
# ### 뉴스 기사 통합

# %%
combinedDf = pd.concat([dfNaver, dfDaum])
combinedDf.head()
# Out:
#                          category        date press  number_of_comment  \
# 5a29c445588c132954d1973a       정치  2017.12.07  연합뉴스               1713
# 5a29c445588c132954d1973b       정치  2017.12.07  한국일보               2551
# 5a29c445588c132954d1973c       정치  2017.12.07   뉴시스                610
# 5a29c445588c132954d1973d       정치  2017.12.07  연합뉴스                145
# 5a29c445588c132954d1973e       정치  2017.12.07  동아일보               1074
#
#                           number_of_crawled_comment rank  \
# 5a29c445588c132954d1973a                       1465    1
# 5a29c445588c132954d1973b                       2062    2
# 5a29c445588c132954d1973c                        536    3
# 5a29c445588c132954d1973d                        133    4
# 5a29c445588c132954d1973e                        932    5
#
#                                                     title  \
# 5a29c445588c132954d1973a    北외무성 "전쟁 바라지 않지만 결코 피하지 않을 것"
# 5a29c445588c132954d1973b             예산전쟁, 예결위 간사ㆍ호남이 웃었다
# 5a29c445588c132954d1973c  혐의 부인에 20시간 조사…檢, 최경환 구속 카드 꺼내나
# 5a29c445588c132954d1973d   최재형 감사원장 후보자 "독립성 강화는 임명권자의 뜻"
# 5a29c445588c132954d1973e          B-1B 한반도에 뜨자, 평양 비운 김정은
#
#                                                                    mainText  \
# 5a29c445588c132954d1973a  美고위인사 대북언급 비난하며 "전쟁 기정사실화" 위협  며칠 새 이어지는 북한 군민...
# 5a29c445588c132954d1973b  예결위 간사들이 최대 수혜자..당 지도부 내 몫 챙기기도 여전   황주홍ㆍ김도읍 등...
# 5a29c445588c132954d1973c  【서울=뉴시스】 최진석 기자 = 박근혜 정부 시절 국가정보원 특수활동비 수수 의혹 ...
# 5a29c445588c132954d1973d  감사원장에 내정된 최재형 사법연수원장(고양=연합뉴스) 이희열 기자 = 7일 감사원장...
# 5a29c445588c132954d1973e  [동아일보] 북중 접경지 양강도 삼지연 시찰… 방북 유엔 사무차장 면담 안할듯 B-...
#
#                                                     keywords  \
# 5a29c445588c132954d1973a                     [외무성, 핵전쟁, 대변인]
# 5a29c445588c132954d1973b                      [예산, 예결위, soc]
# 5a29c445588c132954d1973c                  [최경환, 구속영장, 국가정보원]
# 5a29c445588c132954d1973d  [이슈 · 최재형 감사원장 내정, 감사원장, 최재형, 감사원]
# 5a29c445588c132954d1973e                    [김정은, b-1b, 한반도]
#
#                                                   extracted_keywords
# 5a29c445588c132954d1973a       {핵전쟁, 고위, 도화선, 미국, 조선반도, 대변인, 북한, 중앙}
# 5a29c445588c132954d1973b           {지역구, 국민의당, 예산안, 의원, 호남, 증액, 정부안}
# 5a29c445588c132954d1973c       {국정원장, 조사, 혐의, 구속영장 청구, 정기국회, 의원, 검찰}
# 5a29c445588c132954d1973d              {지명, 공직 사회, 후보자, 생활, 법관, 감사원장}
# 5a29c445588c132954d1973e  {삼지연, 훈련, 양강도, 펠트먼, 공장, 시찰, 사무차장, 김정은, 접경}

# %%
rawData_text = combinedDf.title + '\n' + combinedDf.mainText

# %%
rawData_text[0]
# Out:
# '北외무성 "전쟁 바라지 않지만 결코 피하지 않을 것"\n美고위인사 대북언급 비난하며 "전쟁 기정사실화" 위협  며칠 새 이어지는 북한 군민연환대회(평양 조선중앙통신=연합뉴스) 북한이 \'화성-15형\' 발사 성공을 축하하는 군민연환대회를 지난 5일 황해북도, 강원도, 양강도 등 각지에서 열었다고 6일 조선중앙통신이 보도했다. 2017.12.6 [국내에서만 사용가능. 재배포 금지. For Use Only in the Republic of Korea. No Redistribution] photo@yna.co.kr   (서울=연합뉴스) 홍국기 기자 = 북한은 6일 미국 고위인사들의 대북 강경 발언들을 문제 삼으며 "미국은 매일과 같이 조선반도(한반도)에서의 핵전쟁을 광고하고 있다"면서 "우리는 전쟁을 바라지 않지만 결코 피하지 않을 것"이라고 밝혔다.  북한 외무성 대변인은 이날 조선중앙통신 기자와의 문답에서 "미국이 조선반도에서 우리를 겨냥한 사상 최대의 연합공중훈련을 강행하고 있는 가운데 최근 미국의 고위정객들이 줄줄이 나서서 호전적인 망발들을 늘어놓는 등 심상치 않은 움직임을 보이고 있다"면서 이같이 말했다고 중앙통신이 전했다.  외무성 대변인은 "조선반도에 언제 전쟁이 터질지 모를 일촉즉발의 초긴장상태가 조성되고있는 속에 미국의 고위정객들의 입에서 연달아 터져 나오는 전쟁 폭언으로 말미암아 조선반도에서의 전쟁은 기정사실화되고 이제 남은 것은 언제 전쟁이 터지는가 하는 시점상 문제"라고 위협했다.  대변인은 "백악관 국가안보보좌관과 공화당 소속 국회 상원의원이 북조선과의 전쟁 가능성이 매일 증대되고 있다느니, 선제공격 선택에 더욱 접근하고 있다느니, 남조선 주둔 미군 가족들을 철수시켜야 한다느니 하는 따위의 화약내 풍기는 대결 망발들을 늘어놓은 것은 우리에게 조선반도에서의 전쟁발발에 대비하라는 신호로밖에 달리 해석될 수 없다"고 주장했다.  이어 "지어(심지어) 미 중앙정보국장이란 놈이 우리의 심장인 최고 지도부까지 감히 걸고 들며 도발을 걸어온 것은 우리가 강경 대응조치를 취하게 하고 그를 빌미로 조선반도에서 핵전쟁의 도화선에 기어이 불을 달려는 미국의 간교한 흉심의 노출"이라고 비난했다.  이는 마이크 폼페이오 미 중앙정보국(CIA) 국장이 지난 2일 한 포럼에서 "김정은은 국내외에서 자신의 입지가 얼마나 취약한지 잘 알지 못하는 것으로 생각한다"고 한 발언을 겨냥한 것으로 보인다.  대변인은 "미국이 우리의 자제력을 오판하고 끝끝내 핵전쟁의 도화선에 불을 단다면 다지고 다져온 무진막강한 핵무력으로 반드시 그 대가를 치르게 할 것"이라며 "미국은 제가 지른 불에 타죽지 않으려거든 자중 자숙하는 것이 좋을 것"이라고 밝혔다.  redflag@yna.co.kr  ▶기사제보 및 문의(클릭!)  ▶최신 유행 트렌드 총집결(클릭!)'

# %%
if sys.platform =='darwin':
    clusteringPath ='/Volumes/disk1/Clustering/'
    clusteringModelPath = '/Volumes/disk1/Clustering_model/'
elif sys.platform =='win32':
    clusteringPath = 'd:/Clustering/' 
    clusteringModelPath = 'd:/Clustering_model/'

# %% [markdown]
# ### token

# %%
mecab = Mecab()
ct = Twitter()

# %% [markdown]
# #### 명사만

# %%
outfile_ct = clusteringPath + 'nouns_taggerd_news_text_by_ct.pickled'
if not os.path.isfile(outfile_ct):
    tagged_text_ct = [Nav_tokenizer_noun(doc, ct, stopwords) for doc in tqdm(rawData_text)]
    pickle.dump(tagged_text_ct, open(outfile_ct, 'wb'))
else:
    tagged_text_ct = pickle.load(open(outfile_ct, 'rb'))

# %%
outfile_mecab = clusteringPath + 'nouns_taggerd_news_text_by_mecab.pickled'
if not os.path.isfile(outfile_mecab):
    tagged_text_mecab = [Nav_tokenizer_noun(doc, mecab, stopwords) for doc in tqdm(rawData_text)]
    pickle.dump(tagged_text_mecab, open(outfile_mecab, 'wb'))
else:
    tagged_text_mecab = pickle.load(open(outfile_mecab, 'rb'))

# %%
tagged_text_ct[0]
# Out:
# ['외무성',
#  '전쟁',
#  '바라지',
#  '결코',
#  '피하',
#  '고위',
#  '인사',
#  '대북',
#  '언급',
#  '비난',
#  '전쟁',
#  '기정',
#  '위협',
#  '며칠',
#  '북한',
#  '군민',
#  '연환',
#  '대회',
#  '평양',
#  '조선',
#  '중앙',
#  '통신',
#  '북한',
#  '화성',
#  '15',
#  '발사',
#  '성공',
#  '군민',
#  '연환',
#  '대회',
#  '황해북도',
#  '강원도',
#  '양강도',
#  '각지',
#  '조선중앙통신',
#  '2017',
#  '12',
#  '국내',
#  '사용',
#  '가능',
#  '배포',
#  '금지',
#  '서울',
#  '국기',
#  '북한',
#  '미국',
#  '고위',
#  '인사',
#  '대북',
#  '강경',
#  '발언',
#  '미국',
#  '매일',
#  '조선반도',
#  '한반도',
#  '핵전쟁',
#  '광고',
#  '전쟁',
#  '바라지',
#  '결코',
#  '피하',
#  '북한',
#  '외무성',
#  '대변인',
#  '조선중앙통신',
#  '문답',
#  '미국',
#  '조선반도',
#  '겨냥',
#  '사상',
#  '최대',
#  '연합',
#  '공중',
#  '훈련',
#  '강행',
#  '미국',
#  '고위',
#  '정객',
#  '줄줄이',
#  '호전',
#  '적인',
#  '망발',
#  '상치',
#  '움직임',
#  '중앙통신',
#  '외무성',
#  '대변인',
#  '조선반도',
#  '전쟁',
#  '일촉즉발',
#  '초긴장',
#  '상태',
#  '조성',
#  '미국',
#  '고위',
#  '정객',
#  '연달',
#  '전쟁',
#  '폭언',
#  '조선반도',
#  '서의',
#  '전쟁',
#  '기정',
#  '전쟁',
#  '위협',
#  '대변인',
#  '백악관',
#  '국가',
#  '안보',
#  '보좌',
#  '공화당',
#  '국회',
#  '상원의원',
#  '북조선',
#  '전쟁',
#  '가능성',
#  '매일',
#  '증대',
#  '선제공격',
#  '선택',
#  '접근',
#  '남조선',
#  '주둔',
#  '미군',
#  '가족',
#  '철수',
#  '화약',
#  '풍기',
#  '대결',
#  '망발',
#  '조선반도',
#  '서의',
#  '전쟁',
#  '발발',
#  '대비',
#  '신호',
#  '달리',
#  '해석',
#  '중앙',
#  '정보',
#  '국장',
#  '심장',
#  '최고',
#  '지도부',
#  '감히',
#  '도발',
#  '강경',
#  '대응조치',
#  '빌미',
#  '조선반도',
#  '핵전',
#  '쟁의',
#  '도화선',
#  '기어이',
#  '미국',
#  '간교',
#  '심의',
#  '노출',
#  '비난',
#  '마이크',
#  '폼페이',
#  '중앙',
#  '정보',
#  '국장',
#  '포럼',
#  '김정은',
#  '국내외',
#  '입지',
#  '취약',
#  '한지',
#  '발언',
#  '겨냥',
#  '대변인',
#  '미국',
#  '자제력',
#  '판하',
#  '끝내',
#  '핵전',
#  '쟁의',
#  '도화선',
#  '다지',
#  '무진',
#  '막강',
#  '무력',
#  '대가',
#  '미국',
#  '죽지',
#  '자중',
#  '자숙하',
#  '제보',
#  '문의',
#  '클릭',
#  '최신',
#  '유행',
#  '트렌드',
#  '집결',
#  '클릭']

# %%
tagged_text_mecab[0]
# Out:
# ['외무성',
#  '전쟁',
#  '고위',
#  '인사',
#  '대북',
#  '언급',
#  '비난',
#  '전쟁',
#  '기정사실화',
#  '위협',
#  '며칠',
#  '북한',
#  '군민',
#  '연환',
#  '대회',
#  '평양',
#  '조선중앙통신',
#  '북한',
#  '화성',
#  '발사',
#  '성공',
#  '축하',
#  '군민',
#  '연환',
#  '대회',
#  '황해북도',
#  '강원도',
#  '양강도',
#  '각지',
#  '조선중앙통신',
#  '보도',
#  '국내',
#  '사용',
#  '가능',
#  '재배포',
#  '금지',
#  '서울',
#  '홍국',
#  '북한',
#  '미국',
#  '고위',
#  '인사',
#  '대북',
#  '강경',
#  '발언',
#  '미국',
#  '매일',
#  '조선반도',
#  '한반도',
#  '핵전쟁',
#  '광고',
#  '전쟁',
#  '북한',
#  '외무성',
#  '대변인',
#  '조선중앙통신',
#  '문답',
#  '미국',
#  '조선반도',
#  '겨냥',
#  '사상',
#  '최대',
#  '연합',
#  '공중',
#  '훈련',
#  '강행',
#  '미국',
#  '고위',
#  '정객',
#  '호전',
#  '망발',
#  '움직임',
#  '중앙통신',
#  '외무성',
#  '대변인',
#  '조선반도',
#  '전쟁',
#  '일촉즉발',
#  '초긴장',
#  '상태',
#  '조성',
#  '미국',
#  '고위',
#  '정객',
#  '전쟁',
#  '폭언',
#  '조선반도',
#  '전쟁',
#  '기정사실',
#  '전쟁',
#  '위협',
#  '대변인',
#  '백악관',
#  '국가안보',
#  '보좌관',
#  '공화당',
#  '국회',
#  '상원',
#  '의원',
#  '북조선',
#  '전쟁',
#  '가능',
#  '증대',
#  '선제공격',
#  '선택',
#  '접근',
#  '남조선',
#  '주둔',
#  '미군',
#  '가족',
#  '철수',
#  '화약내',
#  '대결',
#  '망발',
#  '조선반도',
#  '전쟁',
#  '발발',
#  '대비',
#  '신호',
#  '해석',
#  '주장',
#  '지어',
#  '중앙',
#  '정보',
#  '국장',
#  '심장',
#  '최고',
#  '지도부',
#  '도발',
#  '강경',
#  '대응',
#  '조치',
#  '빌미',
#  '조선반도',
#  '핵전쟁',
#  '도화선',
#  '미국',
#  '간교',
#  '흉심',
#  '노출',
#  '비난',
#  '마이크',
#  '폼페이',
#  '중앙정보국',
#  '국장',
#  '포럼',
#  '김정은',
#  '국내외',
#  '입지',
#  '발언',
#  '겨냥',
#  '대변인',
#  '미국',
#  '자제력',
#  '오판',
#  '핵전쟁',
#  '도화선',
#  '단다',
#  '무진',
#  '막강',
#  '무력',
#  '대가',
#  '미국',
#  '자중',
#  '자숙',
#  '문의',
#  '클릭',
#  '최신',
#  '유행',
#  '트렌드',
#  '총집결',
#  '클릭']

# %% [markdown]
# ### 사전 데이터 제작

# %%
# %%time
dict_ct_name = clusteringModelPath + 'dictionary_ct'
dict_mecab_name = clusteringModelPath + 'dictionary_mecab'
if not os.path.isfile(dict_ct_name):
    dictionary_ct = Dictionary(tagged_text_ct)
    dictionary_ct.save(dict_ct_name)
else:
    dictionary_ct = Dictionary.load(dict_ct_name)
if not os.path.isfile(dict_mecab_name):
    dictionary_mecab = Dictionary(tagged_text_mecab)
    dictionary_mecab.save(dict_mecab_name)
else:
    dictionary_mecab = Dictionary.load(dict_mecab_name)
# Out:
# CPU times: user 185 ms, sys: 47.1 ms, total: 232 ms
# Wall time: 273 ms

# %%
# %%time
corpus_ct_name = clusteringModelPath + 'corpus_ct.pickled'
corpus_mecab_name = clusteringModelPath + 'corpus_mecab.pickled'
if not os.path.isfile(corpus_ct_name):
    corpus_ct = [ dictionary_ct.doc2bow(text) for text in tqdm(tagged_text_ct)]
    pickle.dump(corpus_ct, open(corpus_ct_name, 'wb'))
else:
    corpus_ct = pickle.load(open(corpus_ct_name, 'rb'))
if not os.path.isfile(corpus_mecab_name):
    corpus_mecab = [ dictionary_mecab.doc2bow(text) for text in tqdm(tagged_text_mecab)]
    pickle.dump(corpus_mecab, open(corpus_mecab_name, 'wb'))
else:
    corpus_mecab = pickle.load(open(corpus_mecab_name, 'rb'))
# Out:
# CPU times: user 1.6 s, sys: 534 ms, total: 2.13 s
# Wall time: 2.73 s

# %%
print('Number of unique tokens: %d' % len(dictionary_ct))
print('Number of documents: %d' % len(corpus_ct))
print('Number of unique tokens: %d' % len(dictionary_mecab))
print('Number of documents: %d' % len(corpus_mecab))
# Out:
# Number of unique tokens: 98356
# Number of documents: 24492
# Number of unique tokens: 102314
# Number of documents: 24492

# %% [markdown]
# ### LSI (  Latent Semantic Indexing )
# * an indexing and retrieval method that uses a mathematical technique called singular value decomposition (SVD) to identify patterns in the relationships between the terms and concepts contained in an unstructured collection of text

# %%
# %%time
lsimodel_ct_name = clusteringModelPath + 'lsimodel_ct'
lsimodel_mecab_name = clusteringModelPath + 'lsimidel_mecab'
if not os.path.isfile(lsimodel_ct_name):
    lsimodel_ct = LsiModel(corpus = corpus_ct, num_topics = 20, id2word = dictionary_ct)
    lsimodel_ct.save(lsimodel_ct_name)
else:
    lsimodel_ct = LsiModel.load(lsimodel_ct_name)
if not os.path.isfile(lsimodel_mecab_name):
    lsimodel_mecab = LsiModel(corpus = corpus_mecab, num_topics = 20, id2word = dictionary_mecab)
    lsimodel_mecab.save(lsimodel_mecab_name)
else:
    lsimodel_mecab = LsiModel.load(lsimodel_mecab_name)
# Out:
# CPU times: user 455 ms, sys: 182 ms, total: 637 ms
# Wall time: 1.3 s

# %%
lsimodel_ct.show_topics(num_topics = 20)
# Out:
# [(0,
#   '0.240*"대통령" + 0.238*"선수" + 0.231*"경기" + 0.228*"한국" + 0.155*"정부" + 0.151*"중국" + 0.150*"서울" + 0.149*"미국" + 0.145*"적인" + 0.138*"감독"'),
#  (1,
#   '-0.424*"대통령" + 0.379*"경기" + 0.354*"선수" + 0.212*"득점" + 0.203*"감독" + -0.163*"정부" + 0.139*"기록" + 0.118*"리그" + -0.109*"중국" + -0.106*"미국"'),
#  (2,
#   '-0.874*"게임" + 0.178*"대통령" + -0.170*"동아" + -0.168*"출처" + -0.142*"쉘룡" + -0.108*"딴지" + -0.091*"출시" + -0.088*"개발" + -0.068*"국산" + 0.050*"경기"'),
#  (3,
#   '-0.622*"대통령" + -0.210*"게임" + 0.166*"거래" + 0.155*"가상화폐" + -0.149*"경기" + 0.144*"비트코인" + -0.125*"검찰" + 0.121*"한국" + 0.117*"시장" + -0.113*"득점"'),
#  (4,
#   '-0.459*"중국" + -0.365*"북한" + -0.267*"미국" + -0.244*"한국" + 0.173*"서울" + 0.167*"의원" + -0.150*"선수" + 0.149*"검찰" + -0.135*"일본" + 0.134*"수사"'),
#  (5,
#   '-0.503*"선수" + 0.360*"득점" + 0.229*"경기" + 0.202*"중국" + -0.174*"계약" + -0.133*"구단" + -0.130*"감독" + 0.124*"북한" + 0.117*"쿼터" + 0.112*"리바운드"'),
#  (6,
#   '-0.289*"대통령" + -0.280*"거래" + -0.279*"가상화폐" + 0.275*"대표" + 0.266*"의원" + -0.246*"비트코인" + 0.193*"통합" + -0.180*"거래소" + 0.168*"북한" + -0.150*"선수"'),
#  (7,
#   '-0.375*"대표" + -0.357*"의원" + -0.277*"통합" + -0.192*"국민의당" + -0.169*"가상화폐" + -0.168*"정당" + -0.159*"거래" + -0.147*"정부" + 0.139*"경찰" + -0.132*"비트코인"'),
#  (8,
#   '-0.418*"한국" + -0.297*"감독" + 0.233*"북한" + 0.219*"미국" + -0.210*"일본" + 0.181*"계약" + 0.175*"선수" + -0.140*"중국" + 0.129*"트럼프" + -0.125*"축구"'),
#  (9,
#   '0.542*"북한" + -0.271*"아이폰" + -0.265*"애플" + -0.184*"대통령" + -0.177*"한국" + -0.134*"배터리" + 0.127*"경찰" + 0.125*"거래" + 0.122*"가상화폐" + 0.122*"수사"'),
#  (10,
#   '-0.398*"중국" + -0.298*"김현정" + 0.273*"서울" + -0.238*"검찰" + -0.212*"수사" + -0.172*"아이폰" + -0.166*"의원" + -0.165*"애플" + 0.153*"정부" + -0.131*"검사"'),
#  (11,
#   '0.447*"중국" + -0.304*"김현정" + -0.221*"아이폰" + -0.214*"애플" + -0.209*"미국" + -0.196*"북한" + -0.190*"감독" + 0.188*"서울" + -0.120*"트럼프" + 0.119*"계약"'),
#  (12,
#   '0.692*"김현정" + -0.212*"검찰" + -0.177*"수사" + -0.147*"아이폰" + -0.146*"애플" + -0.144*"감독" + -0.142*"북한" + -0.120*"혐의" + -0.117*"검사" + 0.103*"득점"'),
#  (13,
#   '0.412*"한국" + -0.385*"중국" + 0.253*"득점" + 0.242*"일본" + -0.170*"감독" + 0.159*"쿼터" + -0.158*"손흥민" + -0.157*"토트넘" + 0.147*"리바운드" + -0.142*"시티"'),
#  (14,
#   '-0.303*"정부" + -0.247*"아이폰" + -0.241*"김현정" + -0.230*"애플" + -0.164*"북한" + 0.157*"비트코인" + -0.156*"서울" + 0.156*"미국" + 0.153*"방송" + 0.143*"트럼프"'),
#  (15,
#   '0.359*"감독" + -0.264*"미국" + 0.188*"아이폰" + 0.175*"득점" + -0.172*"기록" + -0.171*"한국" + -0.168*"손흥민" + 0.166*"애플" + -0.149*"경기" + 0.148*"중국"'),
#  (16,
#   '0.354*"미국" + 0.284*"서울" + 0.240*"트럼프" + 0.209*"감독" + 0.177*"김현정" + -0.175*"북한" + 0.171*"지역" + -0.161*"일본" + 0.159*"이스라엘" + 0.143*"예루살렘"'),
#  (17,
#   '-0.312*"감독" + 0.304*"서울" + -0.241*"정부" + 0.207*"한국" + 0.189*"비트코인" + 0.148*"아이폰" + -0.148*"기술" + -0.133*"미국" + -0.129*"기업" + 0.124*"정현"'),
#  (18,
#   '-0.338*"만원" + 0.253*"정부" + -0.212*"북한" + 0.196*"화재" + 0.175*"사고" + 0.163*"일본" + -0.160*"비트코인" + -0.153*"가격" + 0.146*"경찰" + 0.142*"현장"'),
#  (19,
#   '0.421*"만원" + -0.332*"기술" + -0.170*"서울" + 0.158*"아이폰" + 0.140*"트럼프" + -0.134*"시장" + 0.131*"인상" + 0.128*"애플" + 0.117*"최저임금" + -0.114*"로봇"')]

# %%
lsimodel_mecab.show_topics(num_topics = 20)
# Out:
# [(0,
#   '0.292*"대통령" + 0.249*"선수" + 0.213*"한국" + 0.209*"경기" + 0.175*"정부" + 0.169*"중국" + 0.163*"미국" + 0.146*"서울" + 0.143*"대표" + 0.139*"감독"'),
#  (1,
#   '0.415*"대통령" + -0.408*"선수" + -0.389*"경기" + -0.220*"감독" + -0.199*"득점" + 0.148*"정부" + -0.144*"기록" + -0.111*"리그" + 0.100*"청와대" + 0.098*"검찰"'),
#  (2,
#   '-0.600*"대통령" + 0.207*"게임" + 0.169*"가상화폐" + -0.163*"경기" + 0.146*"중국" + 0.140*"비트코인" + -0.135*"검찰" + 0.133*"시장" + 0.131*"한국" + -0.129*"청와대"'),
#  (3,
#   '-0.490*"중국" + -0.356*"북한" + -0.275*"미국" + 0.212*"의원" + -0.187*"한국" + 0.179*"게임" + 0.168*"대표" + 0.155*"서울" + 0.150*"검찰" + 0.139*"수사"'),
#  (4,
#   '-0.840*"게임" + -0.196*"출처" + -0.160*"대통령" + -0.127*"꿀딴지" + 0.111*"가상화폐" + -0.105*"개발" + -0.099*"출시" + 0.093*"정부" + -0.088*"소개" + 0.084*"서울"'),
#  (5,
#   '0.452*"선수" + -0.367*"득점" + -0.303*"경기" + 0.215*"대표" + 0.169*"계약" + -0.140*"시티" + -0.136*"가상화폐" + -0.128*"기록" + 0.126*"의원" + 0.113*"구단"'),
#  (6,
#   '-0.343*"대표" + -0.303*"의원" + 0.288*"선수" + 0.256*"가상화폐" + 0.251*"대통령" + -0.215*"통합" + 0.201*"비트코인" + 0.176*"계약" + -0.172*"북한" + -0.171*"중국"'),
#  (7,
#   '-0.331*"대표" + -0.275*"가상화폐" + -0.248*"의원" + -0.205*"통합" + -0.204*"비트코인" + 0.167*"경찰" + -0.163*"거래소" + 0.156*"수사" + -0.147*"거래" + -0.141*"정부"'),
#  (8,
#   '-0.360*"한국" + -0.252*"감독" + -0.251*"중국" + 0.201*"미국" + -0.201*"일본" + -0.178*"검찰" + -0.171*"수사" + -0.171*"가상화폐" + 0.163*"북한" + 0.151*"계약"'),
#  (9,
#   '0.509*"북한" + -0.249*"한국" + -0.206*"대통령" + 0.174*"가상화폐" + 0.170*"김현정" + 0.170*"수사" + 0.167*"검찰" + -0.155*"임금" + -0.128*"감독" + 0.121*"의원"'),
#  (10,
#   '-0.386*"중국" + 0.345*"김현정" + 0.259*"북한" + -0.185*"검찰" + -0.183*"애플" + -0.163*"수사" + 0.162*"임금" + 0.161*"감독" + 0.160*"정부" + -0.150*"의원"'),
#  (11,
#   '0.746*"김현정" + 0.287*"중국" + -0.200*"북한" + -0.168*"감독" + -0.163*"서울" + 0.122*"말씀" + 0.105*"득점" + 0.100*"정두언" + 0.093*"의원" + 0.085*"시장"'),
#  (12,
#   '-0.346*"중국" + 0.289*"미국" + -0.240*"임금" + -0.239*"정부" + 0.234*"애플" + -0.190*"최저" + 0.183*"아이폰" + -0.179*"서울" + 0.163*"트럼프" + -0.156*"인상"'),
#  (13,
#   '0.255*"애플" + -0.216*"중국" + 0.196*"아이폰" + 0.170*"검찰" + -0.169*"방송" + 0.160*"한국" + 0.158*"수사" + 0.158*"임금" + 0.157*"김현정" + 0.149*"북한"'),
#  (14,
#   '-0.363*"한국" + -0.332*"득점" + -0.260*"일본" + 0.257*"중국" + 0.211*"감독" + -0.195*"쿼터" + 0.187*"손흥민" + 0.179*"토트넘" + -0.179*"리바운드" + 0.176*"시티"'),
#  (15,
#   '-0.346*"감독" + 0.235*"미국" + 0.211*"한국" + -0.200*"득점" + -0.199*"애플" + 0.165*"기록" + 0.160*"손흥민" + -0.159*"아이폰" + 0.144*"일본" + 0.132*"의원"'),
#  (16,
#   '-0.366*"임금" + -0.305*"미국" + -0.279*"최저" + -0.216*"인상" + 0.202*"정부" + -0.196*"트럼프" + 0.192*"서울" + 0.174*"일본" + 0.171*"애플" + -0.156*"감독"'),
#  (17,
#   '-0.368*"서울" + -0.204*"지역" + -0.178*"미국" + -0.161*"트럼프" + -0.155*"김현정" + -0.135*"정현" + 0.134*"방송" + 0.131*"북한" + 0.130*"임금" + -0.127*"이스라엘"'),
#  (18,
#   '-0.278*"서울" + -0.270*"비트코인" + 0.248*"기술" + 0.224*"정부" + -0.197*"애플" + -0.195*"한국" + -0.168*"아이폰" + -0.165*"북한" + -0.164*"가격" + 0.161*"감독"'),
#  (19,
#   '0.250*"시장" + -0.217*"애플" + 0.209*"기술" + -0.179*"사고" + -0.175*"화재" + -0.175*"아이폰" + 0.174*"서울" + -0.146*"가상화폐" + -0.142*"임금" + -0.134*"경찰"')]

# %%
lsitopics_ct = lsimodel_ct.show_topics(formatted = False)
lsitopics_mecab = lsimodel_mecab.show_topics(formatted = False)

# %% [markdown]
# ### HDP (Hierarchical Dirichlet Process)
# * a non-parametric bayesian method (note the missing number of requested topics)

# %%
# %%time
hdpmodel_ct_name = clusteringModelPath+'hdpmodel_ct'
hdpmodel_mecab_name = clusteringModelPath+'hdpmodel_mecab'
if not os.path.isfile(hdpmodel_ct_name):
    hdpmodel_ct = HdpModel(corpus = corpus_ct, id2word = dictionary_ct)
    hdpmodel_ct.save(clusteringModelPath+'hdpmodel_ct')
else:
    hdpmodel_ct = HdpModel.load(hdpmodel_ct_name)
if not os.path.isfile(hdpmodel_mecab_name):
    hdpmodel_mecab = HdpModel(corpus = corpus_mecab, id2word = dictionary_mecab)
    hdpmodel_mecab.save(clusteringModelPath+'hdpmodel_mecab')
else:
    hdpmodel_mecab = HdpModel.load(hdpmodel_mecab_name)
# Out:
# CPU times: user 3.07 s, sys: 4.11 s, total: 7.18 s
# Wall time: 16 s

# %%
hdpmodel_ct.show_topics()
# Out:
# [(0,
#   '0.004*선수 + 0.004*한국 + 0.004*서울 + 0.003*사진 + 0.003*적인 + 0.003*경기 + 0.003*대통령 + 0.003*미국 + 0.002*금지 + 0.002*중국 + 0.002*감독 + 0.002*정부 + 0.002*12 + 0.002*배포 + 0.002*무단 + 0.002*상황 + 0.002*대표 + 0.002*모습 + 0.002*20 + 0.002*전재'),
#  (1,
#   '0.007*대통령 + 0.005*정부 + 0.005*서울 + 0.005*북한 + 0.004*한국 + 0.003*중국 + 0.003*미국 + 0.003*사진 + 0.003*금지 + 0.003*적인 + 0.002*배포 + 0.002*무단 + 0.002*검찰 + 0.002*전재 + 0.002*12 + 0.002*대표 + 0.002*상황 + 0.002*혐의 + 0.002*조사 + 0.002*자들'),
#  (2,
#   '0.020*경기 + 0.013*손흥민 + 0.011*토트넘 + 0.010*감독 + 0.010*선수 + 0.008*한국 + 0.007*기록 + 0.006*맨유 + 0.006*리그 + 0.005*케인 + 0.005*2017 + 0.005*전반 + 0.005*이적 + 0.005*공격 + 0.005*득점 + 0.005*맨체스터 + 0.005*맨시티 + 0.004*축구 + 0.004*레알 + 0.004*라운드'),
#  (3,
#   '0.005*미국 + 0.005*북한 + 0.004*중국 + 0.004*정부 + 0.004*한국 + 0.004*예산 + 0.004*인상 + 0.003*지진 + 0.003*서울 + 0.003*대통령 + 0.003*규모 + 0.003*예산안 + 0.003*달러 + 0.003*원내대표 + 0.003*적인 + 0.003*의원 + 0.003*금지 + 0.003*금리 + 0.002*합의 + 0.002*경제'),
#  (4,
#   '0.026*영하 + 0.026*서울 + 0.023*기온 + 0.019*날씨 + 0.015*한파 + 0.015*추위 + 0.013*아침 + 0.012*전국 + 0.010*지역 + 0.007*도로 + 0.007*미세먼지 + 0.006*대구 + 0.006*강원 + 0.006*호남 + 0.006*대부분 + 0.005*최고 + 0.005*지방 + 0.005*바람 + 0.005*중부 + 0.005*건조'),
#  (5,
#   '0.005*의원 + 0.004*김현정 + 0.003*서울 + 0.003*정부 + 0.003*교수 + 0.002*한국 + 0.002*외상 + 0.002*금지 + 0.002*센터 + 0.002*정책 + 0.002*배포 + 0.002*원내대표 + 0.002*무단 + 0.002*방송 + 0.002*국회 + 0.002*학교 + 0.002*전재 + 0.002*환자 + 0.002*상황 + 0.002*예산'),
#  (6,
#   '0.004*선수 + 0.004*한국 + 0.003*감독 + 0.003*경기 + 0.003*무단 + 0.003*영화 + 0.002*SK텔레콤 + 0.002*교수 + 0.002*서울 + 0.002*연구 + 0.002*미국 + 0.002*기록 + 0.002*금지 + 0.002*상태 + 0.002*배포 + 0.002*전재 + 0.002*적인 + 0.002*롯데 + 0.002*경제 + 0.002*올림픽'),
#  (7,
#   '0.004*선수 + 0.004*한국 + 0.003*리그 + 0.003*식당 + 0.003*리즈 + 0.003*배우 + 0.003*로사리오 + 0.003*LG + 0.002*기록 + 0.002*투수 + 0.002*방송 + 0.002*사진 + 0.002*모습 + 0.002*보기 + 0.002*배포 + 0.002*무단 + 0.002*금지 + 0.002*전재 + 0.002*계약 + 0.002*오타니'),
#  (8,
#   '0.009*사고 + 0.006*해경 + 0.005*낚싯배 + 0.005*인천 + 0.005*구조 + 0.004*상황 + 0.004*선창 + 0.003*급유선 + 0.003*대통령 + 0.003*전복 + 0.003*선장 + 0.003*영흥도 + 0.003*15 + 0.003*서울 + 0.003*해상 + 0.003*충돌 + 0.002*김현정 + 0.002*미국 + 0.002*산불 + 0.002*북한'),
#  (9,
#   '0.008*사고 + 0.007*해경 + 0.005*낚싯배 + 0.005*인천 + 0.005*선창 + 0.004*구조 + 0.004*선장 + 0.004*급유선 + 0.003*해상 + 0.003*15 + 0.003*현장 + 0.003*충돌 + 0.003*미국 + 0.003*영흥도 + 0.002*전복 + 0.002*수색 + 0.002*대통령 + 0.002*명진 + 0.002*12 + 0.002*트럼프'),
#  (10,
#   '0.004*사진 + 0.004*비트코인 + 0.004*북한 + 0.004*미국 + 0.003*가상화폐 + 0.003*한국 + 0.003*투자 + 0.003*훈련 + 0.002*22 + 0.002*서울 + 0.002*무단 + 0.002*금지 + 0.002*배포 + 0.002*18 + 0.002*동사 + 0.002*촬영 + 0.002*교수 + 0.002*적인 + 0.001*논문 + 0.001*상황'),
#  (11,
#   '0.003*고용 + 0.003*파리바게뜨 + 0.003*직접 + 0.002*임신 + 0.002*사진 + 0.002*물가 + 0.002*서울 + 0.002*낙태죄 + 0.002*상승 + 0.002*제빵 + 0.002*사장 + 0.002*금지 + 0.002*여성 + 0.001*무단 + 0.001*노조 + 0.001*교수 + 0.001*방송 + 0.001*12 + 0.001*배포 + 0.001*조사'),
#  (12,
#   '0.002*감독 + 0.002*결혼 + 0.002*일본 + 0.002*머리 + 0.002*촉새 + 0.002*아스널 + 0.001*적인 + 0.001*줄리아 + 0.001*한국 + 0.001*무리뉴 + 0.001*왕실 + 0.001*금지 + 0.001*단장 + 0.001*피부 + 0.001*중국 + 0.001*선수 + 0.001*기술 + 0.001*이구 + 0.001*무단 + 0.001*배포'),
#  (13,
#   '0.007*트럼프 + 0.004*대통령 + 0.004*플린 + 0.003*이스라엘 + 0.003*미국 + 0.003*정부 + 0.003*러시아 + 0.002*예루살렘 + 0.002*수용 + 0.002*달러 + 0.002*개발 + 0.002*지역 + 0.002*특검 + 0.002*주민 + 0.002*쿠슈너 + 0.002*백악관 + 0.002*지구 + 0.001*진술 + 0.001*접촉 + 0.001*중동'),
#  (14,
#   '0.004*검찰 + 0.003*영어 + 0.003*할인 + 0.002*의원 + 0.002*멤버십 + 0.002*수사 + 0.002*수업 + 0.002*금지 + 0.002*서울 + 0.002*혐의 + 0.002*한국 + 0.002*특수 + 0.002*조사 + 0.002*국정원 + 0.002*경찰 + 0.002*사건 + 0.002*특활비 + 0.002*만원 + 0.001*방과후 + 0.001*혜택'),
#  (15,
#   '0.009*북한 + 0.008*화성 + 0.007*15 + 0.006*발사 + 0.005*미국 + 0.004*훈련 + 0.004*미사일 + 0.003*공군 + 0.003*기술 + 0.002*한국 + 0.002*엔진 + 0.002*한미 + 0.002*14 + 0.002*22 + 0.002*비행 + 0.002*타격 + 0.002*연합 + 0.002*분석 + 0.002*지방 + 0.002*압박'),
#  (16,
#   '0.004*러시아 + 0.004*비트코인 + 0.003*선수 + 0.003*세계 + 0.002*도핑 + 0.002*삼성 + 0.002*정성훈 + 0.002*미국 + 0.002*11 + 0.002*수당 + 0.002*아동 + 0.002*중국 + 0.002*스포츠 + 0.001*러시 + 0.001*금지 + 0.001*정부 + 0.001*올림픽 + 0.001*구단 + 0.001*한국 + 0.001*00'),
#  (17,
#   '0.005*로봇 + 0.004*펄서 + 0.003*연구 + 0.002*바퀴 + 0.002*혐의 + 0.002*수석 + 0.002*우주 + 0.002*적인 + 0.002*기술 + 0.002*블랙홀 + 0.002*교수 + 0.001*발견 + 0.001*중력파 + 0.001*자들 + 0.001*염기 + 0.001*분야 + 0.001*시스템 + 0.001*개발 + 0.001*검찰 + 0.001*구속영장'),
#  (18,
#   '0.003*리그 + 0.003*규제 + 0.003*LG + 0.003*포털 + 0.003*롯데 + 0.003*선수 + 0.002*경기 + 0.002*허프 + 0.002*계약 + 0.002*가와사키 + 0.002*린드블럼 + 0.002*재계약 + 0.002*리즈 + 0.002*외국인 + 0.002*일본 + 0.002*투수 + 0.002*정성룡 + 0.002*두산 + 0.001*구단 + 0.001*협상'),
#  (19,
#   '0.009*한국 + 0.007*월드컵 + 0.005*독일 + 0.004*포트 + 0.004*감독 + 0.004*러시아 + 0.004*스페인 + 0.003*경기 + 0.003*16 + 0.003*멕시코 + 0.003*본선 + 0.003*스웨덴 + 0.002*일본 + 0.002*상대 + 0.002*대회 + 0.002*축구 + 0.002*선수 + 0.002*랭킹 + 0.002*손흥민 + 0.002*신태용')]

# %%
hdpmodel_mecab.show_topics()
# Out:
# [(0,
#   '0.005*대통령 + 0.005*서울 + 0.004*정부 + 0.003*미국 + 0.003*중국 + 0.003*사진 + 0.003*한국 + 0.003*대표 + 0.003*금지 + 0.003*가능 + 0.002*무단 + 0.002*조사 + 0.002*북한 + 0.002*의원 + 0.002*재배포 + 0.002*시장 + 0.002*전재 + 0.002*상황 + 0.002*검찰 + 0.002*경찰'),
#  (1,
#   '0.013*선수 + 0.010*경기 + 0.007*감독 + 0.007*한국 + 0.005*계약 + 0.005*기록 + 0.004*사진 + 0.003*손흥민 + 0.003*리그 + 0.003*대표 + 0.003*모습 + 0.003*구단 + 0.003*상황 + 0.003*정현 + 0.003*일본 + 0.003*방송 + 0.003*가능 + 0.002*토트넘 + 0.002*영입 + 0.002*우승'),
#  (2,
#   '0.005*방송 + 0.004*무단 + 0.004*화유기 + 0.003*금지 + 0.003*사건 + 0.003*재배포 + 0.003*서울 + 0.003*드라마 + 0.003*영화 + 0.003*전재 + 0.002*사진 + 0.002*수사 + 0.002*손오공 + 0.002*혐의 + 0.002*사용 + 0.002*배우 + 0.002*진선미 + 0.002*SK텔레콤 + 0.002*검찰 + 0.002*이유'),
#  (3,
#   '0.008*한국 + 0.006*경기 + 0.006*감독 + 0.005*선수 + 0.005*맨유 + 0.004*호날두 + 0.004*월드컵 + 0.004*레알 + 0.004*독일 + 0.003*영입 + 0.003*마드리드 + 0.003*사진 + 0.003*기록 + 0.003*네이마르 + 0.003*스페인 + 0.003*금지 + 0.003*코치 + 0.002*무단 + 0.002*상대 + 0.002*재배포'),
#  (4,
#   '0.003*서울 + 0.003*교수 + 0.003*한국 + 0.003*사진 + 0.002*금지 + 0.002*증가 + 0.002*연구 + 0.002*발생 + 0.002*오타니 + 0.002*재배포 + 0.002*무단 + 0.002*선수 + 0.002*경기 + 0.002*전재 + 0.002*지진 + 0.002*소득 + 0.002*달러 + 0.002*기록 + 0.002*미국 + 0.002*가능'),
#  (5,
#   '0.029*영하 + 0.028*서울 + 0.027*기온 + 0.022*날씨 + 0.018*한파 + 0.015*아침 + 0.015*추위 + 0.014*전국 + 0.011*지역 + 0.008*지방 + 0.007*특보 + 0.007*서해안 + 0.007*중부 + 0.007*건조 + 0.007*도로 + 0.007*미세먼지 + 0.007*대구 + 0.007*시작 + 0.007*호남 + 0.007*최고'),
#  (6,
#   '0.004*미국 + 0.004*서울 + 0.004*김현정 + 0.004*대통령 + 0.003*택시 + 0.003*정부 + 0.003*이국종 + 0.002*금지 + 0.002*이스라엘 + 0.002*무단 + 0.002*트럼프 + 0.002*최승호 + 0.002*예루살렘 + 0.002*재배포 + 0.002*전재 + 0.002*조사 + 0.002*북한 + 0.002*교수 + 0.002*지역 + 0.002*대표'),
#  (7,
#   '0.006*계약 + 0.005*한국 + 0.004*선수 + 0.004*롯데 + 0.004*일본 + 0.004*린드블럼 + 0.003*감독 + 0.003*경기 + 0.003*로사리오 + 0.003*구단 + 0.003*투수 + 0.003*협상 + 0.003*달러 + 0.002*북한 + 0.002*리즈 + 0.002*미국 + 0.002*리그 + 0.002*금지 + 0.002*외국인 + 0.002*규제'),
#  (8,
#   '0.014*북한 + 0.008*발사 + 0.008*화성 + 0.008*미국 + 0.006*미사일 + 0.006*중국 + 0.004*가능 + 0.002*기술 + 0.002*한국 + 0.002*정보 + 0.002*압박 + 0.002*금지 + 0.002*대북 + 0.002*화장실 + 0.002*평가 + 0.002*사용 + 0.002*제재 + 0.002*재진입 + 0.002*분석 + 0.002*보도'),
#  (9,
#   '0.004*대통령 + 0.004*미국 + 0.004*교수 + 0.003*사진 + 0.003*서울 + 0.002*로봇 + 0.002*음악 + 0.002*방탄소년단 + 0.002*시장 + 0.002*트럼프 + 0.002*북한 + 0.002*연구 + 0.002*상황 + 0.001*그룹 + 0.001*스마트폰 + 0.001*분석 + 0.001*정부 + 0.001*한국 + 0.001*시작 + 0.001*대표'),
#  (10,
#   '0.003*영하 + 0.003*서울 + 0.002*탈모 + 0.002*사진 + 0.002*북한 + 0.002*금지 + 0.002*조사 + 0.002*기온 + 0.002*무단 + 0.002*재배포 + 0.002*전재 + 0.002*배터리 + 0.002*모습 + 0.002*미국 + 0.002*백제 + 0.001*혐의 + 0.001*지진 + 0.001*강정호 + 0.001*날씨 + 0.001*지역'),
#  (11,
#   '0.008*북한 + 0.006*주택 + 0.004*중국 + 0.004*미국 + 0.004*대통령 + 0.003*훈련 + 0.003*연금 + 0.003*에너지 + 0.003*주거 + 0.002*가능 + 0.002*서울 + 0.002*공군 + 0.002*임대 + 0.002*정부 + 0.002*매입 + 0.002*전투기 + 0.002*셰어하우스 + 0.002*한반도 + 0.002*트럼프 + 0.002*한미'),
#  (12,
#   '0.003*브로드컴 + 0.003*인수 + 0.003*선수 + 0.003*미국 + 0.002*퀄컴 + 0.002*기업 + 0.002*한국 + 0.002*서울 + 0.002*반도체 + 0.002*배우 + 0.002*감독 + 0.002*삼성 + 0.002*트럼프 + 0.002*가능 + 0.002*사업 + 0.002*중국 + 0.002*대통령 + 0.002*야구 + 0.002*스포츠 + 0.001*업계'),
#  (13,
#   '0.007*가상화폐 + 0.005*투자 + 0.003*김현정 + 0.002*윤계상 + 0.002*서민정 + 0.002*강민호 + 0.002*유포자 + 0.002*선수 + 0.002*롯데 + 0.002*이방인 + 0.002*투자자 + 0.002*소장 + 0.002*미국 + 0.002*비케이 + 0.002*정관용 + 0.002*대통령 + 0.001*정부 + 0.001*한국 + 0.001*사진 + 0.001*거래소'),
#  (14,
#   '0.010*월드컵 + 0.009*독일 + 0.008*한국 + 0.008*경기 + 0.007*스웨덴 + 0.006*멕시코 + 0.005*감독 + 0.005*상대 + 0.005*선수 + 0.004*러시아 + 0.004*대표 + 0.003*대회 + 0.003*본선 + 0.003*축구 + 0.003*유럽 + 0.002*전술 + 0.002*예선 + 0.002*준비 + 0.002*우승 + 0.002*지진'),
#  (15,
#   '0.003*특수 + 0.003*검찰 + 0.003*변호사 + 0.002*예루살렘 + 0.002*대통령 + 0.002*이스라엘 + 0.002*활동비 + 0.002*트럼프 + 0.002*미국 + 0.002*조사 + 0.002*국정원 + 0.002*사용 + 0.002*여단 + 0.002*연구 + 0.002*수사 + 0.001*혐의 + 0.001*인정 + 0.001*서울 + 0.001*대사관 + 0.001*이전'),
#  (16,
#   '0.003*의원 + 0.002*정관용 + 0.002*합의 + 0.002*사고 + 0.002*예산안 + 0.002*공무원 + 0.002*서울 + 0.002*증원 + 0.002*윤민 + 0.002*태연 + 0.002*국가 + 0.002*곽수종 + 0.002*정부 + 0.002*총회 + 0.002*기관사 + 0.002*금지 + 0.002*상황 + 0.002*처리 + 0.002*안진걸 + 0.002*여야'),
#  (17,
#   '0.006*의원 + 0.005*검찰 + 0.004*혐의 + 0.003*구속 + 0.003*서울 + 0.002*국정원 + 0.002*출석 + 0.002*국회 + 0.002*무한도전 + 0.002*국민 + 0.002*조사 + 0.002*특수 + 0.001*주장 + 0.001*차관 + 0.001*예능 + 0.001*강식당 + 0.001*강호동 + 0.001*최씨 + 0.001*영재센터 + 0.001*사진'),
#  (18,
#   '0.004*멤버 + 0.004*무한도전 + 0.003*박명수 + 0.003*수능 + 0.003*모습 + 0.002*예산 + 0.002*유재석 + 0.002*조세호 + 0.002*상승 + 0.002*물가 + 0.002*방송 + 0.002*파퀴아오 + 0.002*양세형 + 0.002*영역 + 0.002*공개 + 0.002*코빅 + 0.002*예능 + 0.001*도전 + 0.001*대표 + 0.001*점수'),
#  (19,
#   '0.004*사진 + 0.002*예루살렘 + 0.002*시민 + 0.002*혐의 + 0.002*트럼프 + 0.002*촬영 + 0.002*사진첩 + 0.002*대통령 + 0.002*이스라엘 + 0.001*한국 + 0.001*할머니 + 0.001*계엄군 + 0.001*금지 + 0.001*어머니 + 0.001*수도 + 0.001*대사관 + 0.001*미국 + 0.001*조사 + 0.001*이유 + 0.001*국제')]

# %%
hdptopics_ct = hdpmodel_ct.show_topics(formatted = False)
hdptopics_mecab = hdpmodel_mecab.show_topics(formatted = False)

# %% [markdown]
# ### LDA (Latent Dirichlet allocation)
# * a generative statistical model that allows sets of observations to be explained by unobserved groups that explain why some parts of the data are similar

# %% [markdown]
# #### LDA model1
# * basic

# %%
pyLDAvis.enable_notebook()

# %%
pl_ct = PerplexityMetric(corpus = corpus_ct, logger = 'shell', 
                        title = 'Perplexity (twitter)')
ch_umass_ct = CoherenceMetric(corpus = corpus_ct, coherence = 'u_mass', 
                             logger = 'shell', title = ' Coherence (u_mass)')
ch_cv_ct = CoherenceMetric(corpus = corpus_ct, logger = 'shell', 
                          texts = tagged_text_ct, coherence = 'c_v', 
                          title = 'Coherence (c_v)')
diff_kl_ct = DiffMetric(distance = 'kullback_leibler', 
                       logger = 'shell', title = 'Diff (kullback_leibler)')
convergence_kl_ct = ConvergenceMetric(distance = 'jaccard', logger = 'shell', 
                                     title = 'Convergence (jaccard)')
callbacks_ct = [pl_ct, ch_umass_ct, ch_cv_ct, diff_kl_ct, convergence_kl_ct]

# %%
# %%time
logging.basicConfig(level = logging.INFO)
logger = logging.getLogger(__name__)
logger.setLevel(logging.DEBUG)
ldamodel_ct_name = clusteringModelPath + 'ldamodel_ct'
if not os.path.isfile(ldamodel_ct_name):
    ldamodel_ct = LdaModel(corpus = corpus_ct, num_topics = 20,
                           id2word = dictionary_ct, passes = 25,
                           chunksize = 6123, iterations = 125,
                           alpha='symmetric', callbacks = callbacks_ct)
    ldamodel_ct.save(ldamodel_ct_name)
else:
    ldamodel_ct = LdaModel.load(ldamodel_ct_name)
# Out:
# INFO:gensim.models.ldamodel:using symmetric alpha at 0.05
# INFO:gensim.models.ldamodel:using symmetric eta at 0.05
# INFO:gensim.models.ldamodel:using serial LDA version on this node
# INFO:gensim.models.ldamodel:running online (multi-pass) LDA training, 20 topics, 25 passes over the supplied corpus of 24492 documents, updating model once every 6123 documents, evaluating perplexity every 24492 documents, iterating 125x with a convergence threshold of 0.001000
# INFO:gensim.models.ldamodel:PROGRESS: pass 0, at document #6123/24492
# INFO:gensim.models.ldamodel:merging changes from 6123 documents into a model of 24492 documents
# INFO:gensim.models.ldamodel:topic #2 (0.050): 0.009*"아이폰" + 0.008*"사고" + 0.007*"애플" + 0.004*"배포" + 0.004*"무단" + 0.004*"경기" + 0.004*"금지" + 0.003*"전재" + 0.003*"미국" + 0.003*"배터리"
# INFO:gensim.models.ldamodel:topic #5 (0.050): 0.008*"중국" + 0.005*"대통령" + 0.005*"미국" + 0.004*"한국" + 0.004*"경기" + 0.003*"금지" + 0.003*"보기" + 0.003*"지역" + 0.003*"서울" + 0.003*"북한"
# INFO:gensim.models.ldamodel:topic #6 (0.050): 0.008*"서울" + 0.005*"북한" + 0.005*"대통령" + 0.004*"병원" + 0.004*"한국" + 0.003*"12" + 0.003*"미국" + 0.003*"금지" + 0.003*"무단" + 0.003*"적인"
# INFO:gensim.models.ldamodel:topic #16 (0.050): 0.006*"정부" + 0.005*"한국" + 0.005*"비트코인" + 0.004*"가격" + 0.004*"미국" + 0.004*"서울" + 0.004*"무단" + 0.004*"사진" + 0.004*"가상화폐" + 0.004*"거래"
# INFO:gensim.models.ldamodel:topic #14 (0.050): 0.007*"대통령" + 0.006*"미국" + 0.005*"이스라엘" + 0.005*"비트코인" + 0.004*"금지" + 0.004*"트럼프" + 0.004*"중국" + 0.004*"예루살렘" + 0.004*"정부" + 0.004*"배포"
# INFO:gensim.models.ldamodel:topic diff=15.323494, rho=1.000000
# INFO:gensim.models.ldamodel:PROGRESS: pass 0, at document #12246/24492
# INFO:gensim.models.ldamodel:merging changes from 6123 documents into a model of 24492 documents
# INFO:gensim.models.ldamodel:topic #12 (0.050): 0.016*"북한" + 0.005*"사진" + 0.005*"대통령" + 0.005*"미국" + 0.004*"정부" + 0.004*"인텔" + 0.004*"일본" + 0.004*"적인" + 0.004*"한국" + 0.003*"대화"
# INFO:gensim.models.ldamodel:topic #10 (0.050): 0.008*"화재" + 0.004*"제천" + 0.004*"12" + 0.004*"사진" + 0.003*"만원" + 0.003*"서울" + 0.003*"11" + 0.003*"배포" + 0.003*"2017" + 0.003*"금지"
# INFO:gensim.models.ldamodel:topic #3 (0.050): 0.013*"선수" + 0.005*"LG" + 0.004*"투수" + 0.004*"건물" + 0.004*"구단" + 0.004*"서울" + 0.004*"경기" + 0.004*"롯데" + 0.004*"차량" + 0.004*"두산"
# INFO:gensim.models.ldamodel:topic #9 (0.050): 0.006*"아파트" + 0.006*"대표" + 0.005*"서울" + 0.004*"정부" + 0.004*"의원" + 0.004*"배포" + 0.004*"금지" + 0.003*"김현정" + 0.003*"페이스북" + 0.003*"무단"
# INFO:gensim.models.ldamodel:topic #8 (0.050): 0.006*"인상" + 0.005*"기업" + 0.005*"정부" + 0.005*"서울" + 0.005*"중국" + 0.005*"가격" + 0.005*"시장" + 0.004*"업체" + 0.004*"최저임금" + 0.004*"적인"
# INFO:gensim.models.ldamodel:topic diff=1.982215, rho=0.707107
# INFO:gensim.models.ldamodel:PROGRESS: pass 0, at document #18369/24492
# INFO:gensim.models.ldamodel:merging changes from 6123 documents into a model of 24492 documents
# INFO:gensim.models.ldamodel:topic #10 (0.050): 0.017*"화재" + 0.005*"제천" + 0.005*"현장" + 0.005*"참사" + 0.004*"건물" + 0.004*"경찰" + 0.004*"사진" + 0.004*"병원" + 0.004*"발생" + 0.004*"서울"
# INFO:gensim.models.ldamodel:topic #3 (0.050): 0.024*"선수" + 0.008*"계약" + 0.008*"구단" + 0.007*"투수" + 0.007*"LG" + 0.006*"두산" + 0.006*"롯데" + 0.006*"경기" + 0.005*"기록" + 0.005*"리그"
# INFO:gensim.models.ldamodel:topic #13 (0.050): 0.013*"감독" + 0.013*"경기" + 0.011*"한국" + 0.011*"일본" + 0.011*"중국" + 0.010*"선수" + 0.005*"축구" + 0.005*"북한" + 0.005*"적인" + 0.005*"미국"
# INFO:gensim.models.ldamodel:topic #7 (0.050): 0.010*"손흥민" + 0.010*"경기" + 0.006*"한국" + 0.006*"선수" + 0.005*"토트넘" + 0.004*"레알" + 0.004*"감독" + 0.004*"득점" + 0.003*"사진" + 0.003*"기록"
# INFO:gensim.models.ldamodel:topic #12 (0.050): 0.020*"북한" + 0.005*"사진" + 0.005*"일본" + 0.005*"미국" + 0.005*"대통령" + 0.004*"정부" + 0.004*"한국" + 0.004*"적인" + 0.004*"대화" + 0.003*"대표"
# INFO:gensim.models.ldamodel:topic diff=1.479572, rho=0.577350
# INFO:gensim.models.ldamodel:-9.292 per-word bound, 626.7 perplexity estimate based on a held-out corpus of 6123 documents with 1147178 words
# INFO:gensim.models.ldamodel:PROGRESS: pass 0, at document #24492/24492
# INFO:gensim.models.ldamodel:merging changes from 6123 documents into a model of 24492 documents
# INFO:gensim.models.ldamodel:topic #13 (0.050): 0.018*"감독" + 0.016*"경기" + 0.015*"선수" + 0.013*"한국" + 0.008*"일본" + 0.008*"베트남" + 0.007*"중국" + 0.007*"축구" + 0.006*"이적" + 0.006*"출전"
# INFO:gensim.models.ldamodel:topic #14 (0.050): 0.015*"미국" + 0.013*"대통령" + 0.012*"트럼프" + 0.008*"정부" + 0.004*"달러" + 0.004*"중국" + 0.004*"국가" + 0.004*"한국" + 0.003*"금지" + 0.003*"경제"
# INFO:gensim.models.ldamodel:topic #10 (0.050): 0.019*"화재" + 0.007*"현장" + 0.006*"제천" + 0.006*"경찰" + 0.006*"건물" + 0.005*"참사" + 0.005*"병원" + 0.005*"사진" + 0.004*"발생" + 0.004*"소방"
# INFO:gensim.models.ldamodel:topic #12 (0.050): 0.022*"북한" + 0.006*"사진" + 0.005*"미국" + 0.005*"일본" + 0.005*"대통령" + 0.004*"정부" + 0.004*"올림픽" + 0.004*"적인" + 0.004*"남북" + 0.004*"한국"
# INFO:gensim.models.ldamodel:topic #17 (0.050): 0.016*"코치" + 0.013*"한국" + 0.006*"터미널" + 0.005*"로봇" + 0.004*"감독" + 0.003*"인천공항" + 0.003*"세계" + 0.003*"심판" + 0.003*"공항" + 0.003*"선수"
# INFO:gensim.models.ldamodel:topic diff=1.233046, rho=0.500000
# INFO:gensim.models.ldamodel:Epoch 0: Perplexity (twitter) estimate: 441.93503702029335
# INFO:gensim.topic_coherence.text_analysis:CorpusAccumulator accumulated stats from 1000 documents
# INFO:gensim.topic_coherence.text_analysis:CorpusAccumulator accumulated stats from 2000 documents
# INFO:gensim.topic_coherence.text_analysis:CorpusAccumulator accumulated stats from 3000 documents
# INFO:gensim.topic_coherence.text_analysis:CorpusAccumulator accumulated stats from 4000 documents
# INFO:gensim.topic_coherence.text_analysis:CorpusAccumulator accumulated stats from 5000 documents
# INFO:gensim.topic_coherence.text_analysis:CorpusAccumulator accumulated stats from 6000 documents
# INFO:gensim.topic_coherence.text_analysis:CorpusAccumulator accumulated stats from 7000 documents
# INFO:gensim.topic_coherence.text_analysis:CorpusAccumulator accumulated stats from 8000 documents
# INFO:gensim.topic_coherence.text_analysis:CorpusAccumulator accumulated stats from 9000 documents
# INFO:gensim.topic_coherence.text_analysis:CorpusAccumulator accumulated stats from 10000 documents
# INFO:gensim.topic_coherence.text_analysis:CorpusAccumulator accumulated stats from 11000 documents
# INFO:gensim.topic_coherence.text_analysis:CorpusAccumulator accumulated stats from 12000 documents
# INFO:gensim.topic_coherence.text_analysis:CorpusAccumulator accumulated stats from 13000 documents
# INFO:gensim.topic_coherence.text_analysis:CorpusAccumulator accumulated stats from 14000 documents
# INFO:gensim.topic_coherence.text_analysis:CorpusAccumulator accumulated stats from 15000 documents
# INFO:gensim.topic_coherence.text_analysis:CorpusAccumulator accumulated stats from 16000 documents
# INFO:gensim.topic_coherence.text_analysis:CorpusAccumulator accumulated stats from 17000 documents
# INFO:gensim.topic_coherence.text_analysis:CorpusAccumulator accumulated stats from 18000 documents
# INFO:gensim.topic_coherence.text_analysis:CorpusAccumulator accumulated stats from 19000 documents
# INFO:gensim.topic_coherence.text_analysis:CorpusAccumulator accumulated stats from 20000 documents
# INFO:gensim.topic_coherence.text_analysis:CorpusAccumulator accumulated stats from 21000 documents
# INFO:gensim.topic_coherence.text_analysis:CorpusAccumulator accumulated stats from 22000 documents
# INFO:gensim.topic_coherence.text_analysis:CorpusAccumulator accumulated stats from 23000 documents
# INFO:gensim.topic_coherence.text_analysis:CorpusAccumulator accumulated stats from 24000 documents
# INFO:gensim.models.ldamodel:Epoch 0:  Coherence (u_mass) estimate: -2.3377858909175373
# INFO:gensim.topic_coherence.probability_estimation:using ParallelWordOccurrenceAccumulator(processes=3, batch_size=64) to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:1 batches submitted to accumulate stats from 64 documents (9129 virtual)
# INFO:gensim.topic_coherence.text_analysis:2 batches submitted to accumulate stats from 128 documents (18554 virtual)
# INFO:gensim.topic_coherence.text_analysis:3 batches submitted to accumulate stats from 192 documents (27590 virtual)
# INFO:gensim.topic_coherence.text_analysis:4 batches submitted to accumulate stats from 256 documents (34549 virtual)
# INFO:gensim.topic_coherence.text_analysis:5 batches submitted to accumulate stats from 320 documents (41954 virtual)
# INFO:gensim.topic_coherence.text_analysis:6 batches submitted to accumulate stats from 384 documents (48847 virtual)
# INFO:gensim.topic_coherence.text_analysis:7 batches submitted to accumulate stats from 448 documents (56630 virtual)
# INFO:gensim.topic_coherence.text_analysis:8 batches submitted to accumulate stats from 512 documents (66241 virtual)
# INFO:gensim.topic_coherence.text_analysis:9 batches submitted to accumulate stats from 576 documents (76294 virtual)
# INFO:gensim.topic_coherence.text_analysis:10 batches submitted to accumulate stats from 640 documents (84665 virtual)
# INFO:gensim.topic_coherence.text_analysis:11 batches submitted to accumulate stats from 704 documents (91512 virtual)
# INFO:gensim.topic_coherence.text_analysis:12 batches submitted to accumulate stats from 768 documents (100662 virtual)
# INFO:gensim.topic_coherence.text_analysis:13 batches submitted to accumulate stats from 832 documents (111786 virtual)
# INFO:gensim.topic_coherence.text_analysis:14 batches submitted to accumulate stats from 896 documents (119522 virtual)
# INFO:gensim.topic_coherence.text_analysis:15 batches submitted to accumulate stats from 960 documents (124942 virtual)
# INFO:gensim.topic_coherence.text_analysis:16 batches submitted to accumulate stats from 1024 documents (133667 virtual)
# INFO:gensim.topic_coherence.text_analysis:17 batches submitted to accumulate stats from 1088 documents (142374 virtual)
# INFO:gensim.topic_coherence.text_analysis:18 batches submitted to accumulate stats from 1152 documents (150774 virtual)
# INFO:gensim.topic_coherence.text_analysis:19 batches submitted to accumulate stats from 1216 documents (157177 virtual)
# INFO:gensim.topic_coherence.text_analysis:20 batches submitted to accumulate stats from 1280 documents (167698 virtual)
# INFO:gensim.topic_coherence.text_analysis:21 batches submitted to accumulate stats from 1344 documents (174557 virtual)
# INFO:gensim.topic_coherence.text_analysis:22 batches submitted to accumulate stats from 1408 documents (182585 virtual)
# INFO:gensim.topic_coherence.text_analysis:23 batches submitted to accumulate stats from 1472 documents (190568 virtual)
# INFO:gensim.topic_coherence.text_analysis:24 batches submitted to accumulate stats from 1536 documents (202292 virtual)
# INFO:gensim.topic_coherence.text_analysis:25 batches submitted to accumulate stats from 1600 documents (209087 virtual)
# INFO:gensim.topic_coherence.text_analysis:26 batches submitted to accumulate stats from 1664 documents (214856 virtual)
# INFO:gensim.topic_coherence.text_analysis:27 batches submitted to accumulate stats from 1728 documents (223008 virtual)
# INFO:gensim.topic_coherence.text_analysis:28 batches submitted to accumulate stats from 1792 documents (231665 virtual)
# INFO:gensim.topic_coherence.text_analysis:29 batches submitted to accumulate stats from 1856 documents (240526 virtual)
# INFO:gensim.topic_coherence.text_analysis:30 batches submitted to accumulate stats from 1920 documents (245325 virtual)
# INFO:gensim.topic_coherence.text_analysis:31 batches submitted to accumulate stats from 1984 documents (257138 virtual)
# INFO:gensim.topic_coherence.text_analysis:32 batches submitted to accumulate stats from 2048 documents (267762 virtual)
# INFO:gensim.topic_coherence.text_analysis:33 batches submitted to accumulate stats from 2112 documents (275856 virtual)
# INFO:gensim.topic_coherence.text_analysis:34 batches submitted to accumulate stats from 2176 documents (282430 virtual)
# INFO:gensim.topic_coherence.text_analysis:35 batches submitted to accumulate stats from 2240 documents (290925 virtual)
# INFO:gensim.topic_coherence.text_analysis:36 batches submitted to accumulate stats from 2304 documents (300259 virtual)
# INFO:gensim.topic_coherence.text_analysis:37 batches submitted to accumulate stats from 2368 documents (306140 virtual)
# INFO:gensim.topic_coherence.text_analysis:38 batches submitted to accumulate stats from 2432 documents (314235 virtual)
# INFO:gensim.topic_coherence.text_analysis:39 batches submitted to accumulate stats from 2496 documents (324475 virtual)
# INFO:gensim.topic_coherence.text_analysis:40 batches submitted to accumulate stats from 2560 documents (332618 virtual)
# INFO:gensim.topic_coherence.text_analysis:41 batches submitted to accumulate stats from 2624 documents (338108 virtual)
# INFO:gensim.topic_coherence.text_analysis:42 batches submitted to accumulate stats from 2688 documents (346988 virtual)
# INFO:gensim.topic_coherence.text_analysis:43 batches submitted to accumulate stats from 2752 documents (355406 virtual)
# INFO:gensim.topic_coherence.text_analysis:44 batches submitted to accumulate stats from 2816 documents (362764 virtual)
# INFO:gensim.topic_coherence.text_analysis:45 batches submitted to accumulate stats from 2880 documents (368344 virtual)
# INFO:gensim.topic_coherence.text_analysis:46 batches submitted to accumulate stats from 2944 documents (378327 virtual)
# INFO:gensim.topic_coherence.text_analysis:47 batches submitted to accumulate stats from 3008 documents (385787 virtual)
# INFO:gensim.topic_coherence.text_analysis:48 batches submitted to accumulate stats from 3072 documents (391806 virtual)
# INFO:gensim.topic_coherence.text_analysis:49 batches submitted to accumulate stats from 3136 documents (397310 virtual)
# INFO:gensim.topic_coherence.text_analysis:50 batches submitted to accumulate stats from 3200 documents (406938 virtual)
# INFO:gensim.topic_coherence.text_analysis:51 batches submitted to accumulate stats from 3264 documents (413005 virtual)
# INFO:gensim.topic_coherence.text_analysis:52 batches submitted to accumulate stats from 3328 documents (417372 virtual)
# INFO:gensim.topic_coherence.text_analysis:53 batches submitted to accumulate stats from 3392 documents (425374 virtual)
# INFO:gensim.topic_coherence.text_analysis:54 batches submitted to accumulate stats from 3456 documents (434538 virtual)
# INFO:gensim.topic_coherence.text_analysis:55 batches submitted to accumulate stats from 3520 documents (442865 virtual)
# INFO:gensim.topic_coherence.text_analysis:56 batches submitted to accumulate stats from 3584 documents (448921 virtual)
# INFO:gensim.topic_coherence.text_analysis:57 batches submitted to accumulate stats from 3648 documents (458445 virtual)
# INFO:gensim.topic_coherence.text_analysis:58 batches submitted to accumulate stats from 3712 documents (467292 virtual)
# INFO:gensim.topic_coherence.text_analysis:59 batches submitted to accumulate stats from 3776 documents (475697 virtual)
# INFO:gensim.topic_coherence.text_analysis:60 batches submitted to accumulate stats from 3840 documents (481972 virtual)
# INFO:gensim.topic_coherence.text_analysis:61 batches submitted to accumulate stats from 3904 documents (492633 virtual)
# INFO:gensim.topic_coherence.text_analysis:62 batches submitted to accumulate stats from 3968 documents (500620 virtual)
# INFO:gensim.topic_coherence.text_analysis:63 batches submitted to accumulate stats from 4032 documents (508051 virtual)
# INFO:gensim.topic_coherence.text_analysis:64 batches submitted to accumulate stats from 4096 documents (517975 virtual)
# INFO:gensim.topic_coherence.text_analysis:65 batches submitted to accumulate stats from 4160 documents (528078 virtual)
# INFO:gensim.topic_coherence.text_analysis:66 batches submitted to accumulate stats from 4224 documents (534617 virtual)
# INFO:gensim.topic_coherence.text_analysis:67 batches submitted to accumulate stats from 4288 documents (541770 virtual)
# INFO:gensim.topic_coherence.text_analysis:68 batches submitted to accumulate stats from 4352 documents (549932 virtual)
# INFO:gensim.topic_coherence.text_analysis:69 batches submitted to accumulate stats from 4416 documents (559434 virtual)
# INFO:gensim.topic_coherence.text_analysis:70 batches submitted to accumulate stats from 4480 documents (569287 virtual)
# INFO:gensim.topic_coherence.text_analysis:71 batches submitted to accumulate stats from 4544 documents (577052 virtual)
# INFO:gensim.topic_coherence.text_analysis:72 batches submitted to accumulate stats from 4608 documents (587115 virtual)
# INFO:gensim.topic_coherence.text_analysis:73 batches submitted to accumulate stats from 4672 documents (596078 virtual)
# INFO:gensim.topic_coherence.text_analysis:74 batches submitted to accumulate stats from 4736 documents (604725 virtual)
# INFO:gensim.topic_coherence.text_analysis:75 batches submitted to accumulate stats from 4800 documents (609309 virtual)
# INFO:gensim.topic_coherence.text_analysis:76 batches submitted to accumulate stats from 4864 documents (616860 virtual)
# INFO:gensim.topic_coherence.text_analysis:77 batches submitted to accumulate stats from 4928 documents (623923 virtual)
# INFO:gensim.topic_coherence.text_analysis:78 batches submitted to accumulate stats from 4992 documents (632471 virtual)
# INFO:gensim.topic_coherence.text_analysis:79 batches submitted to accumulate stats from 5056 documents (642579 virtual)
# INFO:gensim.topic_coherence.text_analysis:80 batches submitted to accumulate stats from 5120 documents (651545 virtual)
# INFO:gensim.topic_coherence.text_analysis:81 batches submitted to accumulate stats from 5184 documents (658841 virtual)
# INFO:gensim.topic_coherence.text_analysis:82 batches submitted to accumulate stats from 5248 documents (667472 virtual)
# INFO:gensim.topic_coherence.text_analysis:83 batches submitted to accumulate stats from 5312 documents (678933 virtual)
# INFO:gensim.topic_coherence.text_analysis:84 batches submitted to accumulate stats from 5376 documents (687876 virtual)
# INFO:gensim.topic_coherence.text_analysis:85 batches submitted to accumulate stats from 5440 documents (694054 virtual)
# INFO:gensim.topic_coherence.text_analysis:86 batches submitted to accumulate stats from 5504 documents (698465 virtual)
# INFO:gensim.topic_coherence.text_analysis:87 batches submitted to accumulate stats from 5568 documents (707747 virtual)
# INFO:gensim.topic_coherence.text_analysis:88 batches submitted to accumulate stats from 5632 documents (715941 virtual)
# INFO:gensim.topic_coherence.text_analysis:89 batches submitted to accumulate stats from 5696 documents (725823 virtual)
# INFO:gensim.topic_coherence.text_analysis:90 batches submitted to accumulate stats from 5760 documents (733249 virtual)
# INFO:gensim.topic_coherence.text_analysis:91 batches submitted to accumulate stats from 5824 documents (743088 virtual)
# INFO:gensim.topic_coherence.text_analysis:92 batches submitted to accumulate stats from 5888 documents (749950 virtual)
# INFO:gensim.topic_coherence.text_analysis:93 batches submitted to accumulate stats from 5952 documents (757044 virtual)
# INFO:gensim.topic_coherence.text_analysis:94 batches submitted to accumulate stats from 6016 documents (763314 virtual)
# INFO:gensim.topic_coherence.text_analysis:95 batches submitted to accumulate stats from 6080 documents (772847 virtual)
# INFO:gensim.topic_coherence.text_analysis:96 batches submitted to accumulate stats from 6144 documents (779392 virtual)
# INFO:gensim.topic_coherence.text_analysis:97 batches submitted to accumulate stats from 6208 documents (786001 virtual)
# INFO:gensim.topic_coherence.text_analysis:98 batches submitted to accumulate stats from 6272 documents (799785 virtual)
# INFO:gensim.topic_coherence.text_analysis:99 batches submitted to accumulate stats from 6336 documents (809520 virtual)
# INFO:gensim.topic_coherence.text_analysis:100 batches submitted to accumulate stats from 6400 documents (817152 virtual)
# INFO:gensim.topic_coherence.text_analysis:101 batches submitted to accumulate stats from 6464 documents (821897 virtual)
# INFO:gensim.topic_coherence.text_analysis:102 batches submitted to accumulate stats from 6528 documents (831888 virtual)
# INFO:gensim.topic_coherence.text_analysis:103 batches submitted to accumulate stats from 6592 documents (840667 virtual)
# INFO:gensim.topic_coherence.text_analysis:104 batches submitted to accumulate stats from 6656 documents (846631 virtual)
# INFO:gensim.topic_coherence.text_analysis:105 batches submitted to accumulate stats from 6720 documents (851945 virtual)
# INFO:gensim.topic_coherence.text_analysis:106 batches submitted to accumulate stats from 6784 documents (860774 virtual)
# INFO:gensim.topic_coherence.text_analysis:107 batches submitted to accumulate stats from 6848 documents (866670 virtual)
# INFO:gensim.topic_coherence.text_analysis:108 batches submitted to accumulate stats from 6912 documents (873263 virtual)
# INFO:gensim.topic_coherence.text_analysis:109 batches submitted to accumulate stats from 6976 documents (880653 virtual)
# INFO:gensim.topic_coherence.text_analysis:110 batches submitted to accumulate stats from 7040 documents (887677 virtual)
# INFO:gensim.topic_coherence.text_analysis:111 batches submitted to accumulate stats from 7104 documents (892026 virtual)
# INFO:gensim.topic_coherence.text_analysis:112 batches submitted to accumulate stats from 7168 documents (898192 virtual)
# INFO:gensim.topic_coherence.text_analysis:113 batches submitted to accumulate stats from 7232 documents (909081 virtual)
# INFO:gensim.topic_coherence.text_analysis:114 batches submitted to accumulate stats from 7296 documents (916031 virtual)
# INFO:gensim.topic_coherence.text_analysis:115 batches submitted to accumulate stats from 7360 documents (923068 virtual)
# INFO:gensim.topic_coherence.text_analysis:116 batches submitted to accumulate stats from 7424 documents (928925 virtual)
# INFO:gensim.topic_coherence.text_analysis:117 batches submitted to accumulate stats from 7488 documents (940703 virtual)
# INFO:gensim.topic_coherence.text_analysis:118 batches submitted to accumulate stats from 7552 documents (947811 virtual)
# INFO:gensim.topic_coherence.text_analysis:119 batches submitted to accumulate stats from 7616 documents (955471 virtual)
# INFO:gensim.topic_coherence.text_analysis:120 batches submitted to accumulate stats from 7680 documents (964418 virtual)
# INFO:gensim.topic_coherence.text_analysis:121 batches submitted to accumulate stats from 7744 documents (973121 virtual)
# INFO:gensim.topic_coherence.text_analysis:122 batches submitted to accumulate stats from 7808 documents (981300 virtual)
# INFO:gensim.topic_coherence.text_analysis:123 batches submitted to accumulate stats from 7872 documents (988996 virtual)
# INFO:gensim.topic_coherence.text_analysis:124 batches submitted to accumulate stats from 7936 documents (995301 virtual)
# INFO:gensim.topic_coherence.text_analysis:125 batches submitted to accumulate stats from 8000 documents (1003031 virtual)
# INFO:gensim.topic_coherence.text_analysis:126 batches submitted to accumulate stats from 8064 documents (1012029 virtual)
# INFO:gensim.topic_coherence.text_analysis:127 batches submitted to accumulate stats from 8128 documents (1017357 virtual)
# INFO:gensim.topic_coherence.text_analysis:128 batches submitted to accumulate stats from 8192 documents (1025112 virtual)
# INFO:gensim.topic_coherence.text_analysis:129 batches submitted to accumulate stats from 8256 documents (1034249 virtual)
# INFO:gensim.topic_coherence.text_analysis:130 batches submitted to accumulate stats from 8320 documents (1041192 virtual)
# INFO:gensim.topic_coherence.text_analysis:131 batches submitted to accumulate stats from 8384 documents (1044672 virtual)
# INFO:gensim.topic_coherence.text_analysis:132 batches submitted to accumulate stats from 8448 documents (1051378 virtual)
# INFO:gensim.topic_coherence.text_analysis:133 batches submitted to accumulate stats from 8512 documents (1057305 virtual)
# INFO:gensim.topic_coherence.text_analysis:134 batches submitted to accumulate stats from 8576 documents (1064775 virtual)
# INFO:gensim.topic_coherence.text_analysis:135 batches submitted to accumulate stats from 8640 documents (1072194 virtual)
# INFO:gensim.topic_coherence.text_analysis:136 batches submitted to accumulate stats from 8704 documents (1081285 virtual)
# INFO:gensim.topic_coherence.text_analysis:137 batches submitted to accumulate stats from 8768 documents (1087434 virtual)
# INFO:gensim.topic_coherence.text_analysis:138 batches submitted to accumulate stats from 8832 documents (1092845 virtual)
# INFO:gensim.topic_coherence.text_analysis:139 batches submitted to accumulate stats from 8896 documents (1097597 virtual)
# INFO:gensim.topic_coherence.text_analysis:140 batches submitted to accumulate stats from 8960 documents (1108473 virtual)
# INFO:gensim.topic_coherence.text_analysis:141 batches submitted to accumulate stats from 9024 documents (1116262 virtual)
# INFO:gensim.topic_coherence.text_analysis:142 batches submitted to accumulate stats from 9088 documents (1121600 virtual)
# INFO:gensim.topic_coherence.text_analysis:143 batches submitted to accumulate stats from 9152 documents (1128806 virtual)
# INFO:gensim.topic_coherence.text_analysis:144 batches submitted to accumulate stats from 9216 documents (1136093 virtual)
# INFO:gensim.topic_coherence.text_analysis:145 batches submitted to accumulate stats from 9280 documents (1143763 virtual)
# INFO:gensim.topic_coherence.text_analysis:146 batches submitted to accumulate stats from 9344 documents (1147381 virtual)
# INFO:gensim.topic_coherence.text_analysis:147 batches submitted to accumulate stats from 9408 documents (1157118 virtual)
# INFO:gensim.topic_coherence.text_analysis:148 batches submitted to accumulate stats from 9472 documents (1164624 virtual)
# INFO:gensim.topic_coherence.text_analysis:149 batches submitted to accumulate stats from 9536 documents (1171073 virtual)
# INFO:gensim.topic_coherence.text_analysis:150 batches submitted to accumulate stats from 9600 documents (1176410 virtual)
# INFO:gensim.topic_coherence.text_analysis:151 batches submitted to accumulate stats from 9664 documents (1188002 virtual)
# INFO:gensim.topic_coherence.text_analysis:152 batches submitted to accumulate stats from 9728 documents (1193687 virtual)
# INFO:gensim.topic_coherence.text_analysis:153 batches submitted to accumulate stats from 9792 documents (1201350 virtual)
# INFO:gensim.topic_coherence.text_analysis:154 batches submitted to accumulate stats from 9856 documents (1211241 virtual)
# INFO:gensim.topic_coherence.text_analysis:155 batches submitted to accumulate stats from 9920 documents (1219972 virtual)
# INFO:gensim.topic_coherence.text_analysis:156 batches submitted to accumulate stats from 9984 documents (1228626 virtual)
# INFO:gensim.topic_coherence.text_analysis:157 batches submitted to accumulate stats from 10048 documents (1236112 virtual)
# INFO:gensim.topic_coherence.text_analysis:158 batches submitted to accumulate stats from 10112 documents (1243889 virtual)
# INFO:gensim.topic_coherence.text_analysis:159 batches submitted to accumulate stats from 10176 documents (1253049 virtual)
# INFO:gensim.topic_coherence.text_analysis:160 batches submitted to accumulate stats from 10240 documents (1259643 virtual)
# INFO:gensim.topic_coherence.text_analysis:161 batches submitted to accumulate stats from 10304 documents (1263971 virtual)
# INFO:gensim.topic_coherence.text_analysis:162 batches submitted to accumulate stats from 10368 documents (1271804 virtual)
# INFO:gensim.topic_coherence.text_analysis:163 batches submitted to accumulate stats from 10432 documents (1281734 virtual)
# INFO:gensim.topic_coherence.text_analysis:164 batches submitted to accumulate stats from 10496 documents (1288034 virtual)
# INFO:gensim.topic_coherence.text_analysis:165 batches submitted to accumulate stats from 10560 documents (1292433 virtual)
# INFO:gensim.topic_coherence.text_analysis:166 batches submitted to accumulate stats from 10624 documents (1303598 virtual)
# INFO:gensim.topic_coherence.text_analysis:167 batches submitted to accumulate stats from 10688 documents (1313675 virtual)
# INFO:gensim.topic_coherence.text_analysis:168 batches submitted to accumulate stats from 10752 documents (1320630 virtual)
# INFO:gensim.topic_coherence.text_analysis:169 batches submitted to accumulate stats from 10816 documents (1326205 virtual)
# INFO:gensim.topic_coherence.text_analysis:170 batches submitted to accumulate stats from 10880 documents (1334765 virtual)
# INFO:gensim.topic_coherence.text_analysis:171 batches submitted to accumulate stats from 10944 documents (1341473 virtual)
# INFO:gensim.topic_coherence.text_analysis:172 batches submitted to accumulate stats from 11008 documents (1347475 virtual)
# INFO:gensim.topic_coherence.text_analysis:173 batches submitted to accumulate stats from 11072 documents (1357126 virtual)
# INFO:gensim.topic_coherence.text_analysis:174 batches submitted to accumulate stats from 11136 documents (1368401 virtual)
# INFO:gensim.topic_coherence.text_analysis:175 batches submitted to accumulate stats from 11200 documents (1377267 virtual)
# INFO:gensim.topic_coherence.text_analysis:176 batches submitted to accumulate stats from 11264 documents (1382973 virtual)
# INFO:gensim.topic_coherence.text_analysis:177 batches submitted to accumulate stats from 11328 documents (1391921 virtual)
# INFO:gensim.topic_coherence.text_analysis:178 batches submitted to accumulate stats from 11392 documents (1400883 virtual)
# INFO:gensim.topic_coherence.text_analysis:179 batches submitted to accumulate stats from 11456 documents (1408002 virtual)
# INFO:gensim.topic_coherence.text_analysis:180 batches submitted to accumulate stats from 11520 documents (1413945 virtual)
# INFO:gensim.topic_coherence.text_analysis:181 batches submitted to accumulate stats from 11584 documents (1422837 virtual)
# INFO:gensim.topic_coherence.text_analysis:182 batches submitted to accumulate stats from 11648 documents (1428235 virtual)
# INFO:gensim.topic_coherence.text_analysis:183 batches submitted to accumulate stats from 11712 documents (1434441 virtual)
# INFO:gensim.topic_coherence.text_analysis:184 batches submitted to accumulate stats from 11776 documents (1441701 virtual)
# INFO:gensim.topic_coherence.text_analysis:185 batches submitted to accumulate stats from 11840 documents (1450480 virtual)
# INFO:gensim.topic_coherence.text_analysis:186 batches submitted to accumulate stats from 11904 documents (1457778 virtual)
# INFO:gensim.topic_coherence.text_analysis:187 batches submitted to accumulate stats from 11968 documents (1463929 virtual)
# INFO:gensim.topic_coherence.text_analysis:188 batches submitted to accumulate stats from 12032 documents (1473155 virtual)
# INFO:gensim.topic_coherence.text_analysis:189 batches submitted to accumulate stats from 12096 documents (1481426 virtual)
# INFO:gensim.topic_coherence.text_analysis:190 batches submitted to accumulate stats from 12160 documents (1489494 virtual)
# INFO:gensim.topic_coherence.text_analysis:191 batches submitted to accumulate stats from 12224 documents (1495943 virtual)
# INFO:gensim.topic_coherence.text_analysis:192 batches submitted to accumulate stats from 12288 documents (1506202 virtual)
# INFO:gensim.topic_coherence.text_analysis:193 batches submitted to accumulate stats from 12352 documents (1512710 virtual)
# INFO:gensim.topic_coherence.text_analysis:194 batches submitted to accumulate stats from 12416 documents (1520277 virtual)
# INFO:gensim.topic_coherence.text_analysis:195 batches submitted to accumulate stats from 12480 documents (1526332 virtual)
# INFO:gensim.topic_coherence.text_analysis:196 batches submitted to accumulate stats from 12544 documents (1536733 virtual)
# INFO:gensim.topic_coherence.text_analysis:197 batches submitted to accumulate stats from 12608 documents (1544424 virtual)
# INFO:gensim.topic_coherence.text_analysis:198 batches submitted to accumulate stats from 12672 documents (1550534 virtual)
# INFO:gensim.topic_coherence.text_analysis:199 batches submitted to accumulate stats from 12736 documents (1557311 virtual)
# INFO:gensim.topic_coherence.text_analysis:200 batches submitted to accumulate stats from 12800 documents (1566565 virtual)
# INFO:gensim.topic_coherence.text_analysis:201 batches submitted to accumulate stats from 12864 documents (1574502 virtual)
# INFO:gensim.topic_coherence.text_analysis:202 batches submitted to accumulate stats from 12928 documents (1580079 virtual)
# INFO:gensim.topic_coherence.text_analysis:203 batches submitted to accumulate stats from 12992 documents (1588187 virtual)
# INFO:gensim.topic_coherence.text_analysis:204 batches submitted to accumulate stats from 13056 documents (1597734 virtual)
# INFO:gensim.topic_coherence.text_analysis:205 batches submitted to accumulate stats from 13120 documents (1604602 virtual)
# INFO:gensim.topic_coherence.text_analysis:206 batches submitted to accumulate stats from 13184 documents (1609438 virtual)
# INFO:gensim.topic_coherence.text_analysis:207 batches submitted to accumulate stats from 13248 documents (1617452 virtual)
# INFO:gensim.topic_coherence.text_analysis:208 batches submitted to accumulate stats from 13312 documents (1625267 virtual)
# INFO:gensim.topic_coherence.text_analysis:209 batches submitted to accumulate stats from 13376 documents (1632996 virtual)
# INFO:gensim.topic_coherence.text_analysis:210 batches submitted to accumulate stats from 13440 documents (1638289 virtual)
# INFO:gensim.topic_coherence.text_analysis:211 batches submitted to accumulate stats from 13504 documents (1645258 virtual)
# INFO:gensim.topic_coherence.text_analysis:212 batches submitted to accumulate stats from 13568 documents (1650083 virtual)
# INFO:gensim.topic_coherence.text_analysis:213 batches submitted to accumulate stats from 13632 documents (1656132 virtual)
# INFO:gensim.topic_coherence.text_analysis:214 batches submitted to accumulate stats from 13696 documents (1662340 virtual)
# INFO:gensim.topic_coherence.text_analysis:215 batches submitted to accumulate stats from 13760 documents (1670700 virtual)
# INFO:gensim.topic_coherence.text_analysis:216 batches submitted to accumulate stats from 13824 documents (1677012 virtual)
# INFO:gensim.topic_coherence.text_analysis:217 batches submitted to accumulate stats from 13888 documents (1682493 virtual)
# INFO:gensim.topic_coherence.text_analysis:218 batches submitted to accumulate stats from 13952 documents (1690797 virtual)
# INFO:gensim.topic_coherence.text_analysis:219 batches submitted to accumulate stats from 14016 documents (1702423 virtual)
# INFO:gensim.topic_coherence.text_analysis:220 batches submitted to accumulate stats from 14080 documents (1710503 virtual)
# INFO:gensim.topic_coherence.text_analysis:221 batches submitted to accumulate stats from 14144 documents (1715995 virtual)
# INFO:gensim.topic_coherence.text_analysis:222 batches submitted to accumulate stats from 14208 documents (1727210 virtual)
# INFO:gensim.topic_coherence.text_analysis:223 batches submitted to accumulate stats from 14272 documents (1732740 virtual)
# INFO:gensim.topic_coherence.text_analysis:224 batches submitted to accumulate stats from 14336 documents (1740631 virtual)
# INFO:gensim.topic_coherence.text_analysis:225 batches submitted to accumulate stats from 14400 documents (1745892 virtual)
# INFO:gensim.topic_coherence.text_analysis:226 batches submitted to accumulate stats from 14464 documents (1756148 virtual)
# INFO:gensim.topic_coherence.text_analysis:227 batches submitted to accumulate stats from 14528 documents (1765706 virtual)
# INFO:gensim.topic_coherence.text_analysis:228 batches submitted to accumulate stats from 14592 documents (1770246 virtual)
# INFO:gensim.topic_coherence.text_analysis:229 batches submitted to accumulate stats from 14656 documents (1775423 virtual)
# INFO:gensim.topic_coherence.text_analysis:230 batches submitted to accumulate stats from 14720 documents (1786442 virtual)
# INFO:gensim.topic_coherence.text_analysis:231 batches submitted to accumulate stats from 14784 documents (1793646 virtual)
# INFO:gensim.topic_coherence.text_analysis:232 batches submitted to accumulate stats from 14848 documents (1798582 virtual)
# INFO:gensim.topic_coherence.text_analysis:233 batches submitted to accumulate stats from 14912 documents (1806709 virtual)
# INFO:gensim.topic_coherence.text_analysis:234 batches submitted to accumulate stats from 14976 documents (1814948 virtual)
# INFO:gensim.topic_coherence.text_analysis:235 batches submitted to accumulate stats from 15040 documents (1821360 virtual)
# INFO:gensim.topic_coherence.text_analysis:236 batches submitted to accumulate stats from 15104 documents (1825982 virtual)
# INFO:gensim.topic_coherence.text_analysis:237 batches submitted to accumulate stats from 15168 documents (1831384 virtual)
# INFO:gensim.topic_coherence.text_analysis:238 batches submitted to accumulate stats from 15232 documents (1834975 virtual)
# INFO:gensim.topic_coherence.text_analysis:239 batches submitted to accumulate stats from 15296 documents (1842400 virtual)
# INFO:gensim.topic_coherence.text_analysis:240 batches submitted to accumulate stats from 15360 documents (1846853 virtual)
# INFO:gensim.topic_coherence.text_analysis:241 batches submitted to accumulate stats from 15424 documents (1852762 virtual)
# INFO:gensim.topic_coherence.text_analysis:242 batches submitted to accumulate stats from 15488 documents (1856120 virtual)
# INFO:gensim.topic_coherence.text_analysis:243 batches submitted to accumulate stats from 15552 documents (1860592 virtual)
# INFO:gensim.topic_coherence.text_analysis:244 batches submitted to accumulate stats from 15616 documents (1865285 virtual)
# INFO:gensim.topic_coherence.text_analysis:245 batches submitted to accumulate stats from 15680 documents (1870319 virtual)
# INFO:gensim.topic_coherence.text_analysis:246 batches submitted to accumulate stats from 15744 documents (1875070 virtual)
# INFO:gensim.topic_coherence.text_analysis:247 batches submitted to accumulate stats from 15808 documents (1877531 virtual)
# INFO:gensim.topic_coherence.text_analysis:248 batches submitted to accumulate stats from 15872 documents (1886875 virtual)
# INFO:gensim.topic_coherence.text_analysis:249 batches submitted to accumulate stats from 15936 documents (1888784 virtual)
# INFO:gensim.topic_coherence.text_analysis:250 batches submitted to accumulate stats from 16000 documents (1896059 virtual)
# INFO:gensim.topic_coherence.text_analysis:251 batches submitted to accumulate stats from 16064 documents (1898964 virtual)
# INFO:gensim.topic_coherence.text_analysis:252 batches submitted to accumulate stats from 16128 documents (1904758 virtual)
# INFO:gensim.topic_coherence.text_analysis:253 batches submitted to accumulate stats from 16192 documents (1908104 virtual)
# INFO:gensim.topic_coherence.text_analysis:254 batches submitted to accumulate stats from 16256 documents (1912490 virtual)
# INFO:gensim.topic_coherence.text_analysis:255 batches submitted to accumulate stats from 16320 documents (1917120 virtual)
# INFO:gensim.topic_coherence.text_analysis:256 batches submitted to accumulate stats from 16384 documents (1919882 virtual)
# INFO:gensim.topic_coherence.text_analysis:257 batches submitted to accumulate stats from 16448 documents (1925108 virtual)
# INFO:gensim.topic_coherence.text_analysis:258 batches submitted to accumulate stats from 16512 documents (1928887 virtual)
# INFO:gensim.topic_coherence.text_analysis:259 batches submitted to accumulate stats from 16576 documents (1934356 virtual)
# INFO:gensim.topic_coherence.text_analysis:260 batches submitted to accumulate stats from 16640 documents (1936692 virtual)
# INFO:gensim.topic_coherence.text_analysis:261 batches submitted to accumulate stats from 16704 documents (1941636 virtual)
# INFO:gensim.topic_coherence.text_analysis:262 batches submitted to accumulate stats from 16768 documents (1944655 virtual)
# INFO:gensim.topic_coherence.text_analysis:263 batches submitted to accumulate stats from 16832 documents (1952501 virtual)
# INFO:gensim.topic_coherence.text_analysis:264 batches submitted to accumulate stats from 16896 documents (1957163 virtual)
# INFO:gensim.topic_coherence.text_analysis:265 batches submitted to accumulate stats from 16960 documents (1960644 virtual)
# INFO:gensim.topic_coherence.text_analysis:266 batches submitted to accumulate stats from 17024 documents (1966123 virtual)
# INFO:gensim.topic_coherence.text_analysis:267 batches submitted to accumulate stats from 17088 documents (1967902 virtual)
# INFO:gensim.topic_coherence.text_analysis:268 batches submitted to accumulate stats from 17152 documents (1974784 virtual)
# INFO:gensim.topic_coherence.text_analysis:269 batches submitted to accumulate stats from 17216 documents (1977897 virtual)
# INFO:gensim.topic_coherence.text_analysis:270 batches submitted to accumulate stats from 17280 documents (1984453 virtual)
# INFO:gensim.topic_coherence.text_analysis:271 batches submitted to accumulate stats from 17344 documents (1992453 virtual)
# INFO:gensim.topic_coherence.text_analysis:272 batches submitted to accumulate stats from 17408 documents (1995940 virtual)
# INFO:gensim.topic_coherence.text_analysis:273 batches submitted to accumulate stats from 17472 documents (2002567 virtual)
# INFO:gensim.topic_coherence.text_analysis:274 batches submitted to accumulate stats from 17536 documents (2004947 virtual)
# INFO:gensim.topic_coherence.text_analysis:275 batches submitted to accumulate stats from 17600 documents (2008178 virtual)
# INFO:gensim.topic_coherence.text_analysis:276 batches submitted to accumulate stats from 17664 documents (2009056 virtual)
# INFO:gensim.topic_coherence.text_analysis:277 batches submitted to accumulate stats from 17728 documents (2013782 virtual)
# INFO:gensim.topic_coherence.text_analysis:278 batches submitted to accumulate stats from 17792 documents (2020116 virtual)
# INFO:gensim.topic_coherence.text_analysis:279 batches submitted to accumulate stats from 17856 documents (2023649 virtual)
# INFO:gensim.topic_coherence.text_analysis:280 batches submitted to accumulate stats from 17920 documents (2029584 virtual)
# INFO:gensim.topic_coherence.text_analysis:281 batches submitted to accumulate stats from 17984 documents (2032558 virtual)
# INFO:gensim.topic_coherence.text_analysis:282 batches submitted to accumulate stats from 18048 documents (2039005 virtual)
# INFO:gensim.topic_coherence.text_analysis:283 batches submitted to accumulate stats from 18112 documents (2043368 virtual)
# INFO:gensim.topic_coherence.text_analysis:284 batches submitted to accumulate stats from 18176 documents (2048906 virtual)
# INFO:gensim.topic_coherence.text_analysis:285 batches submitted to accumulate stats from 18240 documents (2055299 virtual)
# INFO:gensim.topic_coherence.text_analysis:286 batches submitted to accumulate stats from 18304 documents (2060060 virtual)
# INFO:gensim.topic_coherence.text_analysis:287 batches submitted to accumulate stats from 18368 documents (2069251 virtual)
# INFO:gensim.topic_coherence.text_analysis:288 batches submitted to accumulate stats from 18432 documents (2072185 virtual)
# INFO:gensim.topic_coherence.text_analysis:289 batches submitted to accumulate stats from 18496 documents (2078876 virtual)
# INFO:gensim.topic_coherence.text_analysis:290 batches submitted to accumulate stats from 18560 documents (2083099 virtual)
# INFO:gensim.topic_coherence.text_analysis:291 batches submitted to accumulate stats from 18624 documents (2088309 virtual)
# INFO:gensim.topic_coherence.text_analysis:292 batches submitted to accumulate stats from 18688 documents (2095312 virtual)
# INFO:gensim.topic_coherence.text_analysis:293 batches submitted to accumulate stats from 18752 documents (2099175 virtual)
# INFO:gensim.topic_coherence.text_analysis:294 batches submitted to accumulate stats from 18816 documents (2110439 virtual)
# INFO:gensim.topic_coherence.text_analysis:295 batches submitted to accumulate stats from 18880 documents (2113494 virtual)
# INFO:gensim.topic_coherence.text_analysis:296 batches submitted to accumulate stats from 18944 documents (2120280 virtual)
# INFO:gensim.topic_coherence.text_analysis:297 batches submitted to accumulate stats from 19008 documents (2124414 virtual)
# INFO:gensim.topic_coherence.text_analysis:298 batches submitted to accumulate stats from 19072 documents (2130690 virtual)
# INFO:gensim.topic_coherence.text_analysis:299 batches submitted to accumulate stats from 19136 documents (2135197 virtual)
# INFO:gensim.topic_coherence.text_analysis:300 batches submitted to accumulate stats from 19200 documents (2138761 virtual)
# INFO:gensim.topic_coherence.text_analysis:301 batches submitted to accumulate stats from 19264 documents (2145402 virtual)
# INFO:gensim.topic_coherence.text_analysis:302 batches submitted to accumulate stats from 19328 documents (2149256 virtual)
# INFO:gensim.topic_coherence.text_analysis:303 batches submitted to accumulate stats from 19392 documents (2156230 virtual)
# INFO:gensim.topic_coherence.text_analysis:304 batches submitted to accumulate stats from 19456 documents (2160171 virtual)
# INFO:gensim.topic_coherence.text_analysis:305 batches submitted to accumulate stats from 19520 documents (2164389 virtual)
# INFO:gensim.topic_coherence.text_analysis:306 batches submitted to accumulate stats from 19584 documents (2170968 virtual)
# INFO:gensim.topic_coherence.text_analysis:307 batches submitted to accumulate stats from 19648 documents (2175138 virtual)
# INFO:gensim.topic_coherence.text_analysis:308 batches submitted to accumulate stats from 19712 documents (2182087 virtual)
# INFO:gensim.topic_coherence.text_analysis:309 batches submitted to accumulate stats from 19776 documents (2186064 virtual)
# INFO:gensim.topic_coherence.text_analysis:310 batches submitted to accumulate stats from 19840 documents (2193761 virtual)
# INFO:gensim.topic_coherence.text_analysis:311 batches submitted to accumulate stats from 19904 documents (2196584 virtual)
# INFO:gensim.topic_coherence.text_analysis:312 batches submitted to accumulate stats from 19968 documents (2200451 virtual)
# INFO:gensim.topic_coherence.text_analysis:313 batches submitted to accumulate stats from 20032 documents (2207484 virtual)
# INFO:gensim.topic_coherence.text_analysis:314 batches submitted to accumulate stats from 20096 documents (2210996 virtual)
# INFO:gensim.topic_coherence.text_analysis:315 batches submitted to accumulate stats from 20160 documents (2217468 virtual)
# INFO:gensim.topic_coherence.text_analysis:316 batches submitted to accumulate stats from 20224 documents (2219195 virtual)
# INFO:gensim.topic_coherence.text_analysis:317 batches submitted to accumulate stats from 20288 documents (2222899 virtual)
# INFO:gensim.topic_coherence.text_analysis:318 batches submitted to accumulate stats from 20352 documents (2226934 virtual)
# INFO:gensim.topic_coherence.text_analysis:319 batches submitted to accumulate stats from 20416 documents (2231510 virtual)
# INFO:gensim.topic_coherence.text_analysis:320 batches submitted to accumulate stats from 20480 documents (2238350 virtual)
# INFO:gensim.topic_coherence.text_analysis:321 batches submitted to accumulate stats from 20544 documents (2242241 virtual)
# INFO:gensim.topic_coherence.text_analysis:322 batches submitted to accumulate stats from 20608 documents (2248802 virtual)
# INFO:gensim.topic_coherence.text_analysis:323 batches submitted to accumulate stats from 20672 documents (2252004 virtual)
# INFO:gensim.topic_coherence.text_analysis:324 batches submitted to accumulate stats from 20736 documents (2257459 virtual)
# INFO:gensim.topic_coherence.text_analysis:325 batches submitted to accumulate stats from 20800 documents (2260773 virtual)
# INFO:gensim.topic_coherence.text_analysis:326 batches submitted to accumulate stats from 20864 documents (2264491 virtual)
# INFO:gensim.topic_coherence.text_analysis:327 batches submitted to accumulate stats from 20928 documents (2270961 virtual)
# INFO:gensim.topic_coherence.text_analysis:328 batches submitted to accumulate stats from 20992 documents (2274220 virtual)
# INFO:gensim.topic_coherence.text_analysis:329 batches submitted to accumulate stats from 21056 documents (2279399 virtual)
# INFO:gensim.topic_coherence.text_analysis:330 batches submitted to accumulate stats from 21120 documents (2281954 virtual)
# ...
# INFO:gensim.topic_coherence.text_analysis:264 batches submitted to accumulate stats from 16896 documents (1957937 virtual)
# INFO:gensim.topic_coherence.text_analysis:265 batches submitted to accumulate stats from 16960 documents (1961369 virtual)
# INFO:gensim.topic_coherence.text_analysis:266 batches submitted to accumulate stats from 17024 documents (1966850 virtual)
# INFO:gensim.topic_coherence.text_analysis:267 batches submitted to accumulate stats from 17088 documents (1968705 virtual)
# INFO:gensim.topic_coherence.text_analysis:268 batches submitted to accumulate stats from 17152 documents (1975674 virtual)
# INFO:gensim.topic_coherence.text_analysis:269 batches submitted to accumulate stats from 17216 documents (1978687 virtual)
# INFO:gensim.topic_coherence.text_analysis:270 batches submitted to accumulate stats from 17280 documents (1985408 virtual)
# INFO:gensim.topic_coherence.text_analysis:271 batches submitted to accumulate stats from 17344 documents (1993260 virtual)
# INFO:gensim.topic_coherence.text_analysis:272 batches submitted to accumulate stats from 17408 documents (1996747 virtual)
# INFO:gensim.topic_coherence.text_analysis:273 batches submitted to accumulate stats from 17472 documents (2003440 virtual)
# INFO:gensim.topic_coherence.text_analysis:274 batches submitted to accumulate stats from 17536 documents (2006309 virtual)
# INFO:gensim.topic_coherence.text_analysis:275 batches submitted to accumulate stats from 17600 documents (2008980 virtual)
# INFO:gensim.topic_coherence.text_analysis:276 batches submitted to accumulate stats from 17664 documents (2009726 virtual)
# INFO:gensim.topic_coherence.text_analysis:277 batches submitted to accumulate stats from 17728 documents (2014665 virtual)
# INFO:gensim.topic_coherence.text_analysis:278 batches submitted to accumulate stats from 17792 documents (2021025 virtual)
# INFO:gensim.topic_coherence.text_analysis:279 batches submitted to accumulate stats from 17856 documents (2024796 virtual)
# INFO:gensim.topic_coherence.text_analysis:280 batches submitted to accumulate stats from 17920 documents (2030311 virtual)
# INFO:gensim.topic_coherence.text_analysis:281 batches submitted to accumulate stats from 17984 documents (2033409 virtual)
# INFO:gensim.topic_coherence.text_analysis:282 batches submitted to accumulate stats from 18048 documents (2039842 virtual)
# INFO:gensim.topic_coherence.text_analysis:283 batches submitted to accumulate stats from 18112 documents (2044132 virtual)
# INFO:gensim.topic_coherence.text_analysis:284 batches submitted to accumulate stats from 18176 documents (2049811 virtual)
# INFO:gensim.topic_coherence.text_analysis:285 batches submitted to accumulate stats from 18240 documents (2056028 virtual)
# INFO:gensim.topic_coherence.text_analysis:286 batches submitted to accumulate stats from 18304 documents (2061435 virtual)
# INFO:gensim.topic_coherence.text_analysis:287 batches submitted to accumulate stats from 18368 documents (2070290 virtual)
# INFO:gensim.topic_coherence.text_analysis:288 batches submitted to accumulate stats from 18432 documents (2073138 virtual)
# INFO:gensim.topic_coherence.text_analysis:289 batches submitted to accumulate stats from 18496 documents (2079679 virtual)
# INFO:gensim.topic_coherence.text_analysis:290 batches submitted to accumulate stats from 18560 documents (2083864 virtual)
# INFO:gensim.topic_coherence.text_analysis:291 batches submitted to accumulate stats from 18624 documents (2089499 virtual)
# INFO:gensim.topic_coherence.text_analysis:292 batches submitted to accumulate stats from 18688 documents (2096028 virtual)
# INFO:gensim.topic_coherence.text_analysis:293 batches submitted to accumulate stats from 18752 documents (2099974 virtual)
# INFO:gensim.topic_coherence.text_analysis:294 batches submitted to accumulate stats from 18816 documents (2111045 virtual)
# INFO:gensim.topic_coherence.text_analysis:295 batches submitted to accumulate stats from 18880 documents (2114100 virtual)
# INFO:gensim.topic_coherence.text_analysis:296 batches submitted to accumulate stats from 18944 documents (2120886 virtual)
# INFO:gensim.topic_coherence.text_analysis:297 batches submitted to accumulate stats from 19008 documents (2125020 virtual)
# INFO:gensim.topic_coherence.text_analysis:298 batches submitted to accumulate stats from 19072 documents (2131296 virtual)
# INFO:gensim.topic_coherence.text_analysis:299 batches submitted to accumulate stats from 19136 documents (2135803 virtual)
# INFO:gensim.topic_coherence.text_analysis:300 batches submitted to accumulate stats from 19200 documents (2139367 virtual)
# INFO:gensim.topic_coherence.text_analysis:301 batches submitted to accumulate stats from 19264 documents (2146008 virtual)
# INFO:gensim.topic_coherence.text_analysis:302 batches submitted to accumulate stats from 19328 documents (2149862 virtual)
# INFO:gensim.topic_coherence.text_analysis:303 batches submitted to accumulate stats from 19392 documents (2156836 virtual)
# INFO:gensim.topic_coherence.text_analysis:304 batches submitted to accumulate stats from 19456 documents (2160777 virtual)
# INFO:gensim.topic_coherence.text_analysis:305 batches submitted to accumulate stats from 19520 documents (2164995 virtual)
# INFO:gensim.topic_coherence.text_analysis:306 batches submitted to accumulate stats from 19584 documents (2171574 virtual)
# INFO:gensim.topic_coherence.text_analysis:307 batches submitted to accumulate stats from 19648 documents (2175744 virtual)
# INFO:gensim.topic_coherence.text_analysis:308 batches submitted to accumulate stats from 19712 documents (2182693 virtual)
# INFO:gensim.topic_coherence.text_analysis:309 batches submitted to accumulate stats from 19776 documents (2186670 virtual)
# INFO:gensim.topic_coherence.text_analysis:310 batches submitted to accumulate stats from 19840 documents (2194367 virtual)
# INFO:gensim.topic_coherence.text_analysis:311 batches submitted to accumulate stats from 19904 documents (2197190 virtual)
# INFO:gensim.topic_coherence.text_analysis:312 batches submitted to accumulate stats from 19968 documents (2201057 virtual)
# INFO:gensim.topic_coherence.text_analysis:313 batches submitted to accumulate stats from 20032 documents (2208090 virtual)
# INFO:gensim.topic_coherence.text_analysis:314 batches submitted to accumulate stats from 20096 documents (2211602 virtual)
# INFO:gensim.topic_coherence.text_analysis:315 batches submitted to accumulate stats from 20160 documents (2218074 virtual)
# INFO:gensim.topic_coherence.text_analysis:316 batches submitted to accumulate stats from 20224 documents (2219801 virtual)
# INFO:gensim.topic_coherence.text_analysis:317 batches submitted to accumulate stats from 20288 documents (2223505 virtual)
# INFO:gensim.topic_coherence.text_analysis:318 batches submitted to accumulate stats from 20352 documents (2227540 virtual)
# INFO:gensim.topic_coherence.text_analysis:319 batches submitted to accumulate stats from 20416 documents (2232116 virtual)
# INFO:gensim.topic_coherence.text_analysis:320 batches submitted to accumulate stats from 20480 documents (2238956 virtual)
# INFO:gensim.topic_coherence.text_analysis:321 batches submitted to accumulate stats from 20544 documents (2242847 virtual)
# INFO:gensim.topic_coherence.text_analysis:322 batches submitted to accumulate stats from 20608 documents (2249408 virtual)
# INFO:gensim.topic_coherence.text_analysis:323 batches submitted to accumulate stats from 20672 documents (2252610 virtual)
# INFO:gensim.topic_coherence.text_analysis:324 batches submitted to accumulate stats from 20736 documents (2258065 virtual)
# INFO:gensim.topic_coherence.text_analysis:325 batches submitted to accumulate stats from 20800 documents (2261379 virtual)
# INFO:gensim.topic_coherence.text_analysis:326 batches submitted to accumulate stats from 20864 documents (2265097 virtual)
# INFO:gensim.topic_coherence.text_analysis:327 batches submitted to accumulate stats from 20928 documents (2271567 virtual)
# INFO:gensim.topic_coherence.text_analysis:328 batches submitted to accumulate stats from 20992 documents (2274826 virtual)
# INFO:gensim.topic_coherence.text_analysis:329 batches submitted to accumulate stats from 21056 documents (2280005 virtual)
# INFO:gensim.topic_coherence.text_analysis:330 batches submitted to accumulate stats from 21120 documents (2282560 virtual)
# INFO:gensim.topic_coherence.text_analysis:331 batches submitted to accumulate stats from 21184 documents (2287248 virtual)
# INFO:gensim.topic_coherence.text_analysis:332 batches submitted to accumulate stats from 21248 documents (2291395 virtual)
# INFO:gensim.topic_coherence.text_analysis:333 batches submitted to accumulate stats from 21312 documents (2293636 virtual)
# INFO:gensim.topic_coherence.text_analysis:334 batches submitted to accumulate stats from 21376 documents (2300210 virtual)
# INFO:gensim.topic_coherence.text_analysis:335 batches submitted to accumulate stats from 21440 documents (2302506 virtual)
# INFO:gensim.topic_coherence.text_analysis:336 batches submitted to accumulate stats from 21504 documents (2308903 virtual)
# INFO:gensim.topic_coherence.text_analysis:337 batches submitted to accumulate stats from 21568 documents (2312813 virtual)
# INFO:gensim.topic_coherence.text_analysis:338 batches submitted to accumulate stats from 21632 documents (2321826 virtual)
# INFO:gensim.topic_coherence.text_analysis:339 batches submitted to accumulate stats from 21696 documents (2326310 virtual)
# INFO:gensim.topic_coherence.text_analysis:340 batches submitted to accumulate stats from 21760 documents (2329999 virtual)
# INFO:gensim.topic_coherence.text_analysis:341 batches submitted to accumulate stats from 21824 documents (2337507 virtual)
# INFO:gensim.topic_coherence.text_analysis:342 batches submitted to accumulate stats from 21888 documents (2339554 virtual)
# INFO:gensim.topic_coherence.text_analysis:343 batches submitted to accumulate stats from 21952 documents (2344999 virtual)
# INFO:gensim.topic_coherence.text_analysis:344 batches submitted to accumulate stats from 22016 documents (2347852 virtual)
# INFO:gensim.topic_coherence.text_analysis:345 batches submitted to accumulate stats from 22080 documents (2355571 virtual)
# INFO:gensim.topic_coherence.text_analysis:346 batches submitted to accumulate stats from 22144 documents (2360802 virtual)
# INFO:gensim.topic_coherence.text_analysis:347 batches submitted to accumulate stats from 22208 documents (2363785 virtual)
# INFO:gensim.topic_coherence.text_analysis:348 batches submitted to accumulate stats from 22272 documents (2369655 virtual)
# INFO:gensim.topic_coherence.text_analysis:349 batches submitted to accumulate stats from 22336 documents (2371391 virtual)
# INFO:gensim.topic_coherence.text_analysis:350 batches submitted to accumulate stats from 22400 documents (2377702 virtual)
# INFO:gensim.topic_coherence.text_analysis:351 batches submitted to accumulate stats from 22464 documents (2380359 virtual)
# INFO:gensim.topic_coherence.text_analysis:352 batches submitted to accumulate stats from 22528 documents (2387201 virtual)
# INFO:gensim.topic_coherence.text_analysis:353 batches submitted to accumulate stats from 22592 documents (2392903 virtual)
# INFO:gensim.topic_coherence.text_analysis:354 batches submitted to accumulate stats from 22656 documents (2398472 virtual)
# INFO:gensim.topic_coherence.text_analysis:355 batches submitted to accumulate stats from 22720 documents (2405402 virtual)
# INFO:gensim.topic_coherence.text_analysis:356 batches submitted to accumulate stats from 22784 documents (2408605 virtual)
# INFO:gensim.topic_coherence.text_analysis:357 batches submitted to accumulate stats from 22848 documents (2415484 virtual)
# INFO:gensim.topic_coherence.text_analysis:358 batches submitted to accumulate stats from 22912 documents (2418579 virtual)
# INFO:gensim.topic_coherence.text_analysis:359 batches submitted to accumulate stats from 22976 documents (2426390 virtual)
# INFO:gensim.topic_coherence.text_analysis:360 batches submitted to accumulate stats from 23040 documents (2432935 virtual)
# INFO:gensim.topic_coherence.text_analysis:361 batches submitted to accumulate stats from 23104 documents (2437625 virtual)
# INFO:gensim.topic_coherence.text_analysis:362 batches submitted to accumulate stats from 23168 documents (2444907 virtual)
# INFO:gensim.topic_coherence.text_analysis:363 batches submitted to accumulate stats from 23232 documents (2447169 virtual)
# INFO:gensim.topic_coherence.text_analysis:364 batches submitted to accumulate stats from 23296 documents (2453006 virtual)
# INFO:gensim.topic_coherence.text_analysis:365 batches submitted to accumulate stats from 23360 documents (2455549 virtual)
# INFO:gensim.topic_coherence.text_analysis:366 batches submitted to accumulate stats from 23424 documents (2461301 virtual)
# INFO:gensim.topic_coherence.text_analysis:367 batches submitted to accumulate stats from 23488 documents (2464857 virtual)
# INFO:gensim.topic_coherence.text_analysis:368 batches submitted to accumulate stats from 23552 documents (2470346 virtual)
# INFO:gensim.topic_coherence.text_analysis:369 batches submitted to accumulate stats from 23616 documents (2478776 virtual)
# INFO:gensim.topic_coherence.text_analysis:370 batches submitted to accumulate stats from 23680 documents (2482542 virtual)
# INFO:gensim.topic_coherence.text_analysis:371 batches submitted to accumulate stats from 23744 documents (2486696 virtual)
# INFO:gensim.topic_coherence.text_analysis:372 batches submitted to accumulate stats from 23808 documents (2491442 virtual)
# INFO:gensim.topic_coherence.text_analysis:373 batches submitted to accumulate stats from 23872 documents (2496682 virtual)
# INFO:gensim.topic_coherence.text_analysis:374 batches submitted to accumulate stats from 23936 documents (2502165 virtual)
# INFO:gensim.topic_coherence.text_analysis:375 batches submitted to accumulate stats from 24000 documents (2506935 virtual)
# INFO:gensim.topic_coherence.text_analysis:376 batches submitted to accumulate stats from 24064 documents (2514484 virtual)
# INFO:gensim.topic_coherence.text_analysis:377 batches submitted to accumulate stats from 24128 documents (2517744 virtual)
# INFO:gensim.topic_coherence.text_analysis:378 batches submitted to accumulate stats from 24192 documents (2525470 virtual)
# INFO:gensim.topic_coherence.text_analysis:379 batches submitted to accumulate stats from 24256 documents (2529291 virtual)
# INFO:gensim.topic_coherence.text_analysis:380 batches submitted to accumulate stats from 24320 documents (2536081 virtual)
# INFO:gensim.topic_coherence.text_analysis:381 batches submitted to accumulate stats from 24384 documents (2542396 virtual)
# INFO:gensim.topic_coherence.text_analysis:382 batches submitted to accumulate stats from 24448 documents (2547404 virtual)
# INFO:gensim.topic_coherence.text_analysis:383 batches submitted to accumulate stats from 24512 documents (2547909 virtual)
# INFO:gensim.topic_coherence.text_analysis:serializing accumulator to return to master...
# INFO:gensim.topic_coherence.text_analysis:accumulator serialized
# INFO:gensim.topic_coherence.text_analysis:serializing accumulator to return to master...
# INFO:gensim.topic_coherence.text_analysis:serializing accumulator to return to master...
# INFO:gensim.topic_coherence.text_analysis:accumulator serialized
# INFO:gensim.topic_coherence.text_analysis:accumulator serialized
# INFO:gensim.topic_coherence.text_analysis:3 accumulators retrieved from output queue
# INFO:gensim.topic_coherence.text_analysis:accumulated word occurrence stats for 2686599 virtual documents
# INFO:gensim.models.ldamodel:Epoch 1: Coherence (c_v) estimate: 0.620937185359459
# INFO:gensim.models.ldamodel:Epoch 1: Diff (kullback_leibler) estimate: [0.44650214 0.86279683 0.43798072 0.47085018 0.70434914 0.58109422
#  0.59921227 0.47498363 0.891068   0.59885582 1.         0.60545236
#  0.68282222 0.44590036 0.85350726 0.97644045 0.55674444 0.7080192
#  0.76002505 0.64773823]
# INFO:gensim.models.ldamodel:Epoch 1: Convergence (jaccard) estimate: 12.112321046464421
# INFO:gensim.models.ldamodel:PROGRESS: pass 2, at document #6123/24492

# %%
# %%time
coherence1_um_ct_name = clusteringModelPath + 'coherence1_ct_u_mass'
if not os.path.isfile(coherence1_um_ct_name):
    cm_ct = CoherenceModel(model = ldamodel_ct, 
                      corpus = corpus_ct, 
                      dictionary = dictionary_ct,
                      coherence = 'u_mass')
    cm_ct.save(coherence1_um_ct_name)
else:
    cm_ct = CoherenceModel.load(coherence1_um_ct_name)

# %%
print ('Coherence : {}'.format(cm_ct.get_coherence()))

# %%
# %%time
coherence1_cv_ct_name = clusteringModelPath + 'coherence1_ct_c_v'
if not os.path.isfile(coherence1_cv_ct_name):
    cm_ct_cv = CoherenceModel(model = ldamodel_ct, 
                         texts = tagged_text_ct,
                         dictionary = dictionary_ct, 
                         coherence = 'c_v')
    cm_ct_cv.save(coherence1_cv_ct_name)
else:
    cm_ct_cv = CoherenceModel.load(coherence1_cv_ct_name)

# %%
print ('Coherence : {}'.format(cm_ct_cv.get_coherence()))

# %%
# %%time
pyLDAvis.gensim.prepare(ldamodel_ct, corpus_ct, dictionary_ct)

# %%
ldatopics_ct = ldamodel_ct.show_topics(formatted = False)

# %%
pl_mecab = PerplexityMetric(corpus = corpus_mecab, logger = 'shell', 
                           title = 'Perplexity (Mecab)')
ch_umass_mecab = CoherenceMetric(corpus = corpus_mecab, coherence = 'u_mass', 
                             logger = 'shell', title = ' Coherence (u_mass)')
ch_cv_mecab = CoherenceMetric(corpus = corpus_mecab, logger = 'shell', 
                          texts = tagged_text_mecab, coherence = 'c_v', 
                          title = 'Coherence (c_v)')
diff_kl_mecab = DiffMetric(distance = 'kullback_leibler', 
                       logger = 'shell', title = 'Diff (kullback_leibler)')
convergence_kl_mecab = ConvergenceMetric(distance = 'jaccard', logger = 'shell', 
                                     title = 'Convergence (jaccard)')
callbacks_mecab = [pl_mecab, ch_umass_mecab, ch_cv_mecab, diff_kl_mecab, convergence_kl_mecab]

# %%
# %%time
logging.basicConfig(level = logging.INFO)
logger = logging.getLogger(__name__)
logger.setLevel(logging.DEBUG)
ldamodel_mecab_name = clusteringModelPath + 'ldamodel_mecab'
if not os.path.isfile(ldamodel_mecab_name):
    ldamodel_mecab = LdaModel( corpus = corpus_mecab, num_topics = 20,
                              id2word = dictionary_mecab, passes = 25,
                           chunksize = 6123, iterations = 125,
                           alpha='symmetric', callbacks = callbacks_mecab)
    ldamodel_mecab.save(ldamodel_mecab_name)
else:
    ldamodel_mecab = LdaModel.load(ldamodel_mecab_name)

# %%
# %%time
coherence1_um_mecab = clusteringModelPath + 'coherence1_mecab_u_mass'
if not os.path.isfile(coherence1_um_mecab):
    cm_mecab = CoherenceModel(model = ldamodel_mecab, 
                      corpus = corpus_mecab, 
                      dictionary = dictionary_mecab,
                      coherence = 'u_mass')
    cm_mecab.save(coherence1_um_mecab)
else:
    cm_mecab = CoherenceModel.load(coherence1_um_mecab)

# %%
print ('Coherence : {}'.format(cm_mecab.get_coherence()))

# %%
# %%time
coherence1_cv_mecab = clusteringModelPath + 'coherence1_mecab_c_v'
if not os.path.isfile(coherence1_cv_mecab):
    cm_mecab_cv = CoherenceModel(model = ldamodel_mecab, 
                         texts = tagged_text_mecab,
                         dictionary = dictionary_mecab, 
                         coherence = 'c_v')
    cm_mecab_cv.save(coherence1_cv_mecab)
else:
    cm_mecab_cv = CoherenceModel.load(coherence1_cv_mecab)

# %%
print ('Coherence : {}'.format(cm_mecab_cv.get_coherence()))

# %%
# %%time
pyLDAvis.gensim.prepare(ldamodel_mecab, corpus_mecab, dictionary_mecab)

# %%
ldatopics_mecab = ldamodel_mecab.show_topics(formatted = False)

# %% [markdown]
# ##### display num_topics - LDA graph using c_v coherence

# %%
# %%time
lmlist_ct, c_v_ct = evaluate_graph(dictionary = dictionary_ct, corpus = corpus_ct, texts = tagged_text_ct, limit = 30, tagger = 'ct', modelpath = clusteringModelPath)

# %%
# %%time
lmlist_mecab, c_v_mecab = evaluate_graph(dictionary = dictionary_mecab, corpus = corpus_mecab, texts = tagged_text_mecab, limit = 30, tagger = 'mecab', modelpath = clusteringModelPath)
